# %%
#newlist of characters to use later on the dictionary keys

# %%
import pandas as pd
from collections import defaultdict

# %%
#https://en.wikipedia.org/wiki/List_of_Stranger_Things_characters
all_characters_main = pd.read_html("https://en.wikipedia.org/wiki/List_of_Stranger_Things_characters")[3]

# %%
all_characters_second = pd.read_html("https://en.wikipedia.org/wiki/List_of_Stranger_Things_characters")[4]

# %%
recuring_chars = all_characters_second[(   'Character',    'Character')].tolist()

# %%
main_chars = all_characters_main[(   'Character',    'Character')].tolist()

# %%
full_character =main_chars+recuring_chars

# %%
full_character
# Out:
# ['Joyce Byers',
#  'Jim Hopper',
#  'Mike Wheeler',
#  'Eleven / Jane Hopper',
#  'Dustin Henderson',
#  'Lucas Sinclair',
#  'Nancy Wheeler',
#  'Jonathan Byers',
#  'Karen Wheeler',
#  'Martin Brenner',
#  'Will Byers',
#  'Max Mayfield',
#  'Steve Harrington',
#  'Billy Hargrove',
#  'Bob Newby',
#  'Sam Owens',
#  'Robin Buckley',
#  'Erica Sinclair',
#  'Murray Bauman',
#  'Vecna / One / Henry Creel',
#  'Argyle',
#  'Eddie Munson',
#  'Ted Wheeler',
#  'Calvin Powell',
#  'Lonnie Byers',
#  'Barbara "Barb" Holland',
#  'Phil Callahan',
#  'Demogorgon',
#  'Connie Frazier',
#  'Scott Clarke',
#  'Lead Agent',
#  'James Dante',
#  'Holly Wheeler',
#  'Florence',
#  'Troy Walsh',
#  'Tommy Hagan',
#  'Carol Perkins',
#  'Kali Prasad/ Eight',
#  'Claudia Henderson',
#  'Terry Ives',
#  'Bruce',
#  'Grigori',
#  'Tom Holloway',
#  'Heather Holloway',
#  'Alexei',
#  'Mayor Larry Kline',
#  'Doris Driscoll',
#  'Jason Carver',
#  'Vickie',
#  'Angela',
#  'Ten',
#  'Two',
#  'Patrick McKinney',
#  'Dmitri "Enzo" Antonov',
#  'Andy',
#  'Susan Hargrove',
#  'Lt. Colonel Sullivan',
#  'Melnikov',
#  'Wayne Munson',
#  'Agent Stinson',
#  'Yuri Ismaylov',
#  'Oleg',
#  'Ivan']

# %%
characters_v1 = []
for item in full_character:
    item = item.replace(". ",".")
    if "/" in item:
        new_tmps = item.split("/")
        upper_tmps = [x.strip().split()[0].upper() for x in new_tmps]
        characters_v1.extend(upper_tmps)
    else:
        characters_v1.append(item.upper().split()[0])

# %%
characters_v1.append("HOPPER")

# %%
print(characters_v1)
# Out:
# ['JOYCE', 'JIM', 'MIKE', 'ELEVEN', 'JANE', 'DUSTIN', 'LUCAS', 'NANCY', 'JONATHAN', 'KAREN', 'MARTIN', 'WILL', 'MAX', 'STEVE', 'BILLY', 'BOB', 'SAM', 'ROBIN', 'ERICA', 'MURRAY', 'VECNA', 'ONE', 'HENRY', 'ARGYLE', 'EDDIE', 'TED', 'CALVIN', 'LONNIE', 'BARBARA', 'PHIL', 'DEMOGORGON', 'CONNIE', 'SCOTT', 'LEAD', 'JAMES', 'HOLLY', 'FLORENCE', 'TROY', 'TOMMY', 'CAROL', 'KALI', 'EIGHT', 'CLAUDIA', 'TERRY', 'BRUCE', 'GRIGORI', 'TOM', 'HEATHER', 'ALEXEI', 'MAYOR', 'DORIS', 'JASON', 'VICKIE', 'ANGELA', 'TEN', 'TWO', 'PATRICK', 'DMITRI', 'ANDY', 'SUSAN', 'LT.COLONEL', 'MELNIKOV', 'WAYNE', 'AGENT', 'YURI', 'OLEG', 'IVAN', 'HOPPER']

# %%
from pdfminer.layout import LAParams
from pdfminer.converter import PDFResourceManager, PDFPageAggregator
from pdfminer.pdfpage import PDFPage
from pdfminer.layout import LTTextBoxHorizontal
from pdfminer.high_level import extract_text


elementslist2 = []
from pdfminer.high_level import extract_pages 
for page_layout in extract_pages("s3e2_8flix.pdf"):
    for element in page_layout: 
        if isinstance(element, LTTextBoxHorizontal):
            elementslist2.append(element.get_text())

# %%
text = extract_text('s3e2_8flix.pdf')

# %%
text
# Out:
# 'STRANGER THINGS 3\n\nEPISODE #302\n\n"CHAPTER TWO: THE MALL RATS"\n\nby\n\nThe Duffer Brothers\n\nFINAL PRE-POST DRAFT\n\n\x0cFloor  plans  are  for  reference  only.  Check  with  Art  Dept.  for \nupdated versions.\n\nii.\nii.\n\n\x0ciii.iii.\n\n\x0civ.\niv.\n\nNOTE: Scenes in RED take place in the UPSIDE DOWN.\n\nNOTE: Interior Starcourt Mall scenes include SHOP ADDRESS in \nparenthesis (see attached floor plan).*\n\n* 2M is now FLASH STUDIO (formerly OLAN MILLS).\n\n\x0cFADE IN:\n\nINT. ERIMBORN STEELWORKS - NIGHT\n\nPicking up where we left off.\n\nThe only light, from the BRIGHT MOON, spills through the \nFILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the \nSTAIRS leading to the basement. It’s QUIET.\n\nJUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the \nstairwell door, pulling himself up. Then, he BREAKS FREE from \nthe FLESHY TENTACLE which pulled him downstairs only moments \nago.\n\nEXT. ERIMBORN STEELWORKS - MOMENTS LATER\n\nBilly sprints out of the abandoned factory, heading to his \nCAMARO.\n\nBilly speeds away; leaving a trail of dust in his wake.\n\nEXT. CORNWALLIS ROAD - LATER\n\nBilly pulls over to a TELEPHONE BOOTH. He dashes frantically \nfrom his car to the BOOTH. He DIALS 9-1-1. On the SECOND \nRING, the FEMALE OPERATOR picks up:\n\nOPERATOR (O.S.)\nNine-one-one, what’s your \nemergency?\n\nFLASHBACK:\n\nI/E. ERIMBORN STEELWORKS - NIGHT\n\nBilly getting pulled into the factory, and down the stairs.\n\nIN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS \nattack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS \nTO BILLY’S FACE.\n\nFLASH CUT TO:\n\nEXT. CORNWALLIS ROAD - NIGHT\n\nThe LIGHT inside the booth FLICKERS.\n\n8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY\n\n\x0c2.\n2.\n\nOPERATOR (O.S.)\n\nIs someone there? Hello?\n\nThe LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the \nreceiver and then steps outside the booth.\n\nHe sees something off in the distance. WHITE PARTICLES float \nin the air. Billy steps onto Cornwallis Road. Through THICK \nFOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male, \nfemale, various ages) shuffling forward.\n\nBILLY\n\nWhat do you want?\n\nHe cautiously walks toward the crowd.\n\nHey! I said, what do you want?\n\nBILLY (CONT\'D)\n\nThe group continues shuffling toward Billy.\n\nBILLY (CONT\'D)\nI said WHAT -- DO -- YOU -- WANT?\n\nTHUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the \nUPSIDE DOWN. The group halts their march. A LONE FIGURE \nemerges from the silhouetted group and approaches Billy.\n\nThe FIGURE STEPS INTO THE LIGHT. \n\nBilly stares into the face of an IDENTICLE VERSION OF \nHIMSELF.\n\nOPENING CREDITS\n\nCUT TO:\n\nEFFECTS IN:\n\nEXT. HOPPER’S CABIN - MORNING\n\nELEVEN is pacing on the porch. She leans over the edge, takes \na look round, then turns and storms inside the cabin.\n\nINT. HOPPER\'S CABIN - ON GOING\n\nEl marches in and heads straight for the TELEPHONE ON THE \nWALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.\n\nHOPPER\n\nIs everything okay?\n\n8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY\n\n\x0c3.\n3.\n\nEL\n\nYes.\n\nINT. WHEELER RESIDENCE - KITCHEN - MORNING\n\nKAREN WHEELER is packing LUNCH and SNACKS.\n\nPHONE RINGS\n\nKaren answers.\n\nKAREN\n\nHello, this is the Wheelers.\nYeah, just a sec.\n\nKaren puts her hand over the mouthpiece, then yells:\n\nMike! Phone!\n\nKAREN (CONT\'D)\n\nINT. WHEELER RESIDENCE - BASEMENT - ON GOING\n\nMike is pacing nervously.\n\nMIKE\n(yells to Karen)\n\nOkay!\n\nMike walks stiffly to the PHONE ON THE WALL. He takes a deep \nbreath before picking up.\n\nMIKE (CONT\'D)\n\n(into the phone)\n\nHello?\n\nINT. HOPPER\'S CABIN - EL’S ROOM - MORNING\n\nEl goes into her room.\n\nEL\n\nIt’s nine-thirty-two. Where are \nyou?\n\nShe TELEKINETICALLY closes her bedroom door.\n\nINTERCUT: MIKE’S BASEMENT AND EL’S BEDROOM\n\nMIKE\n(stammers)\n\nSorry, I was just about to call. I -\n- um -- can’t see you today.\n\n8FLiX.com SCR ...

# %%
text2 = text.replace("\n\n",":")

# %%
print(text2)
# Out:
# STRANGER THINGS 3:EPISODE #302:"CHAPTER TWO: THE MALL RATS":by:The Duffer Brothers:FINAL PRE-POST DRAFT:Floor  plans  are  for  reference  only.  Check  with  Art  Dept.  for
# updated versions.:ii.
# ii.:iii.iii.:iv.
# iv.:NOTE: Scenes in RED take place in the UPSIDE DOWN.:NOTE: Interior Starcourt Mall scenes include SHOP ADDRESS in
# parenthesis (see attached floor plan).*:* 2M is now FLASH STUDIO (formerly OLAN MILLS).:FADE IN::INT. ERIMBORN STEELWORKS - NIGHT:Picking up where we left off.:The only light, from the BRIGHT MOON, spills through the
# FILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the
# STAIRS leading to the basement. It’s QUIET.:JUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the
# stairwell door, pulling himself up. Then, he BREAKS FREE from
# the FLESHY TENTACLE which pulled him downstairs only moments
# ago.:EXT. ERIMBORN STEELWORKS - MOMENTS LATER:Billy sprints out of the abandoned factory, heading to his
# CAMARO.:Billy speeds away; leaving a trail of dust in his wake.:EXT. CORNWALLIS ROAD - LATER:Billy pulls over to a TELEPHONE BOOTH. He dashes frantically
# from his car to the BOOTH. He DIALS 9-1-1. On the SECOND
# RING, the FEMALE OPERATOR picks up::OPERATOR (O.S.)
# Nine-one-one, what’s your
# emergency?:FLASHBACK::I/E. ERIMBORN STEELWORKS - NIGHT:Billy getting pulled into the factory, and down the stairs.:IN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS
# attack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS
# TO BILLY’S FACE.:FLASH CUT TO::EXT. CORNWALLIS ROAD - NIGHT:The LIGHT inside the booth FLICKERS.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:2.
# 2.:OPERATOR (O.S.):Is someone there? Hello?:The LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the
# receiver and then steps outside the booth.:He sees something off in the distance. WHITE PARTICLES float
# in the air. Billy steps onto Cornwallis Road. Through THICK
# FOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male,
# female, various ages) shuffling forward.:BILLY:What do you want?:He cautiously walks toward the crowd.:Hey! I said, what do you want?:BILLY (CONT'D):The group continues shuffling toward Billy.:BILLY (CONT'D)
# I said WHAT -- DO -- YOU -- WANT?:THUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the
# UPSIDE DOWN. The group halts their march. A LONE FIGURE
# emerges from the silhouetted group and approaches Billy.:The FIGURE STEPS INTO THE LIGHT. :Billy stares into the face of an IDENTICLE VERSION OF
# HIMSELF.:OPENING CREDITS:CUT TO::EFFECTS IN::EXT. HOPPER’S CABIN - MORNING:ELEVEN is pacing on the porch. She leans over the edge, takes
# a look round, then turns and storms inside the cabin.:INT. HOPPER'S CABIN - ON GOING:El marches in and heads straight for the TELEPHONE ON THE
# WALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.:HOPPER:Is everything okay?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:3.
# 3.:EL:Yes.:INT. WHEELER RESIDENCE - KITCHEN - MORNING:KAREN WHEELER is packing LUNCH and SNACKS.:PHONE RINGS:Karen answers.:KAREN:Hello, this is the Wheelers.
# Yeah, just a sec.:Karen puts her hand over the mouthpiece, then yells::Mike! Phone!:KAREN (CONT'D):INT. WHEELER RESIDENCE - BASEMENT - ON GOING:Mike is pacing nervously.:MIKE
# (yells to Karen):Okay!:Mike walks stiffly to the PHONE ON THE WALL. He takes a deep
# breath before picking up.:MIKE (CONT'D):(into the phone):Hello?:INT. HOPPER'S CABIN - EL’S ROOM - MORNING:El goes into her room.:EL:It’s nine-thirty-two. Where are
# you?:She TELEKINETICALLY closes her bedroom door.:INTERCUT: MIKE’S BASEMENT AND EL’S BEDROOM:MIKE
# (stammers):Sorry, I was just about to call. I -
# - um -- can’t see you today.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:4.
# 4.:EL:What? Why not?:MIKE:It’s my Nana. She’s very sick.:EL:But Hop said that your Nana was
# okay. That it was a false alarm.:MIKE:Yeah -- that’s what we thought it
# was at first, but then she took a
# real turn for the worse.:Oh.:EL:MIKE:Yeah. We think she might -- die.:INT. WHEELER RESIDENCE - KITCHEN - ON GOING:Karen’s been listening in.:KAREN:What?:INT. WHEELER RESIDENCE - BASEMENT - ON GOING:A look of worry flashes across Mike’s face before he covers
# the mouthpiece and yells upstairs.:MIKE:Mom! Get off the phone! How many
# times?!:INT. WHEELER RESIDENCE - KITCHEN - ON GOING:Karen, still on the phone, but yelling to Mike.:KAREN:Did Nana call?:INT. WHEELER RESIDENCE - BASEMENT - ON GOING:MIKE:(yelling in the direction :of the kitchen)
# (MORE)
# (MORE):8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:MIKE (CONT'D)
# MIKE (CONT'D)
# No, Mom! Just get -- off - the --
# phone!:5.
# 5.:INT. WHEELER RESIDENCE - KITCHEN - ON GOING:With a distraught expression, Karen SCOFFS, then hangs up.:INT. WHEELER RESIDENCE - BASEMENT - ON GOING:Mike takes a deep breath, then::MIKE:(to El)
# Sorry about that.:INT. HOPPER'S CABIN - EL'S ROOM - ON GOING:EL:Was that your mom?:INTERCUT: MIKE’S BASEMENT AND EL’S BEDROOM:MIKE:Yeah. She’s so upset, she’s making
# no sense. Because we have to go to
# the nursing home. To see Nana.:EL
# You can come over after?:MIKE:No! I mean -- I just think I need
# to be alone today.
# (thinking)
# With my -- feelings?:EL:Do you lie?:MIKE:(aghast):What?! No. Friends don’t lie.:Time to end this before the hole gets any deeper.:MIKE (CONT'D):(covers the mouthpiece):What, Mom?:Mike waits for Karen’s “response”. Then::8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:6.
# 6.:MIKE (CONT'D):(to El):My mom’s calling me. Better go.
# Talk to you tomorrow. Miss you
# already. Bye!:He quickly hangs up.:INT. HOPPER'S CABIN - EL'S ROOM - ON GOING:El stares at her receiver in bewilderment.:INT. WHEELER RESIDENCE - BASEMENT - ON GOING:Mike leans his forehead against his phone and sighs.:INT. HOPPER'S CABIN - ON GOING:El comes out of her room to hang up. Hopper is standing in
# the kitchen eating a BOWL OF CEREAL.:HOPPER
# What’s going on?:Without answering, El trudges back to her room and
# TELEKINETICALLY slams the door behind her.:IN THE KITCHEN, a smile spreads across Hopper’s face. The
# song: “YOU DON’T MESS AROUND WITH JIM” BY JIM CROCE plays.:EXT. FORESTED ROAD - DAY:Hopper’s POLICE TRUCK drives by. The SONG CONTINUES, and
# Hopper sings along.:INT. HOPPER’S TRUCK - DAY:He’s drumming his hands on the wheel and singing along. Yes,
# he certainly showed that -- that smug sonofabitch, Mike,
# who’s boss.:HOPPER:(singing):And they say...
# You don’t tug on Superman’s cape...
# You don’t spit into the wind...
# You don’t pull the mask on...
# That old Lone Ranger...
# And you don’t mess around with Jim.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:7.
# 7.:EXT. MELVALD’S GENERAL STORE - LATER:Hopper pulls into an empty parking space next to JOYCE’S FORD
# PINTO.:INT. MELVALD'S GENERAL STORE - MOMENTS LATER:With a hop in his step, Hopper bursts through the door. JOYCE
# BYERS is at the CASH COUNTER.:HOPPER
# Emotions have been shared.
# Boundaries have been set. Order --
# has been ... restored.:JOYCE:Wait, wait, it worked?:HOPPER:Uh, this is the first day in six
# long, excruciating months that they
# will not be seeing each other. Yes!
# I think it worked! Yes!:Hopper chuckles and Joyce CLAPS EMPHATICALLY.:HOPPER (CONT'D):No, stop! It’s all you. I’m a
# puppet, you’re the master.:So you remembered everything?:JOYCE:HOPPER:(laughs):Yeah, yeah. I mean I had to
# improvise a little bit, you know?
# It turns out, getting to Mike --
# that was the key.:JOYCE
# And you didn’t yell at him?:HOPPER:I’ll tell you everything over
# dinner. I was thinking, you know,
# Enzo’s, tonight, seven o’clock.
# Hey, before you say no, I’d like to
# make one thing crystal clear. This
# is not a date.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:8.
# 8.:JOYCE:Wait, a date? You never said
# anything about a date.:HOPPER:I know. I didn’t say anything about
# a date. I just wanted to clear it
# up in case there was any confusion
# on your part.:JOYCE:There’s not.:HOPPER:Great. It’s just two friends
# getting together for a nice dinner.
# I mean, we’ve earned it, haven’t
# we?:JOYCE:I can’t be out late.:HOPPER:You’ll be home by nine.:Eight.:JOYCE:HOPPER:Eight-thirty, I’ll pick you up.:JOYCE:I’ll meet you there.:HOPPER:Seven. Enzo’s. Meeting there. Deal.:JUST THEN, Hopper’s WALKIE TALKIE comes alive.:OFFICER POWELL (O.S.)
# Hey, Chief, do you copy? Chief!:He turns and heads for an AISLE while grabbing his walkie
# from his belt.:HOPPER:(to Powell):Yeah, I’m a little busy right now.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:EXT. TOWN HALL - DAY:PROTESTERS, female, male, adults, have gathered to protest
# the Mayor and Starcourt Mall. They’re carrying PLACARDS and
# shouting.:9.
# 9.:OFFICER POWELL
# Yeah, well, I’m busier here. You
# wanna keep your job tomorrow, I
# think you need to get your ass to
# Town Hall. Now!:INT. MELVALD'S GENERAL STORE - DAY:Hopper puts his walkie on his belt.:HOPPER:Duty calls.:While heading for the door, he nearly slips on FALLEN
# MAGNETS. But, without missing a beat::Clean up on aisle five.:HOPPER (CONT'D):JOYCE:Bye!:HOPPER
# See you tonight.:IN THE AISLE, Joyce crouches down and picks up one of the
# magnets. She tries to put one back on the DISPLAY, but it
# falls down. She tries again with DIFFERENT MAGNETS but the
# same thing happens.:INT. THE HAWKINS POST - COFFEE ROOM - DAY:NANCY WHEELER is pouring COFFEE into a MUG absentmindedly
# while glancing at the NOTE: DORIS DRISCOLL 4819 CORNWALLIS RD
# DISEASE RATS. Then she notices the coffee overflowing.:NANCY:Oh, shit, shit, shit.:INT. THE HAWKINS POST - REPORTERS’ OFFICE - ON GOING:BRUCE is leaning back in his chair. He notices Nancy.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:10.
# 10.:BRUCE:Whoopsie-daisy! Careful, there,
# Nancy Drew. Careful. Pouring
# coffee’s a tough gig, girl:The other REPORTERS in the room, SNICKER.:INT. THE HAWKINS POST - COFFEE ROOM - ON GOING:Nancy forces a tight smile then begins the clean up.:INT. THE HAWKINS POST - TOM HOLLOWAY’S OFFICE - LATER:TOM HOLLOWAY is at his DESK. Nancy walks in carrying the MUG.:NANCY:And here you are, two creams, two
# sugars.:TOM:Thanks, sweetheart.:NANCY:Of course.:BEAT:Tom?:Hm?:NANCY (CONT'D):TOM:NANCY:I really hate to ask this, but do
# you think one of the other girls
# could run and grab lunch today?:They’re needed at their desks.:TOM:NANCY:I know, I just, I really need to go
# to the doctor.:Nancy leans closer to Tom while he sips his coffee.:NANCY (CONT'D)
# I’ve been having some -- um, girl
# problems.:Tom COUGHS NERVOUSLY before recovering and nodding shyly.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:INT. THE HAWKINS POST - DARK ROOM - MOMENTS LATER:Ignoring the ILLUMINATED RED LIGHT, Nancy bursts in. JONATHAN
# BYERS is working.:11.
# 11.:JONATHAN:Oh, come on! The light!:NANCY:Let’s go!:EXT. THE HAWKINS POST - MOMENTS LATER:With a spring in her step, and a renewed sense of self-worth,
# Nancy rushes out of the building. Jonathan is not too far
# behind her carrying BAGS OF PHOTOGRAPHY EQUIPMENT.:JONATHAN:Look, I just don’t know if this is
# such a good idea anymore.:NANCY:Really? Because I feel like this is
# the best idea I’ve had all summer.:NEAR JONATHAN’S CAR:JONATHAN:Look, all I’m saying is, what harm
# is there in asking?:NANCY:The harm in asking is that Tom will
# say no. We ask for forgiveness, not
# permission. And if the story’s as
# good as I think it’s gonna be, then
# Tom won’t care. In fact, he’ll
# thank us.:JONATHAN:Or, the old lady is nuts and the
# story blows up in our face and Tom
# fires us.:NANCY:And then we never have to work in
# this shithole again.:They climb into the car.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:INT. STARCOURT MALL - FOOD COURT - DAY:MONTAGE OVER THE SONG: “GET UP AND GO” BY THE GO GO’S:12.
# 12.:- PATRONS eating.:- COUPLES by the FOUNTAIN.:- WORKERS preparing FOOD.:- TEENAGERS being teenagers.:INT. SCOOPS AHOY (1D) - DAY:ROBIN BUCKLEY glumly hands a FATHER AND DAUGHTER their ICE
# CREAM CONES.:ROBIN:(emotionless):Have a nice day.:DAUGHTER
# (enthusiastic):Thank you!:DUSTIN HENDERSON is standing right behind them. He approaches
# Robin at the counter. Dustin’s toothless smile - BEAMING.:DUSTIN:ROBIN:(morosely):Hi!:Hi.:DUSTIN:I’m Dustin.:I’m Robin.:ROBIN:DUSTIN:Please to meet you. Uh, is -- is he
# here?:ROBIN:Is who here?:STEVE HARRINGTON swings open the door from the back room.:STEVE:(excited):Henderson!:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:13.
# 13.:Dustin laughs.:Henderson! He’s back!:STEVE (CONT'D):He makes his way to Dustin.:DUSTIN
# I’m back! You got the job!:STEVE:I got the job!:Steve PANTOMIMES AND IMITATES A TRUMPET before he and Dustin
# do a COMPLICATED HANDSHAKE, including a DUEL WITH LIGHTSABERS
# where Steve, ultimately, “dies” after being disemboweled.
# They both LAUGH AND GRIN WIDELY after Steve “spills his
# guts.”:ROBIN:How many children are you friends
# with?:Steve’s smile fades.:INT. SCOOPS AHOY (1D) - BOOTH - LATER:Steve and Dustin are in a BOOTH. Dustin is enjoying the
# BANANA BOAT ICE CREAM.:STEVE:No, no. No way. Hotter than Phoebe
# Cates?:DUSTIN:Brilliant, too. And she doesn’t
# even care that my real pearls are
# still coming in. She says kissing
# is better without teeth.:Steve struggles to maintain a neutral expression.:STEVE:Wow. Yeah, that’s great. Proud of
# you, man. That’s kinda romantic.
# Just -- like, wow.:BEAT:DUSTIN:So do you really just get to eat as
# much of this as you want?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:14.
# 14.:STEVE:Yeah. I mean, sure. It’s not really
# a good idea for me, though. I gotta
# keep in shape for the ladies.:Robin is cleaning and organizing near the counter.:ROBIN:Yeah, and how’s that working out
# for you?:STEVE:Ignore her.:DUSTIN:Seems cool.:STEVE:She’s not. So, where are the other
# knuckleheads?:DUSTIN
# They ditched me yesterday.:No.:STEVE:DUSTIN:My first day back! Can you believe
# that shit?:STEVE
# Whoa. Seriously?:DUSTIN:I swear to God. Mm. They’re gonna
# regret it, though. Big time. When
# they don’t get to share in my
# glory.:STEVE:Glory? What glory?:Dustin scoots closer to Steve, and lowers his voice.:DUSTIN:So, last night, we’re trying to get
# in contact with Suzie -- and, uh --:(glances around, covers :mouth, whispering):I intercepted a secret Russian
# communication.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:15.
# 15.:STEVE:What?:Dustin looks around, and repeats SOFTLY::DUSTIN:I intercepted a secret Russian
# communication.:STEVE:Just speak louder.:DUSTIN
# (much louder):I intercepted a secret Russian
# communication!:PATRONS stop what they’re doing and look.:STEVE:Jeez, shh. Yeah, okay that’s what I
# thought you said.:(beat):What does that mean?:DUSTIN:It means, Steve, we could be
# heroes. True American heroes.:Ah!:Mm-hmm.:STEVE:DUDTIN:STEVE
# American heroes.:DUSTIN:Just think, you could have all the
# ladies you want and more.:More?:More.:STEVE:DUSTIN:STEVE:I like more.:DUSTIN:Mm-hmm.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:16.
# 16.:STEVE:What’s the catch?:DUSTIN:No catch, I just need your help.:STEVE:With what?:Dustin unzips his BACKPACK and pulls out a RUSSIAN - ENGLISH
# DICTIONARY.:DUSTIN:Translation.:EXT. 4819 CHERRY LANE - DAY:MAX MAYFIELD SKATEBOARDS out front of her house. She attempts
# an OLLIE but fails. She tries again, nearly falling this
# time, and sending her board rolling away.:The board rolls to a stop at El’s feet. She kicks it up into
# her hands.:EL:(gives Max the board):MAX:(confused):Hi.:Hi?:EL:(shyly)
# Can we talk?:INT. MAX’S BEDROOM - LATER:El is sitting on the edge of Max’s BED. Max paces.:EL:And then he said he missed me. And
# then he just hung up.:MAX:He’s a piece of shit.:What?:EL:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:17.
# 17.:MAX:Mike doesn’t have jack shit to do
# today and his Nana obviously isn’t
# sick. I guarantee you, him and
# Lucas are playing Atari right now.:EL
# But friends don’t lie.:MAX:Yeah, well, boyfriends lie. All.
# The. Time.:INT. WHEELER RESIDENCE - BASEMENT - DAY:Mike is pacing.:MIKE:She knows I’m lying. She knows I’m
# lying.:LUCAS SINCLAIR is sitting in the RECLINER listening intently.
# WILL BYERS is sitting at the GAME TABLE, setting up D&D, not
# interested in the conversation.:LUCAS:I don’t even understand. Why lie?:MIKE
# Hopper. He threatened me.:LUCAS
# Did he say he’d kill you?:What? No!:MIKE:LUCAS:So then, what’s the big deal?:MIKE:The big deal is, if I don’t do what
# he says, then he’ll stop me from
# seeing El. Like, permanently. You
# don’t understand, Lucas. He’s
# crazy. He’s lost his mind.:WILL:Hey, guys, I’m almost set up here.:MIKE:I had no choice, Lucas. I really
# had no choice.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:18.
# 18.:LUCAS:I just wish you’d consulted me,
# because the way you handled this,
# you’re in deep shit.:INT. MAX'S BEDROOM - DAY:MAX:You’re going to stop calling him.
# You’re going to ignore his calls.
# As far as you’re concerned, he
# doesn’t exist.:EL:(intrigued):Doesn’t exist?:MAX:He treated you like garbage. You’re
# gonna treat him like garbage. Give
# him a taste of his own medicine.:EL
# Give him the medicine.:MAX:Mm-hmm. And if he doesn’t fix this,
# if he doesn’t explain himself, dump
# his ass.:INT. WHEELER RESIDENCE - BASEMENT - DAY:Mike flops down on the SOFA.:LUCAS:I’m not gonna lie, it’s gonna be
# bad. But, you can fix this.:(rises from his seat)
# It’s just one little mistake.
# I’ve made hundreds, thousands. Max
# has dumped me five times! But what
# have I done? Huh? Have I despaired?
# No. I’ve marched back into battle,
# and I’ve won her back. Every.
# Single. Freaking. Time.:How?:MIKE:LUCAS:I’ll show you. Come on.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:19.
# 19.:INT. MAX'S BEDROOM - DAY:Come on.:MAX:EL:Where are we going?:MAX:To have some fun. There’s more to
# life than stupid boys, you know.:INT. WHEELER RESIDENCE - BASEMENT - DAY:Mike and Lucas run upstairs, forgetting Will.:WILL:Wait, guys! I’m still here!:Will cranes his neck toward the stairs.:Guys?:WILL (CONT'D):EXT. HAWKINS COMMUNITY POOL - DAY:DOZENS OF CHILDREN AND ADULTS hang out and play in the water.
# HEATHER HOLLOWAY, on duty sitting in the HIGHCHAIR, blows her
# MARINE WHISTLE, then raises a MEGAPHONE to her mouth.:HEATHER:Hey! No dunking, Curtis!:(beat)
# No -- dunking.:Karen and HER MOM FRIENDS lounge, reading ROMANCE NOVELS,
# TRASHY MAGAZINES. MOM #1 (blonde), MOM #2 (LIZ - black hair),
# MOM #3 (Jill - brunette).:LIZ:God, even her voice annoys me.:JILL:Nails on a chalkboard.:MOM #1:(putting lotion on her :legs):Don’t worry, ladies, ten more
# minutes ‘till showtime. Liz --:(holds up lotion bottle):-- will you get my back?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:Karen notices Billy rushing through a GRATED DOOR into the
# BUILDING next to the pool.:20.
# 20.:KAREN:Hey, Jill, I gotta used the
# restroom. Will you watch Holly for
# me?:JILL:Sure thing, hon.:KAREN:Thanks.:INT. HAWKINS COMMUNITY POOL - MECHANICAL ROOM - ON GOING:Karen walks in, through the grated door. It’s a NARROW ROOM
# lined with MACHINERY AND ELECTRICAL PANELS. She rounds a
# corner into the next room:INT. HAWKINS COMMUNITY POOL - STORAGE ROOM - ON GOING:SHELVES LINE THE WALLS. CHEMICALS and HARDLY-USED POOL
# SUPPLIES fill the shelves. Karen walks in. Billy, looking
# through the chemical bottles, has his back turned to the
# door.:KAREN
# (concerned):Billy?:Billy sets down a CHEMICAL BOTTLE on the shelf, but does not
# turn to face Karen.:KAREN (CONT'D)
# I understand if you’re angry with
# me.:Billy does not respond.:I wanted to explain --:KAREN (CONT'D):(takes two steps closer)
# -- why I didn’t come last night.
# It’s not you, it’s just -- I have a
# family.:SWEAT on Billy’s face glistens in the poorly-lit room.
# Karen’s VOICE STARTS TO ECHO. We can HEAR BILLY’S HEARTBEAT
# POUNDING.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:21.
# 21.:KAREN (CONT'D)
# And I can’t do anything that will
# hurt them. You can understand that,
# right? But I shouldn’t have said
# that --:Billy TURNS QUICKLY, THEN SLAMS KAREN’S HEAD INTO A SHELF.:BLACK:BEAT:Karen’s VOICE ECHOES::KAREN (O.S.):Billy?:CUT TO::CUT TO::INT. HAWKINS COMMUNITY POOL - STORAGE ROOM - DAY:Karen is standing behind Billy as if nothing happened.:KAREN:Billy ... please, will you talk to
# me?:Billy turns to face her. Karen is slightly taken aback by his
# appearance.:BILLY
# Stay away from me, Karen.:He marches past Karen.:EXT. HAWKINS COMMUNITY POOL - DAY:INTERCUT: BILLY’S POV & HANDHELD FOLLOW:POV BILLY: Walking through the grated door.:Billy stumbles out. He looks up, holding a hand up against
# the blazing sun.:POV BILLY: BLURRED, OVER-EXPOSED. Scans the pool and
# surroundings. Heather struts past him.:HEATHER:Looking good, Billy.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:22.
# 22.:Billy stares at her confusedly, then passes Karen’s friends.:POV BILLY: Karen’s friends, flirty smile, then in UNISON::KAREN’S FRIENDS:Afternoon, Billy.:Billy stares at them confusedly.:EXT. HAWKINS COMMUNITY POOL - MOMENTS LATER:AT THE HIGHCHAIR, Billy struggles to climb up but manages to
# get himself seated. He’s pale, clammy. He LOOKS UP. The
# bright sun PULSES. He’s exhausted. His PUPILS: FULLY
# DIALATED.:ECU: INTENSLY GLOWING SUN:DISSOLVE TO::INT. SCOOPS AHOY - DAY:ECU: OVERHEAD; TUB OF ICE CREAM. MINT CHOCOLATE-CHIP. Robin’s
# HAND, holding a small SAMPLE SPOON, scoops.:Robin gives it to ERICA SINCLAIR, who, with her THREE FRIENDS
# standing close behind, accepts the free sample. She tastes
# it.:ERICA:Can I try the peppermint stick?:ROBIN:Haven’t you already tried the
# peppermint stick?:ERICA:(annoyed):Yes, and I’d like to try it again.:Robin rolls her eyes.:ROBIN:(calling out):Steve!:INT. SCOOPS AHOY - BACK ROOM - DAY:Steve, eating a BANANA, is pacing. Dustin is sitting at a
# TABLE. On the table: RUSSIAN - ENGLISH DICTIONARY and a
# MICROCASSETTE RECORDER. :8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:A recording Dustin made of the SECRET RUSSIAN COMMUNICATION
# plays. In the background of the recording, the instrumental
# song: “DAISY BELL” BY HARRY DACRE plays.:23.
# 23.:DUSTIN
# (turns off recorder):So, what do you think?:STEVE:It sounded familiar.:What?:DUSTIN:STEVE:The music. The music right there at
# the end.:DUSTIN:Why are you listening to the music,
# Steve? Listen to the Russian! We’re
# translating Russian!:STEVE:I’m trying to listen to the
# Russian, but there’s music playing -
# -:Robin bursts in.:ROBIN:All right, babysitting time is
# over. You need to get in there.:Robin instantly turns her attention to the WALL MOUNTED WHITE
# BOARD. It no longer shows Steve’s “YOU SUCK” ratio. Instead,
# the RUSSIAN ALPHABET and its ENGLISH EQUIVALENT.:ROBIN (CONT'D)
# Hey, my board! That was important
# data, shitbirds.:DUSTIN:I guarantee you, what we’re doing
# is way more important than your
# data.:ROBIN:Yeah? And how do you know these
# Russians are up to no good,
# anyways?:Dustin turns to Steve in shock, and without a hint of irony::8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:24.
# 24.:DUSTIN
# How does she know about the
# Russians?:STEVE:(mouth full of banana):I don’t know.:DUSTIN:You told her about the
# Russians.:It wasn’t me.:STEVE (CONT'D):ROBIN:Hello, I can hear you.:Steve and Dustin regard Robin.:ROBIN (CONT'D)
# Actually, I can hear everything.
# You are both extremely loud. You
# think you have evil Russians
# plotting against our country, on
# tape, and you’re trying to
# translate, but haven’t figured out
# a word because you didn’t realize
# Russians use an entirely different
# alphabet than we do. Sound about
# right?:She reaches for the recorder, but Steve snaps it away.:STEVE:Whoa, whoa, what do you think
# you’re doing?:ROBIN
# I wanna hear it.:Why?:STEVE:Why?:DUSTIN:ROBIN:‘Cause maybe I can help. I’m fluent
# in four languages, you know.:Russian?:DUSTIN:ROBIN:Ou-yay are-yay umb-day.:Steve and Dustin are impressed!:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:25.
# 25.:Oh-ho-ho!:STEVE:Holly shit!:DUSTIN:ROBIN
# That was Pig Latin, dingus.:Steve smacks Dustin with the banana peel.:Idiot.:STEVE:ROBIN:But I can speak Spanish and French
# and Italian, and I’ve been in band
# for twelve years. My ears are
# little geniuses, trust me.:Steve is skeptical.:ROBIN (CONT'D)
# Come on, it’s your turn to sling
# ice cream, my turn to translate. I
# don’t even want credit, I’m just
# bored.:The SERVICE BELL at the counter rings.:Steve and Dustin glance at each other resignedly. Then, Steve
# trades the recorder for Robin’s ICE CREAM SCOOP.:EXT. 4819 CORNWALLIS RD. - DRISCOLL RESIDENCE - DAY:Jonathan’s car pulls in to the driveway and past a MAILBOX
# that reads: DRISCOLL.:EXT. DRISCOLL RESIDENCE - PORCH - MOMENTS LATER:Nancy knocks on the door, Jonathan standing beside her. DORIS
# DRISCOLL, 80s, answers the door.:MRS. DRISCOLL:Yes?:Mrs. Driscoll?:NANCY:Yes?:MRS. DRISCOLL:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:26.
# 26.:NANCY:Hi, I’m Nancy? Nancy Wheeler, we
# spoke briefly on the phone last
# night.:JONATHAN
# We’re from The Hawkins Post.:MRS. DRISCOLL
# Oh! Oh, yes! Oh my goodness. Oh.
# You look too young for reporters.:JONATHAN
# We get that a lot.:MRS. DRISCOLL:(chuckles):Follow me.:INT. DRISCOLL RESIDENCE - ON GOING:Mrs. Driscoll leads Nancy and Jonathan through the house and
# toward the basement stairs.:NANCY:Lovely. Do you live here all alone?:Jonathan is carrying BAGS OF PHOTOGRAPHY EQUIPMENT and Nancy
# is carrying her NOTEBOOK.:MRS. DRISCOLL
# Yes. Jack, my husband, he passed
# away -- what is it now -- ten years
# ago.:NANCY:Oh, um, I’m so sorry.:MRS. DRISCOLL:Oh, don’t be. I kinda like the
# quiet.:They’re now standing at the DOOR LEADING TO THE BASEMENT.:At least, I did.:MRS. DRISCOLL (CONT'D):Mrs. Driscoll opens the door.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:27.
# 27.:INT. DRISCOLL RESIDENCE - BASEMENT - ON GOING:MRS. DRISCOLL:This way.:She starts down the stairs. Jonathan and Nancy peer down
# after her and exchange an uneasy look before following her
# down.:AT THE BOTTOM of the stairs, Mrs. Driscoll turns on the
# light.:It’s right over there.:MRS. DRISCOLL (CONT'D):She points to the other side of the basement. Nancy and
# Jonathan venture ahead. Nancy crouches down in front of
# PARTIALLY EMPTY BAGS OF FERTILIZER WITH HOLES IN THEM. She
# lifts one up.:MRS. DRISCOLL (CONT'D):You see those little teeth marks,
# don’t ya?:Jonathan SNAPS a photo and Nancy locks eyes with him.:NANCY:And, these bags, you’re sure they
# were full before?:MRS. DRISCOLL
# I’m old, honey, not senile. Bought
# them over at Blackburn’s Supplies
# just last Tuesday. Now you tell me,
# why would rats wanna eat a poor old
# woman’s fertilizer?:NANCY:Are you sure they did?:Mrs. Driscoll is slightly offended by the question.:NANCY (CONT'D)
# Maybe they just gnawed the bag? I
# mean, eating fertilizer seems --:MRS. DRISCOLL
# Crazy. Believe me, I know, honey.
# But -- something’s not right with
# these rats.:NANCY:What does that mean, exactly ...
# not right?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:28.
# 28.:MRS. DRISCOLL
# Rabies, my guess. That’s when I
# said to myself, Doris, you gotta
# call the paper. Because if those
# diseased rats are runnin’ loose,
# the people, the oughta know.
# Wouldn’t you agree?:Just then, a CRASHING SOUND from the other room startles
# Nancy and Jonathan.:MRS. DRISCOLL (CONT'D):(excited):Oh, yes, I forgot to mention! Come
# on over here.:INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - ON GOING:Mrs. Driscoll rounds a corner, followed by Nancy and
# Jonathan. Mrs. Driscoll proudly proclaims::MRS. DRISCOLL:I caught one of the little
# bastards.:ON TOP OF A WASHING MACHINE, A FLORAL SHEET covers a
# RECTANGULAR OBJECT which shakes violently.:SQUEALING. SNARLING. BANGING.:EXT. TOWN HALL - DAY:CROWDS OF PROTESTERS are shouting.:PROTESTERS:Kline’s a swine! Kline’s a swine!
# Kline’s a swine!:INT. TOWN HALL - HALLWAY - DAY:CAMERA FOLLOWS BEHIND a STRAPPING MAN CARRYING A MOTORCYCLE
# HELMET (Grigori - no face is shown) heading for the FRONT
# DOORS. He passes by Hopper sitting in a CHAIR, where the
# CAMERA HOLDS. Hopper eyeballs (Grigori) momentarily. Hopper
# has a LIT CIGARETTE hanging from his lips.:CANDACE:Jim? Mayor Kline is ready for you.:CANDACE, late 20s, is MAYOR KLINE’s SECRETARY.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:29.
# 29.:HOPPER:(unenthusiastic):Great.:He butts his cigarette out in an ASHTRAY.:INT. KLINE’S OFFICE - MOMENTS LATER:MAYOR LARRY KLINE, 50s, the wealthy (some say corrupt),
# smarmy politician responsible for building Starcourt Mall, is
# sitting behind his DESK reading the latest edition of THE
# HAWKINS POST. Candace leads Hopper in.:KLINE:Jim!:He warmly greets Hopper at the door.:Thanks for coming by.:KLINE (CONT'D):HOPPER:I’m not doing it, Larry.:KLINE:(laughs):Calm down, now. You don’t even know
# what I want.:Kline goes back to his desk.:HOPPER:You don’t like your fan club, you
# want me to shut ‘em down. Sound
# about right?:KLINE:(laughs):When did you get so serious? Take a
# seat.:PROTESTERS CAN BE HEARD YELLING. Hopper sits in the chair
# opposite the MAYOR’S DESK.:KLINE (CONT'D)
# My fan club, as you call them, no,
# you know why they’re out there,
# don’t ya?:HOPPER
# They’re not actually fans?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:30.
# 30.:KLINE:They lost their jobs to the mall
# and blame me for helping make that
# happen. Now, you go ask anyone else
# in this town -- they all love the
# mall. It helped our economy grow,
# brought in new jobs, and just some
# incredible new stores.:(reaching for a fresh :CUBAN CIGAR):Which is why they all stopped
# shopping at their, uh, mom-and-
# pops. Now, that’s not me, Jim.
# (uses the CIGAR CUTTER)
# That’s just good old fashioned
# American capitalism.:HOPPER:Well, Larry, I think that they’re
# just exercising their good old
# fashioned American right to
# protest.:Hopper stands and heads for the door. Kline is preparing to
# light his cigar.:KLINE:I agree. If they had a permit. Now
# correct me if I’m wrong here, Jim,
# but I don’t believe they secured a
# permit from your office. Did they?:HOPPER:Not that I’m aware of.:KLINE:Then I do believe it’s within my
# right to get rid of them.:(lights cigar):HOPPER:Larry, I’m not a politics guy, but
# I think if you force those people
# out of here without provocation, I
# don’t think that’s a good look for
# your re-election campaign.:Kline walks to the window overlooking the protesters. He
# peers out. An instrumental version of “AMERICA THE BEAUTIFUL”
# (ironically) plays SOFTLY in the BACKGROUND.:KLINE:You know what’s in four days, Jim?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:31.
# 31.:HOPPER
# Independence Day?:Kline turns and walks over to Hopper.:KLINE:That’s right. And I’m gonna throw
# this town the biggest bash it’s
# ever seen.:(now face to face):Fireworks, music, activities, you
# name it. I’m gonna pull out all the
# stops. You know why? ‘Cause at the
# end of the day, that’s all the
# voters will remember. But I can’t
# think, much less plan, with all
# that racket going on out there.:(opens the door for :Hopper):So, if you don’t mind, please, just
# do your job. Flash your little gold
# badge and get rid of them.:As the SONG CRESCENDOS, Kline flashes a bright smile, pats
# Hopper on the arm, and sticks the cigar between his teeth.:EXT. STARCOURT MALL - BUS STOP (L2) - DAY:MALL PATRONS get off a BUS. Including El and Max.:MAX
# So, what do you think?:El gazes worriedly.:Hey, what’s wrong?:MAX (CONT'D):EL:Too many people. Against the rules.:MAX:Seriously? You have superpowers.
# What’s the worst that could happen?:INT. STARCOURT MALL - FOOD COURT - MOMENTS LATER:A SWEEPING SHOT of the ATRIUM settles on Max and El.:MAX:So, what should we do first?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:32.
# 32.:El looks at Max blankly.:MAX (CONT'D):You’ve never been shopping before,
# have you?:El shakes her head.:MAX (CONT'D):Well, then I guess we’re just gonna
# have to try everything. Come on.:Max takes El by the hand and they run in to THE GAP.:INT. STARCOURT MALL - NEAR THE GAP (1B) - ON GOING:AT THAT MOMENT, Mike, Lucas and Will walk past, neither
# notice the other.:MIKE:I just -- I don’t understand what
# we’re looking for.:LUCAS:Something pretty and shiny that
# says, I’m sorry.:MIKE:What, just something that literally
# says I’m sorry?:LUCAS:(exasperated):No!:INT. THE GAP (1B) - LATER:Max smiles as she trails behind El who peruses racks of
# clothes. Her mouth agape, El stares up at an OUTFIT DISPLAY.:MAX
# You like that?:EL:How do I know -- what I like?:MAX:You just try things on. Until you
# find something that feels like you.:EL:Like me?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:33.
# 33.:MAX:Yeah. Not Hopper. Not Mike. You.:EXT. MELVALD'S GENERAL STORE - LATER THAT DAY:It’s quiet. A lone CAR drives past.:INT. MELVALD'S GENERAL STORE - DAY:Joyce, sitting at the CASH COUNTER, studies an open TEXTBOOK.
# Stacked around her: SEVERAL TEXTBOOKS ON ELECTROMAGNETIC
# CONCEPTS. Exhausted, she sighs and drops her head. Them, she
# looks up; her eyes shifting thoughtfully.:EXT. MELVALD'S GENERAL STORE - MOMENTS LATER:Joyce’s CAR backs out of its spot, then speeds off.:EXT. SCOTT CLARKE’S RESIDNCE - PORCH - LATER:Joyce, holding the TALL STACK OF TEXTBOOKS, rings the
# DOORBELL.:JOYCE:Hello!?:INT. SCOTT CLARKE'S RESIDNCE - WORKSHOP - ON GOING:FROM BEHIND we see a MAN sitting at a work table. He’s
# WEARING A HEADBAND MAGNIFIER.:ECU: The man is using a FINE BRUSH and PAINTING A FIGURINE.:JOYCE (O.S.):Hello?:DOORBELL CHIMES:The man looks up and then over his shoulder.:EXT. SCOTT CLARKE'S RESIDNCE - PORCH - ON GOING:Joyce glances around, then heads back to her car - walking
# past the GARAGE.:JUST THEN, the garage door begins to open. Joyce turns her
# attention there. The door opens all the way, REVEALING MR.
# CLARKE. He flips up the magnifier.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:34.
# 34.:MR. CLARKE:Mrs. Byers?:INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - DAY:Jonathan SNAPS pictures of the RABID RAT running into the
# walls of it’s CAGE on the WASHING MACHINE.:JONATHAN:We’re going to have to keep doing
# this until you stop moving, you
# little shit.:INT. DRISCOLL RESIDENCE - KITCHEN - ON GOING:Nancy stands over an open PHONE BOOK with the PHONE to her
# ear. Mrs. Driscoll is in the kitchen preparing LEMONADE.:NANCY:Hi, yes, this is nancy Wheeler from
# The Hawkins Post. Yeah, I have a
# bit of a weird question for you. I
# was wondering if you guys had
# gotten any recent call about rabid
# rats?:INDISTINCT MALE VOICE RESPONDS.:NANCY (CONT'D)
# No, rabid rats. Rats with rabies?
# Okay, how about just rats in
# general?:The response is in the NEGATIVE.:Okay, thank you.:NANCY (CONT'D):Nancy hangs up. Mrs. Driscoll comes from the kitchen carrying
# a GLASS OF LEMONADE.:MRS. DRISCOLL
# You’re a regular little detective,
# aren’t ya? Lemonade? It’s fresh-
# squeezed.:Sure. Thanks.:NANCY:(reluctantly accepts the :drink):Do you mind if I make just a few
# more calls?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:35.
# 35.:MRS. DRISCOLL
# Not at all! I enjoy the company.:Mrs. Driscoll walks off, then Nancy looks through the
# phonebook. She turns to a page with a LARGE ADVERTISEMENT:
# BLACKBURN’S FARM SUPPLY. “BEST PRICES & LARGEST SELECTION!”:Nancy picks up the phone and dials.:INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - ON GOING:Jonathan continues snapping photos as the rat continues to
# throw itself against the walls of its cage. Jonathan turns
# away to reload his camera at a nearby WORKBENCH.:The SQUEALING suddenly STOPS. Jonathan looks over his
# shoulder. He walks back to the cage. The rat is now WRITHING
# ON THE FLOOR of its cage.:JONATHAN:You all right, little bud?:JUST THEN, Nancy at the bottom of the stairs::NANCY:Jonathan!:Startled, Jonathan turns to Nancy.:I have a lead.:NANCY (CONT'D):JONATHAN:Yeah, okay, but -- I just think
# there’s something really wrong with
# this rat.:NANCY:Yeah, no shit. Come on.:Nancy starts heading back upstairs.:JONATHAN:No, I --:He takes another look at the writhing rat before hastily
# grabbing his camera gear and following her.:Nancy, wait up.:JONATHAN (CONT'D):8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:36.
# 36.:Once he’s gone, the BASEMENT LIGHTS BEGIN TO FLICKER. SORES
# APPEAR on the writhing rat’s body moments before it EXPLODES
# INTO A PILE OF GOO. Then, the pile of goo starts SLIDING
# ACROSS THE CAGE FLOOR and SEEPS through the bars of the cage.:It drifts off the side of the washing machine and onto the
# floor. It begins to MORPH INTO A CREATURE WITH LEGS and moves
# across the basement floor with increasing speed.:EXT. CORNWALLIS ROAD - NIGHT:In the UPSIDE DOWN, RED LIGHNING FLASHES across the dark sky.:BILLY
# I said, what do you want!?:Facing the IDENTICAL VERSION of himself::BILLY #2
# To build. I want you to build.:BILLY:To build what?:BILLY #2:What you see.:BILLY:I don’t understand.:LIGHTNING FLASHES:EXT. CORNWALLIS ROAD - NIGHT:BILLY:I don’t understand.:(looks around):What do you mean? I don’t
# understand!:FLASH CUT TO::FLASH CUT TO::EXT. HAWKINS COMMUNITY POOL - DAY:Billy JERKS AWAKE, sitting on the LIFEGUARD HIGHCHAIR. His
# BLUE EYES appear VIVID. He glances around at the CROWDED
# POOL. He notices his arm HANGING OUT OF THE SHADE of the
# UMBRELLA. The SKIN NEAR HIS ELBOW, DARK RED and SHINY.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:37.
# 37.:Walking along the pool deck, Billy bumps into a MAN causing
# him to drop his COOLER. ICE and CANNED SODA spill out of the
# busted cooler.:POV BILLY: Heather is sitting at a nearby TABLE with FRIENDS.:HEATHER:Billy, are you okay?:Ignoring her, Billy continues on.:INT. HAWKINS COMMUNITY POOL - LOCKER ROOM - MOMENTS LATER:AT A SHOWER STALL, Billy pulls aside the CURTAIN and turns
# the TAP TO COLD. Bracing himself against the wall, he stands
# under the water stream.:He studies his LEFT ARM. A DARK VEIN travels up his skin and
# branches off. He touches it and SEES A FLASH OF THE SHADOW
# MONSTER.:He WRITHES in pain and backs into the corner of the shower
# stall. HIGH PITCHED NOISES causes Billy to cover his ears. He
# YELLS as he CRUMBLES to the floor.:HEATHER (O.C.):Billy?:Billy looks up and sees Heather standing there.:Billy.:HEATHER (CONT'D):Heather crouches down to eye-level - her expression,
# completely calm. In a DISTORDED VOICE::Take me to him.:HEATHER (CONT'D):What?:BILLY:HEATHER:(concerned, normal voice):I said, are you hurt?:Billy stares in disbelief.:HEATHER (CONT'D)
# What’s going on? I heard screaming.
# Should I call an ambulance?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:38.
# 38.:Billy’s stare changes. His face, WITHOUT EMOTION. His FINGERS
# DIG INTO HIS LEG. Heather LEANS BACK fearfully moments before
# Billy LASHES OUT.:INT. STARCOURT MALL - THE GAP (1C) - DAY:MONTAGE: “MATERIAL GIRL” BY MADONNA plays while::- Eleven tries on different clothes in front of a FULL LENGTH
# MIRROR.:INT. STARCOURT MALL - ZALES (2Q) - ON GOING:MONTAGE CONTINUES::Mike, Lucas, Will browsing for pretty shiny things that say
# “I’m sorry.” Mike sees a SMALL GOLDEN TEDDY BEAR behind the
# GLASS COUNTER. Mike gets the attention of the salesman,
# PARKER, early 40s, standing nearby.:MIKE:Excuse me, sir. How much for this
# little teddy bear here?:Parker eyes Mike, then smiles politely.:INT. STARCOURT MALL - (EXT.) ZALES (2Q) - MOMENTS LATER:Lucas, Will and Mike leave the store (heading SOUTH).:LUCAS:Three-hundred? Three-hundred.:MIKE:I should have shoved that little
# teddy bear right up his --:INT. STARCOURT MALL - THE GAP (1C) - ON GOING:MONTAGE CONTINUES::- El tries on DIFFERENT OUTFITS.:- Max trying on DIFFERENT SUNGLASSES; eventually finding ones
# she likes.:INT. STARCOURT MALL - LOVELACE (1E) - ON GOING:MONTAGE CONTINUES::8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:39.
# 39.:The boys are about to enter the LINGERIE STORE but stop dead
# in their tracks when noticing::- SEVERAL WOMEN, 20s and 30s, perusing sexy lingerie.:- Mike gawks at THIGH-HIGH STOCKINGS.:- Lucas stares at a MANNEQUIN in a BRA AND PANTIES.:- Will sees BIKINI BOTTOMS on a MANNEQUIN’S LOWER-HALF.:- The boys backing away from the store, then taking off.:INT. STARCOURT MALL - THE GAP (1C) - ON GOING:MONTAGE CONTINUES::- El has found a COLORFUL ROMPER. She smiles as she checks
# herself out in the mirror.:INT. STARCOURT MALL - (EXT.) THE GAP (1C) - MOMENTS LATER:MONTAGE CONTINUES::- Max and El leave the store. El wearing the ROMPER and Max
# wearing RED FRAMED SUNGLASSES.:- Strutting through the mall, smiling, arm-in-arm.:INT. STARCOURT MALL - PERFUME COUNTER (2G) - ON GOING:MONTAGE CONTINUES::- Mike and Will sniff SAMPLE FRAGRANCES.:- Lucas sprays A BOTTLE into the air and smells it.:LUCAS:Hey, Mike.:Lucas sprays Mike’s face.:INT. STARCOURT MALL - (EXT.) FLASH STUDIO (2M) - ON GOING:MONTAGE CONTINUES::Max and El go into a PHOTO STUDIO.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:40.
# 40.:INT. STARCOURT MALL - FLASH STUDIO (2M) - ON GOING:MONTAGE CONTINUES::Max and El pose in VARIOUS COLORFUL COSTUMES. While the
# FLAMBOYANT PHOTOGRAPHER, TOBY, 30s, SNAPS PICTURES.:TOBY:Wardrobe change! Wardrobe change,
# thank you!:- More cheesy poses in EXTRAVAGANT OUTFITS.:Shake it! Shake it out for me.:TOBY (CONT'D):INT. STARCOURT MALL - KAUFMAN SHOES (2P) - ON GOING:MONTAGE CONTINUES::In the SHOE STORE, Max helps El walk in a PAIR OF HEELS. El
# twists her ankle and falls, CRACKING UP.:THREE GIRLS, 17, INCLUDING STACEY, are looking at a display
# of HEELS. They ROLL THEIR EYES at the immature behavior. Max
# and El just burst into LAUGHTER.:INT. STARCOURT MALL - FOOD COURT (1N - 1Q) - ON GOING:MONTAGE CONTINUES::Near BURGER KING, Max and El peek around a corner at Stacey
# and her friends chatting with a TEEN BOY, 17, OUT FRONT OF
# ORANGE JULIUS. The girls are enjoying a TALL FROTHY ORANGE
# JULIUS BEVERAGE.:El concentrates momentarily, then JERKS HER HEAD UPWARD.:JUST THEN, Stacey’s DRINK EXPLODES, covering her and her
# friends with the beverage.:Max and El run away giddily.:INT. STARCOURT MALL - FOOD COURT (1R - 1S) - ON GOING:SONG CONTINUES as Max and El, running::MAX:See, what did I tell you. There’s
# more to life than stupid boys.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:41.
# 41.:INT. STARCOURT MALL - BENCH (1C) - ON GOING:SONG CONTINUES as Max and El run by, still unaware of the
# boys’ presence.  Sitting on a NEARBY BENCH, with POTTED
# PLANTS BEHIND, Will, Mike and Lucas sit gloomily.:WILL:Can we please play D&D now.:No.:MIKE:No.:LUCAS:INT. SCOOPS AHOY (1D) - BACK ROOM - DAY:SONG ENDS.:Dustin is sitting at the table, controlling the RECORDER. The
# SECRET RUSSIAN COMMUNICATION plays, while Robin paces,
# listening.:ROBIN:Wait, that last part, just one more
# time.:DUSTIN
# (cuing the recorder):Okay.:RECORDING CONTINUES and Robin listens intently. AT THE WORD:
# “DLYNNAYA”::ROBIN
# Okay, that word.:Dustin stops the recorder.:It’s pronounced dly-nna-ya.:ROBIN (CONT'D):Dly-nna-ya.:DUSTIN:ROBIN:Which is spelled --:(pointing to the white :board)
# -- D, D ...:Dustin rushes to the WHITE BOARD.:DUSTIN:D ... D ... The -- the chair! The
# chair-looking thingy!:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:42.
# 42.:ROBIN:Yeah, okay.:Robin jots something down on a NOTEPAD.:INT. SCOOPS AHOY (1D) - ON GOING:Robin slides open the window to the front of the store. Steve
# is serving two CUSTOMERS (Max and El: O.C.).:ROBIN:We’ve got our first sentence.:Steve turns around, holding TWO ICE CREAM CONES.:STEVE:Oh, seriously?:ROBIN
# (Russian accent):The week is long.:STEVE:(disappointed)
# Well that’s thrilling.:ROBIN:I know. But, progress.:She shuts the window. Steve turns his attention back to the
# customers: Max and El.:STEVE:Okay, here you go, you got a
# strawberry and then a vanilla with
# sprinkles, extra whipped cream.:Thanks.:MAX:Thanks.:EL:STEVE:(to El):Wait a second. Are you even allowed
# to be here?:The girls exchange a giddy look then run out leaving Steve
# perplexed.:Okay.:STEVE (CONT'D):8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:43.
# 43.:EXT. STARCOURT MALL - FRONT (L2) - DAY:Max and El burst out the MALL ENTRANCE, enjoying their ICE
# CREAM CONES.:MAX:You wanna trade?:They switch cones. Max and El stop when they HEAR MIKE at the
# BICYCLE RACK nearby.:MIKE:That’s ridiculous. Why can’t I just
# mow Old Man Humphries’ lawn?:MAX:(to El):You’ve gotta be shitting me.:He hasn’t got that much.:Yeah, but --:LUCAS:MIKE:Okay, what if we split it?:MIKE (CONT'D):LUCAS:Split it with what? That doesn’t
# even make sense.:Max and El march over.:Isn’t this a nice surprise.:MAX:Mike drops his bike and points at El.:MIKE
# What are you doing here?:Shopping.:EL:MAX:This is her new style. What do you
# think?:MIKE:What’s wrong with you? You know
# she’s not allowed to be here.:MAX:What is she, your little pet?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:44.
# 44.:EL:Yeah. Am I your pet?:What? No!:MIKE:EL:Then why do you treat me like
# garbage?:MIKE:What?:EL
# You said Nana was sick.:MIKE:She is. She is sick.:(motions to Lucas for
# back up)
# She is sick.:Yeah, sick -- she’s sick.:LUCAS:LUCAS (CONT'D)
# She’s super sick. That’s why we’re
# here, actually.:MIKE:(nervously):Yeah, we’re shopping -- Not for us,
# but for her, for Nana.:For Nana!:LUCAS:MIKE:(to El):Also, we’re here to get a gift for
# you. Just -- we couldn’t find
# anything that suited you. And I
# only have, like, three dollars and
# fifty-cents, so it’s hard.:LUCAS:Super. Hard. It’s expensive.:Nope. Not working.:EL:You. Lie.:Mike looks at El guiltily.:Why do you lie?:EL (CONT'D):8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:45.
# 45.:JUST THEN, the BUS pulls in.:El glares as she steps closer. Mike stands his ground -
# albeit very nervously.:I dump your ass.:EL (CONT'D):Max’s jaw drops as she follows El away leaving the boys
# staring dumbly. :INT. CITY BUS - MOMENTS LATER:El and Max take their seat on the CROWDED bus. They HIGH
# FIVE.:EXT. STARCOURT MALL - BUS STOP (L2) - MOMENTS LATER:The boys watch the bus pull away.:WILL:Now can we play D&D?:LUCAS:No.:Mike stands. Heartbroken.:EXT. TOWN HALL - DAY:Hopper HANDCUFFS a PROTESTER, HENRY, 40s, before leading him
# away to a WAITING POLICE CAR.:HENRY:He raised my property taxes, Jim.
# Forced me off my land.:HOPPER:You can protest all you want,
# Henry, you’ve just gotta go through
# the proper channels first.:AT THE POLICE CAR, Hopper tries to sit Henry in the back seat
# where THREE OTHER PROTESTERS are already sitting handcuffed.:HENRY:Nothing proper about what that man
# did to us! To our town!:Henry relents and get in. Hopper slams the door.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:46.
# 46.:FLO:Special delivery!:FLORENCE arrives carrying a PAPER BAG FROM JC PENNY. She
# holds the bag out for Hopper.:HOPPER
# (grabbing the bag):Ohh, yeah!:Hopper pulls out a sweet-looking HAWAIIAN SHIRT.:FLO
# Is that the right one?:HOPPER:(chuckles):Yeah. Yeah!:Powell, standing nearby, looks on in disbelief.:OFFICER POWELL:That’s a lot of color for you,
# Chief.:HOPPER:(placing the shirt back in :the bag):It’s cuttin’ edge stuff, all right?:Hopper marches off to his TRUCK. Looking over his shoulder
# back at Flo and Powell::It’s cutting edge!:HOPPER (CONT'D):Powell shakes his head.:INT. ENZO’S - NIGHT:An UPSCALE RESTAURANT. A LIVE ENSEMBLE plays “STRING QUINTET
# IN E MAJOR, G. 275: III. MINUETTO” BY LUIGI BOCCHERINI.:Hopper comes in wearing a TAN BLAZER over his new shirt. He
# adjusts his blazer.:INT. ENZO’S - TABLE - MOMENTS LATER:Hopper peruses the DRINK MENU. A SNOBBY WAITER, 30s, is
# taking Hopper’s order.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:47.
# 47.:HOPPER:I’ll start off with a Scotch, you
# can make that a double.:WAITER:Very good, sir.:HOPPER:And I think we’ll have a bottle of
# red, as well.:WAITER:Very good, sir!:HOPPER
# And how’s your chee-an-ti?:WAITER
# Our Chianti is quite good.:Chianti.:HOPPER:WAITER:Medium-bodied, with just a hint of
# cherry.:HOPPER:Great! Women love cherries, huh?
# (closes the menu, hands it :back to the waiter):All right, we’ll have that and two -
# - two glasses, please, one for, uh,
# me, and one for the lady.:WAITER:Ooh, very good sir.:The waiter leaves and Hopper lights a CIGARETTE. He stares
# past the EMPTY SEAT across from him -- at the door. Hopper
# checks his watch. The restaurant is PACKED. Hopper sits alone
# -- waiting.:EXT. SCOTT CLARKE'S RESIDENCE - DRIVEWAY - NIGHT:It’s dark. Joyce’s CAR is parked in front of the garage.:INT. SCOTT CLARKE'S RESIDENCE - WORKSHOP - ON GOING:Scott is wrapping COPPER WIRE around a METAL TOOLBOX.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:48.
# 48.:JOYCE:What is this, again?:MR. CLARKE
# This is a solenoid. It’s a coil
# wrapped around a metallic core, and
# when electricity passes through it -
# -:JOYCE:It creates an electromagnetic
# field.:MR. CLARKE:Exactamundo. Now for the fun part.
# Shall we?:Mr. Clarke flips on a TRANSFORMER.:JOYCE:I don’t see anything.:MR. CLARKE:Nope. You can’t see it, but it’s
# there, I assure you. Our very own
# Clarke-Byers Electromagnetic Field.
# Pretty neato, huh?:JOYCE:(bewildered):Yeah.:MR. CLARKE:And this field affects any charged
# object in its vicinity.:JOYCE:Just like my magnets.:MR. CLARKE:Just like your magnets.:JOYCE:Okay. Why is nothing happening?:MR. CLARKE:Oh, because our field is stable.
# But, if we reduce the current --:He turns a CRANK on the transformer and MAGNETS FALL OFF THE
# METAL TOOLBOX.:JOYCE:How ...:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:49.
# 49.:MR. CLARKE
# The magnetic dipoles tried to
# orient according to the field, but
# since --:JOYCE:No, no, no, I mean, how is this
# happening at my house?:MR. CLARKE:You want my honest opinion? One of
# your kiddos got up in the middle of
# the night, bumped into the fridge,
# and knocked the suckers loose.:JOYCE:And the magnets at Melvald’s?:MR. CLARKE
# Apophenia. (app-oh-fee-nee-ah):JOYCE
# Apo-what-o-whah?:MR. CLARKE
# Apophenia. Uh -- You’re seeing
# patterns that aren’t there.
# Coincidence.:JOYCE:But what if it’s not.:MR. CLARKE:Well --:(turns away thoughtfully)
# Theoretically speaking, I suppose
# some large version of this AC
# transformer could exist. A machine
# of some kind.:JOYCE:A machine?:MR. CLARKE:But, in order to reach your house
# and downtown, gosh, that would take
# billions of volts of electricity
# and cost tens of millions of
# dollars.:JOYCE:But, it is possible?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:50.
# 50.:MR. CLARKE
# We cured polio in fifty-three.
# Landed on the moon in sixty-nine.
# As I tell my students, once you
# open up that curiosity door,
# anything is possible.:INT. STARCOURT MALL - NIGHT:The mall is CLOSED. The FOOD COURT is vacant. Shops’ BARRED
# GATES are down and locked. Except for::INT. STARCOURT MALL - (EXT.) SCOOPS AHOY (1D) - NIGHT:The only shop in the mall whose lights are still on.:INT. SCOOPS AHOY (1D) - BACK ROOM - NIGHT:Robin, Steve and Dustin are making progress.:ROBIN, DUSTIN, STEVE:(reading from the white :board):The week is long. The silver cat
# feeds. When blue meets yellow in
# the west.:INT. STARCOURT MALL - (EXT.) SCOOPS AHOY (1D) - MOMENTS LATER:Steve closes and locks the GATE.:STEVE:I mean, it just, it just can’t be
# right.:ROBIN:It’s right.:Steve joins Robin and Dustin as they walk through the closed
# mall (heading SOUTH exit).:DUSTIN:Honestly, I think it’s great news.:STEVE:How is this great news? I mean, so
# much for being American heroes.
# It’s total nonsense.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:51.
# 51.:DUSTIN
# It’s not nonsense. It’s too
# specific. It’s obviously a code.:STEVE
# What do you mean, a code?:DUSTIN’
# Like a super secret spy code.:STEVE:That’s a total stretch.:ROBIN:I don’t know, is it?:STEVE
# You’re buying into this?:ROBIN:Listen, just for kicks, let’s
# entertain the possibility that it
# is a secret Russian transmission.
# What’d you think they were gonna
# say, fire the warhead at noon?:Exactly.:DUSTIN:ROBIN:And my translation is correct. I
# know that for sure, so, the silver
# cat feeds. Why would anyone talk
# like that unless they were trying
# to mask the meaning of their
# message?:Exactly.:DUSTIN:ROBIN:And why would anyone mask the true
# meaning of their message unless the
# message was somehow sensitive?:Exactly!:DUSTIN:ROBIN:So I guess that confirms your
# suspicion.:DUSTIN:Evil Russians.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:52.
# 52.:ROBIN:I can’t believe I’m about to agree
# with this strange child, but, yeah,
# totally evil Russians.:DUSTIN:So how do we crack it?:ROBIN:Well, I guess we translate the rest
# and hopefully a pattern emerges.:DUSTIN:A pattern. Right, like maybe silver
# cat is a meeting place?:ROBIN:Or a person.:DUSTIN:Or a weapon.:ROBIN:It’s probably gonna take a super
# genius to crack it, but -- where’s
# Steve?:INT. STARCOURT MALL - (EXT.) (1F - 1H) - ON GOING:Steve is standing next to the INDIANA FLYER MECHANICAL HORSE,
# going through his pockets for change.:ROBIN:What are you doing?:STEVE:It’s a quarter. I need -- do you
# have a quarter?:ROBIN:Are you sure you’re tall enough for
# that ride?:STEVE:Quarter!:Robin tosses Steve a quarter and he puts it into a slot on
# the machine. The ride comes to life. The song: “DAISY BELL”
# BY HARRY DACRE plays.:ROBIN:You need help getting up, little
# Stevie?:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:53.
# 53.:STEVE:Shh!:DUSTIN:(chuckles):STEVE:Would you two just shut up and
# listen?:DUSTIN:Holly shit. The music.:Dustin takes off his BACKPACK and kneels down.:The music!:DUSTIN (CONT'D):He takes the RECORDER out of his backpack and presses play.
# The SECRET RUSSIAN COMMUNICATION plays with the SAME SONG
# behind it.:ROBIN:I don’t understand.:DUSTIN:It’s the exact same song on the
# recording.:ROBIN:Maybe they have horses like this in
# Russia.:STEVE:Indiana Flyer? I don’t think so.
# This code, it -- didn’t come from
# Russia.:(looks to Robin):It came from here.:INT. ENZO'S - NIGHT:The STRING QUARTET plays: LA TRAVIATA: ACT I. “LIBIAMO, NE’
# LIETI CALICI”.:INT. ENZO'S - TABLE - ON GOING:Hopper, staring toward A YOUNG COUPLE ENJOYING THEIR DINNER,
# holds a NEARLY EMPTY GLASS OF CHIANTI. His eyes, SUNKIN. He’s
# drunk. He chugs what’s left and bites into a BREADSTICK.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:54.
# 54.:WAITER:Would you like to order your
# entrée, sir?:HOPPER:(slurring)
# You know what, Enzo?:WAITER:My name is not Enzo.:Hopper waves him off, reaching for his WALLET.:HOPPER:I just lost my appetite, all right?:(slaps down cash):Here you go. You can keep the
# change.:Hopper stumbles to his feet, grabs the Chianti bottle.:WAITER:Sir, I’m afraid no alcohol is
# allowed off the premises.:Hopper BLOWS RASPBERRY in the waiter’s face.:HOPPER:I can do anything I want. I’m the
# chief of police.:Hopper takes a SWIG FROM THE BOTTLE as he leaves the
# restaurant.:BY THE BAR, Hopper bumps into a MAN enjoying a DRINK but says
# nothing and just keeps walking. It’s Grigori - his MOTORCYCLE
# HELMET in front of him. He watches Hopper go.:EXT. CORNWALLIS ROAD - NIGHT:Billy’s car SPEEDS DOWN THE ROAD.:EXT. ERIMBORN STEELWORKS - LATER:Billy pulls up to the abandoned factory and parks.:The door SWINGS OPEN and Billy gets out. He moves to the back
# of the car and opens the TRUNK. He peers into it. Heather
# Holloway, BOUND AND UNCONSCIOUS.:FLASHBACK: Inside the locker room at the Hawkins Community
# Pool.:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:HEATHER:Billy, are you okay?:Billy grabs Heather by the throat. He shuts the curtain,
# which she FLAILS AGAINST.:55.
# 55.:BLACK:BEAT:CUT TO::CUT TO::INT. ERIMBORN STEELWORKS - NIGHT:Billy, carrying the unconscious Heather, walks through the
# factory toward the BASEMENT STAIRS.:INT. ERIMBORN STEELWORKS - BASEMENT - MOMENTS LATER:Billy lays her down. DUCT TAPE covers Heather’s mouth. She
# comes to and looks around before noticing Billy staring down
# at her. She squirms desperately, but is unable to break free
# from the ROPES THAT BIND HER HANDS AND ANKLES TOGETHER.:Billy grabs her by the shoulders and leans close to her ear.:BILLY:Don’t be afraid. It’ll be over
# soon. Just stay very still.:Hovering his face close to hers, Billy slowly tears the duct
# tape off of her mouth. Billy gets up. Heather turns her head
# toward a GROWLING SOUND.:A LARGE SLIMY CREATURE emerges from the shadows. GROWLING.:Heather SCREAMS.:As he watches the FLAYING, Billy’s face remains impassive.:CUT TO::BLACK:THE END:8FLiX.com SCREENPLAY DATABASE
# FOR EDUCATIONAL USE ONLY:

# %%
list_text = text2.split(":")

# %%
list_text
# Out:
# ['STRANGER THINGS 3',
#  'EPISODE #302',
#  '"CHAPTER TWO',
#  ' THE MALL RATS"',
#  'by',
#  'The Duffer Brothers',
#  'FINAL PRE-POST DRAFT',
#  '\x0cFloor  plans  are  for  reference  only.  Check  with  Art  Dept.  for \nupdated versions.',
#  'ii.\nii.',
#  '\x0ciii.iii.',
#  '\x0civ.\niv.',
#  'NOTE',
#  ' Scenes in RED take place in the UPSIDE DOWN.',
#  'NOTE',
#  ' Interior Starcourt Mall scenes include SHOP ADDRESS in \nparenthesis (see attached floor plan).*',
#  '* 2M is now FLASH STUDIO (formerly OLAN MILLS).',
#  '\x0cFADE IN',
#  '',
#  'INT. ERIMBORN STEELWORKS - NIGHT',
#  'Picking up where we left off.',
#  'The only light, from the BRIGHT MOON, spills through the \nFILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the \nSTAIRS leading to the basement. It’s QUIET.',
#  'JUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the \nstairwell door, pulling himself up. Then, he BREAKS FREE from \nthe FLESHY TENTACLE which pulled him downstairs only moments \nago.',
#  'EXT. ERIMBORN STEELWORKS - MOMENTS LATER',
#  'Billy sprints out of the abandoned factory, heading to his \nCAMARO.',
#  'Billy speeds away; leaving a trail of dust in his wake.',
#  'EXT. CORNWALLIS ROAD - LATER',
#  'Billy pulls over to a TELEPHONE BOOTH. He dashes frantically \nfrom his car to the BOOTH. He DIALS 9-1-1. On the SECOND \nRING, the FEMALE OPERATOR picks up',
#  '',
#  'OPERATOR (O.S.)\nNine-one-one, what’s your \nemergency?',
#  'FLASHBACK',
#  '',
#  'I/E. ERIMBORN STEELWORKS - NIGHT',
#  'Billy getting pulled into the factory, and down the stairs.',
#  'IN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS \nattack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS \nTO BILLY’S FACE.',
#  'FLASH CUT TO',
#  '',
#  'EXT. CORNWALLIS ROAD - NIGHT',
#  'The LIGHT inside the booth FLICKERS.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c2.\n2.',
#  'OPERATOR (O.S.)',
#  'Is someone there? Hello?',
#  'The LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the \nreceiver and then steps outside the booth.',
#  'He sees something off in the distance. WHITE PARTICLES float \nin the air. Billy steps onto Cornwallis Road. Through THICK \nFOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male, \nfemale, various ages) shuffling forward.',
#  'BILLY',
#  'What do you want?',
#  'He cautiously walks toward the crowd.',
#  'Hey! I said, what do you want?',
#  "BILLY (CONT'D)",
#  'The group continues shuffling toward Billy.',
#  "BILLY (CONT'D)\nI said WHAT -- DO -- YOU -- WANT?",
#  'THUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the \nUPSIDE DOWN. The group halts their march. A LONE FIGURE \nemerges from the silhouetted group and approaches Billy.',
#  'The FIGURE STEPS INTO THE LIGHT. ',
#  'Billy stares into the face of an IDENTICLE VERSION OF \nHIMSELF.',
#  'OPENING CREDITS',
#  'CUT TO',
#  '',
#  'EFFECTS IN',
#  '',
#  'EXT. HOPPER’S CABIN - MORNING',
#  'ELEVEN is pacing on the porch. She leans over the edge, takes \na look round, then turns and storms inside the cabin.',
#  "INT. HOPPER'S CABIN - ON GOING",
#  'El marches in and heads straight for the TELEPHONE ON THE \nWALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.',
#  'HOPPER',
#  'Is everything okay?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c3.\n3.',
#  'EL',
#  'Yes.',
#  'INT. WHEELER RESIDENCE - KITCHEN - MORNING',
#  'KAREN WHEELER is packing LUNCH and SNACKS.',
#  'PHONE RINGS',
#  'Karen answers.',
#  'KAREN',
#  'Hello, this is the Wheelers.\nYeah, just a sec.',
#  'Karen puts her hand over the mouthpiece, then yells',
#  '',
#  'Mike! Phone!',
#  "KAREN (CONT'D)",
#  'INT. WHEELER RESIDENCE - BASEMENT - ON GOING',
#  'Mike is pacing nervously.',
#  'MIKE\n(yells to Karen)',
#  'Okay!',
#  'Mike walks stiffly to the PHONE ON THE WALL. He takes a deep \nbreath before picking up.',
#  "MIKE (CONT'D)",
#  '(into the phone)',
#  'Hello?',
#  "INT. HOPPER'S CABIN - EL’S ROOM - MORNING",
#  'El goes into her room.',
#  'EL',
#  'It’s nine-thirty-two. Where are \nyou?',
#  'She TELEKINETICALLY closes her bedroom door.',
#  'INTERCUT',
#  ' MIKE’S BASEMENT AND EL’S BEDROOM',
#  'MIKE\n(stammers)',
#  'Sorry, I was just about to call. I -\n- um -- can’t see you today.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c4.\n4.',
#  'EL',
#  'What? Why not?',
#  'MIKE',
#  'It’s my Nana. She’s very sick.',
#  'EL',
#  'But Hop said that your Nana was \nokay. That it was a false alarm.',
#  'MIKE',
#  'Yeah -- that’s what we thought it \nwas at first, but then she took a \nreal turn for the worse.',
#  'Oh.',
#  'EL',
#  'MIKE',
#  'Yeah. We think she might -- die.',
#  'INT. WHEELER RESIDENCE - KITCHEN - ON GOING',
#  'Karen’s been listening in.',
#  'KAREN',
#  'What?',
#  'INT. WHEELER RESIDENCE - BASEMENT - ON GOING',
#  'A look of worry flashes across Mike’s face before he covers \nthe mouthpiece and yells upstairs.',
#  'MIKE',
#  'Mom! Get off the phone! How many \ntimes?!',
#  'INT. WHEELER RESIDENCE - KITCHEN - ON GOING',
#  'Karen, still on the phone, but yelling to Mike.',
#  'KAREN',
#  'Did Nana call?',
#  'INT. WHEELER RESIDENCE - BASEMENT - ON GOING',
#  'MIKE',
#  '(yelling in the direction ',
#  'of the kitchen)\n(MORE)\n(MORE)',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  "\x0cMIKE (CONT'D)\nMIKE (CONT'D)\nNo, Mom! Just get -- off - the -- \nphone!",
#  '5.\n5.',
#  'INT. WHEELER RESIDENCE - KITCHEN - ON GOING',
#  'With a distraught expression, Karen SCOFFS, then hangs up.',
#  'INT. WHEELER RESIDENCE - BASEMENT - ON GOING',
#  'Mike takes a deep breath, then',
#  '',
#  'MIKE',
#  '(to El)\nSorry about that.',
#  "INT. HOPPER'S CABIN - EL'S ROOM - ON GOING",
#  'EL',
#  'Was that your mom?',
#  'INTERCUT',
#  ' MIKE’S BASEMENT AND EL’S BEDROOM',
#  'MIKE',
#  'Yeah. She’s so upset, she’s making \nno sense. Because we have to go to \nthe nursing home. To see Nana.',
#  'EL\nYou can come over after?',
#  'MIKE',
#  'No! I mean -- I just think I need \nto be alone today.\n(thinking)\nWith my -- feelings?',
#  'EL',
#  'Do you lie?',
#  'MIKE',
#  '(aghast)',
#  'What?! No. Friends don’t lie.',
#  'Time to end this before the hole gets any deeper.',
#  "MIKE (CONT'D)",
#  '(covers the mouthpiece)',
#  'What, Mom?',
#  'Mike waits for Karen’s “response”. Then',
#  '',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c6.\n6.',
#  "MIKE (CONT'D)",
#  '(to El)',
#  'My mom’s calling me. Better go. \nTalk to you tomorrow. Miss you \nalready. Bye!',
#  'He quickly hangs up.',
#  "INT. HOPPER'S CABIN - EL'S ROOM - ON GOING",
#  'El stares at her receiver in bewilderment.',
#  'INT. WHEELER RESIDENCE - BASEMENT - ON GOING',
#  'Mike leans his forehead against his phone and sighs.',
#  "INT. HOPPER'S CABIN - ON GOING",
#  'El comes out of her room to hang up. Hopper is standing in \nthe kitchen eating a BOWL OF CEREAL.',
#  'HOPPER\nWhat’s going on?',
#  'Without answering, El trudges back to her room and \nTELEKINETICALLY slams the door behind her.',
#  'IN THE KITCHEN, a smile spreads across Hopper’s face. The \nsong',
#  ' “YOU DON’T MESS AROUND WITH JIM” BY JIM CROCE plays.',
#  'EXT. FORESTED ROAD - DAY',
#  'Hopper’s POLICE TRUCK drives by. The SONG CONTINUES, and \nHopper sings along.',
#  'INT. HOPPER’S TRUCK - DAY',
#  'He’s drumming his hands on the wheel and singing along. Yes, \nhe certainly showed that -- that smug sonofabitch, Mike, \nwho’s boss.',
#  'HOPPER',
#  '(singing)',
#  'And they say...\nYou don’t tug on Superman’s cape...\nYou don’t spit into the wind...\nYou don’t pull the mask on...\nThat old Lone Ranger...\nAnd you don’t mess around with Jim.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c7.\n7.',
#  'EXT. MELVALD’S GENERAL STORE - LATER',
#  'Hopper pulls into an empty parking space next to JOYCE’S FORD \nPINTO.',
#  "INT. MELVALD'S GENERAL STORE - MOMENTS LATER",
#  'With a hop in his step, Hopper bursts through the door. JOYCE \nBYERS is at the CASH COUNTER.',
#  'HOPPER\nEmotions have been shared. \nBoundaries have been set. Order -- \nhas been ... restored.',
#  'JOYCE',
#  'Wait, wait, it worked?',
#  'HOPPER',
#  'Uh, this is the first day in six \nlong, excruciating months that they \nwill not be seeing each other. Yes! \nI think it worked! Yes!',
#  'Hopper chuckles and Joyce CLAPS EMPHATICALLY.',
#  "HOPPER (CONT'D)",
#  'No, stop! It’s all you. I’m a \npuppet, you’re the master.',
#  'So you remembered everything?',
#  'JOYCE',
#  'HOPPER',
#  '(laughs)',
#  'Yeah, yeah. I mean I had to \nimprovise a little bit, you know? \nIt turns out, getting to Mike -- \nthat was the key.',
#  'JOYCE\nAnd you didn’t yell at him?',
#  'HOPPER',
#  'I’ll tell you everything over \ndinner. I was thinking, you know, \nEnzo’s, tonight, seven o’clock. \nHey, before you say no, I’d like to \nmake one thing crystal clear. This \nis not a date.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c8.\n8.',
#  'JOYCE',
#  'Wait, a date? You never said \nanything about a date.',
#  'HOPPER',
#  'I know. I didn’t say anything about \na date. I just wanted to clear it \nup in case there was any confusion \non your part.',
#  'JOYCE',
#  'There’s not.',
#  'HOPPER',
#  'Great. It’s just two friends \ngetting together for a nice dinner. \nI mean, we’ve earned it, haven’t \nwe?',
#  'JOYCE',
#  'I can’t be out late.',
#  'HOPPER',
#  'You’ll be home by nine.',
#  'Eight.',
#  'JOYCE',
#  'HOPPER',
#  'Eight-thirty, I’ll pick you up.',
#  'JOYCE',
#  'I’ll meet you there.',
#  'HOPPER',
#  'Seven. Enzo’s. Meeting there. Deal.',
#  'JUST THEN, Hopper’s WALKIE TALKIE comes alive.',
#  'OFFICER POWELL (O.S.)\nHey, Chief, do you copy? Chief!',
#  'He turns and heads for an AISLE while grabbing his walkie \nfrom his belt.',
#  'HOPPER',
#  '(to Powell)',
#  'Yeah, I’m a little busy right now.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0cEXT. TOWN HALL - DAY',
#  'PROTESTERS, female, male, adults, have gathered to protest \nthe Mayor and Starcourt Mall. They’re carrying PLACARDS and \nshouting.',
#  '9.\n9.',
#  'OFFICER POWELL\nYeah, well, I’m busier here. You \nwanna keep your job tomorrow, I \nthink you need to get your ass to \nTown Hall. Now!',
#  "INT. MELVALD'S GENERAL STORE - DAY",
#  'Hopper puts his walkie on his belt.',
#  'HOPPER',
#  'Duty calls.',
#  'While heading for the door, he nearly slips on FALLEN \nMAGNETS. But, without missing a beat',
#  '',
#  'Clean up on aisle five.',
#  "HOPPER (CONT'D)",
#  'JOYCE',
#  'Bye!',
#  'HOPPER\nSee you tonight.',
#  'IN THE AISLE, Joyce crouches down and picks up one of the \nmagnets. She tries to put one back on the DISPLAY, but it \nfalls down. She tries again with DIFFERENT MAGNETS but the \nsame thing happens.',
#  'INT. THE HAWKINS POST - COFFEE ROOM - DAY',
#  'NANCY WHEELER is pouring COFFEE into a MUG absentmindedly \nwhile glancing at the NOTE',
#  ' DORIS DRISCOLL 4819 CORNWALLIS RD \nDISEASE RATS. Then she notices the coffee overflowing.',
#  'NANCY',
#  'Oh, shit, shit, shit.',
#  'INT. THE HAWKINS POST - REPORTERS’ OFFICE - ON GOING',
#  'BRUCE is leaning back in his chair. He notices Nancy.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c10.\n10.',
#  'BRUCE',
#  'Whoopsie-daisy! Careful, there, \nNancy Drew. Careful. Pouring \ncoffee’s a tough gig, girl',
#  'The other REPORTERS in the room, SNICKER.',
#  'INT. THE HAWKINS POST - COFFEE ROOM - ON GOING',
#  'Nancy forces a tight smile then begins the clean up.',
#  'INT. THE HAWKINS POST - TOM HOLLOWAY’S OFFICE - LATER',
#  'TOM HOLLOWAY is at his DESK. Nancy walks in carrying the MUG.',
#  'NANCY',
#  'And here you are, two creams, two \nsugars.',
#  'TOM',
#  'Thanks, sweetheart.',
#  'NANCY',
#  'Of course.',
#  'BEAT',
#  'Tom?',
#  'Hm?',
#  "NANCY (CONT'D)",
#  'TOM',
#  'NANCY',
#  'I really hate to ask this, but do \nyou think one of the other girls \ncould run and grab lunch today?',
#  'They’re needed at their desks.',
#  'TOM',
#  'NANCY',
#  'I know, I just, I really need to go \nto the doctor.',
#  'Nancy leans closer to Tom while he sips his coffee.',
#  "NANCY (CONT'D)\nI’ve been having some -- um, girl \nproblems.",
#  'Tom COUGHS NERVOUSLY before recovering and nodding shyly.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0cINT. THE HAWKINS POST - DARK ROOM - MOMENTS LATER',
#  'Ignoring the ILLUMINATED RED LIGHT, Nancy bursts in. JONATHAN \nBYERS is working.',
#  '11.\n11.',
#  'JONATHAN',
#  'Oh, come on! The light!',
#  'NANCY',
#  'Let’s go!',
#  'EXT. THE HAWKINS POST - MOMENTS LATER',
#  'With a spring in her step, and a renewed sense of self-worth, \nNancy rushes out of the building. Jonathan is not too far \nbehind her carrying BAGS OF PHOTOGRAPHY EQUIPMENT.',
#  'JONATHAN',
#  'Look, I just don’t know if this is \nsuch a good idea anymore.',
#  'NANCY',
#  'Really? Because I feel like this is \nthe best idea I’ve had all summer.',
#  'NEAR JONATHAN’S CAR',
#  'JONATHAN',
#  'Look, all I’m saying is, what harm \nis there in asking?',
#  'NANCY',
#  'The harm in asking is that Tom will \nsay no. We ask for forgiveness, not \npermission. And if the story’s as \ngood as I think it’s gonna be, then \nTom won’t care. In fact, he’ll \nthank us.',
#  'JONATHAN',
#  'Or, the old lady is nuts and the \nstory blows up in our face and Tom \nfires us.',
#  'NANCY',
#  'And then we never have to work in \nthis shithole again.',
#  'They climb into the car.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0cINT. STARCOURT MALL - FOOD COURT - DAY',
#  'MONTAGE OVER THE SONG',
#  ' “GET UP AND GO” BY THE GO GO’S',
#  '12.\n12.',
#  '- PATRONS eating.',
#  '- COUPLES by the FOUNTAIN.',
#  '- WORKERS preparing FOOD.',
#  '- TEENAGERS being teenagers.',
#  'INT. SCOOPS AHOY (1D) - DAY',
#  'ROBIN BUCKLEY glumly hands a FATHER AND DAUGHTER their ICE \nCREAM CONES.',
#  'ROBIN',
#  '(emotionless)',
#  'Have a nice day.',
#  'DAUGHTER\n(enthusiastic)',
#  'Thank you!',
#  'DUSTIN HENDERSON is standing right behind them. He approaches \nRobin at the counter. Dustin’s toothless smile - BEAMING.',
#  'DUSTIN',
#  'ROBIN',
#  '(morosely)',
#  'Hi!',
#  'Hi.',
#  'DUSTIN',
#  'I’m Dustin.',
#  'I’m Robin.',
#  'ROBIN',
#  'DUSTIN',
#  'Please to meet you. Uh, is -- is he \nhere?',
#  'ROBIN',
#  'Is who here?',
#  'STEVE HARRINGTON swings open the door from the back room.',
#  'STEVE',
#  '(excited)',
#  'Henderson!',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c13.\n13.',
#  'Dustin laughs.',
#  'Henderson! He’s back!',
#  "STEVE (CONT'D)",
#  'He makes his way to Dustin.',
#  'DUSTIN\nI’m back! You got the job!',
#  'STEVE',
#  'I got the job!',
#  'Steve PANTOMIMES AND IMITATES A TRUMPET before he and Dustin \ndo a COMPLICATED HANDSHAKE, including a DUEL WITH LIGHTSABERS \nwhere Steve, ultimately, “dies” after being disemboweled. \nThey both LAUGH AND GRIN WIDELY after Steve “spills his \nguts.”',
#  'ROBIN',
#  'How many children are you friends \nwith?',
#  'Steve’s smile fades.',
#  'INT. SCOOPS AHOY (1D) - BOOTH - LATER',
#  'Steve and Dustin are in a BOOTH. Dustin is enjoying the \nBANANA BOAT ICE CREAM.',
#  'STEVE',
#  'No, no. No way. Hotter than Phoebe \nCates?',
#  'DUSTIN',
#  'Brilliant, too. And she doesn’t \neven care that my real pearls are \nstill coming in. She says kissing \nis better without teeth.',
#  'Steve struggles to maintain a neutral expression.',
#  'STEVE',
#  'Wow. Yeah, that’s great. Proud of \nyou, man. That’s kinda romantic. \nJust -- like, wow.',
#  'BEAT',
#  'DUSTIN',
#  'So do you really just get to eat as \nmuch of this as you want?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c14.\n14.',
#  'STEVE',
#  'Yeah. I mean, sure. It’s not really \na good idea for me, though. I gotta \nkeep in shape for the ladies.',
#  'Robin is cleaning and organizing near the counter.',
#  'ROBIN',
#  'Yeah, and how’s that working out \nfor you?',
#  'STEVE',
#  'Ignore her.',
#  'DUSTIN',
#  'Seems cool.',
#  'STEVE',
#  'She’s not. So, where are the other \nknuckleheads?',
#  'DUSTIN\nThey ditched me yesterday.',
#  'No.',
#  'STEVE',
#  'DUSTIN',
#  'My first day back! Can you believe \nthat shit?',
#  'STEVE\nWhoa. Seriously?',
#  'DUSTIN',
#  'I swear to God. Mm. They’re gonna \nregret it, though. Big time. When \nthey don’t get to share in my \nglory.',
#  'STEVE',
#  'Glory? What glory?',
#  'Dustin scoots closer to Steve, and lowers his voice.',
#  'DUSTIN',
#  'So, last night, we’re trying to get \nin contact with Suzie -- and, uh --',
#  '(glances around, covers ',
#  'mouth, whispering)',
#  'I intercepted a secret Russian \ncommunication.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c15.\n15.',
#  'STEVE',
#  'What?',
#  'Dustin looks around, and repeats SOFTLY',
#  '',
#  'DUSTIN',
#  'I intercepted a secret Russian \ncommunication.',
#  'STEVE',
#  'Just speak louder.',
#  'DUSTIN\n(much louder)',
#  'I intercepted a secret Russian \ncommunication!',
#  'PATRONS stop what they’re doing and look.',
#  'STEVE',
#  'Jeez, shh. Yeah, okay that’s what I  \nthought you said.',
#  '(beat)',
#  'What does that mean?',
#  'DUSTIN',
#  'It means, Steve, we could be \nheroes. True American heroes.',
#  'Ah!',
#  'Mm-hmm.',
#  'STEVE',
#  'DUDTIN',
#  'STEVE\nAmerican heroes.',
#  'DUSTIN',
#  'Just think, you could have all the \nladies you want and more.',
#  'More?',
#  'More.',
#  'STEVE',
#  'DUSTIN',
#  'STEVE',
#  'I like more.',
#  'DUSTIN',
#  'Mm-hmm.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c16.\n16.',
#  'STEVE',
#  'What’s the catch?',
#  'DUSTIN',
#  'No catch, I just need your help.',
#  'STEVE',
#  'With what?',
#  'Dustin unzips his BACKPACK and pulls out a RUSSIAN - ENGLISH \nDICTIONARY.',
#  'DUSTIN',
#  'Translation.',
#  'EXT. 4819 CHERRY LANE - DAY',
#  'MAX MAYFIELD SKATEBOARDS out front of her house. She attempts \nan OLLIE but fails. She tries again, nearly falling this \ntime, and sending her board rolling away.',
#  'The board rolls to a stop at El’s feet. She kicks it up into \nher hands.',
#  'EL',
#  '(gives Max the board)',
#  'MAX',
#  '(confused)',
#  'Hi.',
#  'Hi?',
#  'EL',
#  '(shyly)\nCan we talk?',
#  'INT. MAX’S BEDROOM - LATER',
#  'El is sitting on the edge of Max’s BED. Max paces.',
#  'EL',
#  'And then he said he missed me. And \nthen he just hung up.',
#  'MAX',
#  'He’s a piece of shit.',
#  'What?',
#  'EL',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c17.\n17.',
#  'MAX',
#  'Mike doesn’t have jack shit to do \ntoday and his Nana obviously isn’t \nsick. I guarantee you, him and \nLucas are playing Atari right now.',
#  'EL\nBut friends don’t lie.',
#  'MAX',
#  'Yeah, well, boyfriends lie. All. \nThe. Time.',
#  'INT. WHEELER RESIDENCE - BASEMENT - DAY',
#  'Mike is pacing.',
#  'MIKE',
#  'She knows I’m lying. She knows I’m \nlying.',
#  'LUCAS SINCLAIR is sitting in the RECLINER listening intently. \nWILL BYERS is sitting at the GAME TABLE, setting up D&D, not \ninterested in the conversation.',
#  'LUCAS',
#  'I don’t even understand. Why lie?',
#  'MIKE\nHopper. He threatened me.',
#  'LUCAS\nDid he say he’d kill you?',
#  'What? No!',
#  'MIKE',
#  'LUCAS',
#  'So then, what’s the big deal?',
#  'MIKE',
#  'The big deal is, if I don’t do what \nhe says, then he’ll stop me from \nseeing El. Like, permanently. You \ndon’t understand, Lucas. He’s \ncrazy. He’s lost his mind.',
#  'WILL',
#  'Hey, guys, I’m almost set up here.',
#  'MIKE',
#  'I had no choice, Lucas. I really \nhad no choice.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c18.\n18.',
#  'LUCAS',
#  'I just wish you’d consulted me, \nbecause the way you handled this, \nyou’re in deep shit.',
#  "INT. MAX'S BEDROOM - DAY",
#  'MAX',
#  'You’re going to stop calling him. \nYou’re going to ignore his calls. \nAs far as you’re concerned, he \ndoesn’t exist.',
#  'EL',
#  '(intrigued)',
#  'Doesn’t exist?',
#  'MAX',
#  'He treated you like garbage. You’re \ngonna treat him like garbage. Give \nhim a taste of his own medicine.',
#  'EL\nGive him the medicine.',
#  'MAX',
#  'Mm-hmm. And if he doesn’t fix this, \nif he doesn’t explain himself, dump \nhis ass.',
#  'INT. WHEELER RESIDENCE - BASEMENT - DAY',
#  'Mike flops down on the SOFA.',
#  'LUCAS',
#  'I’m not gonna lie, it’s gonna be \nbad. But, you can fix this.',
#  '(rises from his seat)\nIt’s just one little mistake.\nI’ve made hundreds, thousands. Max \nhas dumped me five times! But what \nhave I done? Huh? Have I despaired? \nNo. I’ve marched back into battle, \nand I’ve won her back. Every. \nSingle. Freaking. Time.',
#  'How?',
#  'MIKE',
#  'LUCAS',
#  'I’ll show you. Come on.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c19.\n19.',
#  "INT. MAX'S BEDROOM - DAY",
#  'Come on.',
#  'MAX',
#  'EL',
#  'Where are we going?',
#  'MAX',
#  'To have some fun. There’s more to \nlife than stupid boys, you know.',
#  'INT. WHEELER RESIDENCE - BASEMENT - DAY',
#  'Mike and Lucas run upstairs, forgetting Will.',
#  'WILL',
#  'Wait, guys! I’m still here!',
#  'Will cranes his neck toward the stairs.',
#  'Guys?',
#  "WILL (CONT'D)",
#  'EXT. HAWKINS COMMUNITY POOL - DAY',
#  'DOZENS OF CHILDREN AND ADULTS hang out and play in the water. \nHEATHER HOLLOWAY, on duty sitting in the HIGHCHAIR, blows her \nMARINE WHISTLE, then raises a MEGAPHONE to her mouth.',
#  'HEATHER',
#  'Hey! No dunking, Curtis!',
#  '(beat)\nNo -- dunking.',
#  'Karen and HER MOM FRIENDS lounge, reading ROMANCE NOVELS, \nTRASHY MAGAZINES. MOM #1 (blonde), MOM #2 (LIZ - black hair), \nMOM #3 (Jill - brunette).',
#  'LIZ',
#  'God, even her voice annoys me.',
#  'JILL',
#  'Nails on a chalkboard.',
#  'MOM #1',
#  '(putting lotion on her ',
#  'legs)',
#  'Don’t worry, ladies, ten more \nminutes ‘till showtime. Liz --',
#  '(holds up lotion bottle)',
#  '-- will you get my back?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0cKaren notices Billy rushing through a GRATED DOOR into the \nBUILDING next to the pool.',
#  '20.\n20.',
#  'KAREN',
#  'Hey, Jill, I gotta used the \nrestroom. Will you watch Holly for \nme?',
#  'JILL',
#  'Sure thing, hon.',
#  'KAREN',
#  'Thanks.',
#  'INT. HAWKINS COMMUNITY POOL - MECHANICAL ROOM - ON GOING',
#  'Karen walks in, through the grated door. It’s a NARROW ROOM \nlined with MACHINERY AND ELECTRICAL PANELS. She rounds a \ncorner into the next room',
#  'INT. HAWKINS COMMUNITY POOL - STORAGE ROOM - ON GOING',
#  'SHELVES LINE THE WALLS. CHEMICALS and HARDLY-USED POOL \nSUPPLIES fill the shelves. Karen walks in. Billy, looking \nthrough the chemical bottles, has his back turned to the \ndoor.',
#  'KAREN\n(concerned)',
#  'Billy?',
#  'Billy sets down a CHEMICAL BOTTLE on the shelf, but does not \nturn to face Karen.',
#  "KAREN (CONT'D)\nI understand if you’re angry with \nme.",
#  'Billy does not respond.',
#  'I wanted to explain --',
#  "KAREN (CONT'D)",
#  '(takes two steps closer)\n-- why I didn’t come last night. \nIt’s not you, it’s just -- I have a \nfamily.',
#  'SWEAT on Billy’s face glistens in the poorly-lit room. \nKaren’s VOICE STARTS TO ECHO. We can HEAR BILLY’S HEARTBEAT \nPOUNDING.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c21.\n21.',
#  "KAREN (CONT'D)\nAnd I can’t do anything that will \nhurt them. You can understand that, \nright? But I shouldn’t have said \nthat --",
#  'Billy TURNS QUICKLY, THEN SLAMS KAREN’S HEAD INTO A SHELF.',
#  'BLACK',
#  'BEAT',
#  'Karen’s VOICE ECHOES',
#  '',
#  'KAREN (O.S.)',
#  'Billy?',
#  'CUT TO',
#  '',
#  'CUT TO',
#  '',
#  'INT. HAWKINS COMMUNITY POOL - STORAGE ROOM - DAY',
#  'Karen is standing behind Billy as if nothing happened.',
#  'KAREN',
#  'Billy ... please, will you talk to \nme?',
#  'Billy turns to face her. Karen is slightly taken aback by his \nappearance.',
#  'BILLY\nStay away from me, Karen.',
#  'He marches past Karen.',
#  'EXT. HAWKINS COMMUNITY POOL - DAY',
#  'INTERCUT',
#  ' BILLY’S POV & HANDHELD FOLLOW',
#  'POV BILLY',
#  ' Walking through the grated door.',
#  'Billy stumbles out. He looks up, holding a hand up against \nthe blazing sun.',
#  'POV BILLY',
#  ' BLURRED, OVER-EXPOSED. Scans the pool and \nsurroundings. Heather struts past him.',
#  'HEATHER',
#  'Looking good, Billy.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c22.\n22.',
#  'Billy stares at her confusedly, then passes Karen’s friends.',
#  'POV BILLY',
#  ' Karen’s friends, flirty smile, then in UNISON',
#  '',
#  'KAREN’S FRIENDS',
#  'Afternoon, Billy.',
#  'Billy stares at them confusedly.',
#  'EXT. HAWKINS COMMUNITY POOL - MOMENTS LATER',
#  'AT THE HIGHCHAIR, Billy struggles to climb up but manages to \nget himself seated. He’s pale, clammy. He LOOKS UP. The \nbright sun PULSES. He’s exhausted. His PUPILS',
#  ' FULLY \nDIALATED.',
#  'ECU',
#  ' INTENSLY GLOWING SUN',
#  'DISSOLVE TO',
#  '',
#  'INT. SCOOPS AHOY - DAY',
#  'ECU',
#  ' OVERHEAD; TUB OF ICE CREAM. MINT CHOCOLATE-CHIP. Robin’s \nHAND, holding a small SAMPLE SPOON, scoops.',
#  'Robin gives it to ERICA SINCLAIR, who, with her THREE FRIENDS \nstanding close behind, accepts the free sample. She tastes \nit.',
#  'ERICA',
#  'Can I try the peppermint stick?',
#  'ROBIN',
#  'Haven’t you already tried the \npeppermint stick?',
#  'ERICA',
#  '(annoyed)',
#  'Yes, and I’d like to try it again.',
#  'Robin rolls her eyes.',
#  'ROBIN',
#  '(calling out)',
#  'Steve!',
#  'INT. SCOOPS AHOY - BACK ROOM - DAY',
#  'Steve, eating a BANANA, is pacing. Dustin is sitting at a \nTABLE. On the table',
#  ' RUSSIAN - ENGLISH DICTIONARY and a \nMICROCASSETTE RECORDER. ',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0cA recording Dustin made of the SECRET RUSSIAN COMMUNICATION \nplays. In the background of the recording, the instrumental \nsong',
#  ' “DAISY BELL” BY HARRY DACRE plays.',
#  '23.\n23.',
#  'DUSTIN\n(turns off recorder)',
#  'So, what do you think?',
#  'STEVE',
#  'It sounded familiar.',
#  'What?',
#  'DUSTIN',
#  'STEVE',
#  'The music. The music right there at \nthe end.',
#  'DUSTIN',
#  'Why are you listening to the music, \nSteve? Listen to the Russian! We’re \ntranslating Russian!',
#  'STEVE',
#  'I’m trying to listen to the \nRussian, but there’s music playing -\n-',
#  'Robin bursts in.',
#  'ROBIN',
#  'All right, babysitting time is \nover. You need to get in there.',
#  'Robin instantly turns her attention to the WALL MOUNTED WHITE \nBOARD. It no longer shows Steve’s “YOU SUCK” ratio. Instead, \nthe RUSSIAN ALPHABET and its ENGLISH EQUIVALENT.',
#  "ROBIN (CONT'D)\nHey, my board! That was important \ndata, shitbirds.",
#  'DUSTIN',
#  'I guarantee you, what we’re doing \nis way more important than your \ndata.',
#  'ROBIN',
#  'Yeah? And how do you know these \nRussians are up to no good, \nanyways?',
#  'Dustin turns to Steve in shock, and without a hint of irony',
#  '',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c24.\n24.',
#  'DUSTIN\nHow does she know about the \nRussians?',
#  'STEVE',
#  '(mouth full of banana)',
#  'I don’t know.',
#  'DUSTIN',
#  'You told her about the \nRussians.',
#  'It wasn’t me.',
#  "STEVE (CONT'D)",
#  'ROBIN',
#  'Hello, I can hear you.',
#  'Steve and Dustin regard Robin.',
#  "ROBIN (CONT'D)\nActually, I can hear everything. \nYou are both extremely loud. You \nthink you have evil Russians \nplotting against our country, on \ntape, and you’re trying to \ntranslate, but haven’t figured out \na word because you didn’t realize \nRussians use an entirely different \nalphabet than we do. Sound about \nright?",
#  'She reaches for the recorder, but Steve snaps it away.',
#  'STEVE',
#  'Whoa, whoa, what do you think \nyou’re doing?',
#  'ROBIN\nI wanna hear it.',
#  'Why?',
#  'STEVE',
#  'Why?',
#  'DUSTIN',
#  'ROBIN',
#  '‘Cause maybe I can help. I’m fluent \nin four languages, you know.',
#  'Russian?',
#  'DUSTIN',
#  'ROBIN',
#  'Ou-yay are-yay umb-day.',
#  'Steve and Dustin are impressed!',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c25.\n25.',
#  'Oh-ho-ho!',
#  'STEVE',
#  'Holly shit!',
#  'DUSTIN',
#  'ROBIN\nThat was Pig Latin, dingus.',
#  'Steve smacks Dustin with the banana peel.',
#  'Idiot.',
#  'STEVE',
#  'ROBIN',
#  'But I can speak Spanish and French \nand Italian, and I’ve been in band \nfor twelve years. My ears are \nlittle geniuses, trust me.',
#  'Steve is skeptical.',
#  "ROBIN (CONT'D)\nCome on, it’s your turn to sling \nice cream, my turn to translate. I \ndon’t even want credit, I’m just \nbored.",
#  'The SERVICE BELL at the counter rings.',
#  'Steve and Dustin glance at each other resignedly. Then, Steve \ntrades the recorder for Robin’s ICE CREAM SCOOP.',
#  'EXT. 4819 CORNWALLIS RD. - DRISCOLL RESIDENCE - DAY',
#  'Jonathan’s car pulls in to the driveway and past a MAILBOX \nthat reads',
#  ' DRISCOLL.',
#  'EXT. DRISCOLL RESIDENCE - PORCH - MOMENTS LATER',
#  'Nancy knocks on the door, Jonathan standing beside her. DORIS \nDRISCOLL, 80s, answers the door.',
#  'MRS. DRISCOLL',
#  'Yes?',
#  'Mrs. Driscoll?',
#  'NANCY',
#  'Yes?',
#  'MRS. DRISCOLL',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c26.\n26.',
#  'NANCY',
#  'Hi, I’m Nancy? Nancy Wheeler, we \nspoke briefly on the phone last \nnight.',
#  'JONATHAN\nWe’re from The Hawkins Post.',
#  'MRS. DRISCOLL\nOh! Oh, yes! Oh my goodness. Oh. \nYou look too young for reporters.',
#  'JONATHAN\nWe get that a lot.',
#  'MRS. DRISCOLL',
#  '(chuckles)',
#  'Follow me.',
#  'INT. DRISCOLL RESIDENCE - ON GOING',
#  'Mrs. Driscoll leads Nancy and Jonathan through the house and \ntoward the basement stairs.',
#  'NANCY',
#  'Lovely. Do you live here all alone?',
#  'Jonathan is carrying BAGS OF PHOTOGRAPHY EQUIPMENT and Nancy \nis carrying her NOTEBOOK.',
#  'MRS. DRISCOLL\nYes. Jack, my husband, he passed \naway -- what is it now -- ten years \nago.',
#  'NANCY',
#  'Oh, um, I’m so sorry.',
#  'MRS. DRISCOLL',
#  'Oh, don’t be. I kinda like the \nquiet.',
#  'They’re now standing at the DOOR LEADING TO THE BASEMENT.',
#  'At least, I did.',
#  "MRS. DRISCOLL (CONT'D)",
#  'Mrs. Driscoll opens the door.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c27.\n27.',
#  'INT. DRISCOLL RESIDENCE - BASEMENT - ON GOING',
#  'MRS. DRISCOLL',
#  'This way.',
#  'She starts down the stairs. Jonathan and Nancy peer down \nafter her and exchange an uneasy look before following her \ndown.',
#  'AT THE BOTTOM of the stairs, Mrs. Driscoll turns on the \nlight.',
#  'It’s right over there.',
#  "MRS. DRISCOLL (CONT'D)",
#  'She points to the other side of the basement. Nancy and \nJonathan venture ahead. Nancy crouches down in front of \nPARTIALLY EMPTY BAGS OF FERTILIZER WITH HOLES IN THEM. She \nlifts one up.',
#  "MRS. DRISCOLL (CONT'D)",
#  'You see those little teeth marks, \ndon’t ya?',
#  'Jonathan SNAPS a photo and Nancy locks eyes with him.',
#  'NANCY',
#  'And, these bags, you’re sure they \nwere full before?',
#  'MRS. DRISCOLL\nI’m old, honey, not senile. Bought \nthem over at Blackburn’s Supplies \njust last Tuesday. Now you tell me, \nwhy would rats wanna eat a poor old \nwoman’s fertilizer?',
#  'NANCY',
#  'Are you sure they did?',
#  'Mrs. Driscoll is slightly offended by the question.',
#  "NANCY (CONT'D)\nMaybe they just gnawed the bag? I \nmean, eating fertilizer seems --",
#  'MRS. DRISCOLL\nCrazy. Believe me, I know, honey. \nBut -- something’s not right with \nthese rats.',
#  'NANCY',
#  'What does that mean, exactly ... \nnot right?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c28.\n28.',
#  'MRS. DRISCOLL\nRabies, my guess. That’s when I \nsaid to myself, Doris, you gotta \ncall the paper. Because if those \ndiseased rats are runnin’ loose, \nthe people, the oughta know. \nWouldn’t you agree?',
#  'Just then, a CRASHING SOUND from the other room startles \nNancy and Jonathan.',
#  "MRS. DRISCOLL (CONT'D)",
#  '(excited)',
#  'Oh, yes, I forgot to mention! Come \non over here.',
#  'INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - ON GOING',
#  'Mrs. Driscoll rounds a corner, followed by Nancy and \nJonathan. Mrs. Driscoll proudly proclaims',
#  '',
#  'MRS. DRISCOLL',
#  'I caught one of the little \nbastards.',
#  'ON TOP OF A WASHING MACHINE, A FLORAL SHEET covers a \nRECTANGULAR OBJECT which shakes violently.',
#  'SQUEALING. SNARLING. BANGING.',
#  'EXT. TOWN HALL - DAY',
#  'CROWDS OF PROTESTERS are shouting.',
#  'PROTESTERS',
#  'Kline’s a swine! Kline’s a swine! \nKline’s a swine!',
#  'INT. TOWN HALL - HALLWAY - DAY',
#  'CAMERA FOLLOWS BEHIND a STRAPPING MAN CARRYING A MOTORCYCLE \nHELMET (Grigori - no face is shown) heading for the FRONT \nDOORS. He passes by Hopper sitting in a CHAIR, where the \nCAMERA HOLDS. Hopper eyeballs (Grigori) momentarily. Hopper \nhas a LIT CIGARETTE hanging from his lips.',
#  'CANDACE',
#  'Jim? Mayor Kline is ready for you.',
#  'CANDACE, late 20s, is MAYOR KLINE’s SECRETARY.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c29.\n29.',
#  'HOPPER',
#  '(unenthusiastic)',
#  'Great.',
#  'He butts his cigarette out in an ASHTRAY.',
#  'INT. KLINE’S OFFICE - MOMENTS LATER',
#  'MAYOR LARRY KLINE, 50s, the wealthy (some say corrupt), \nsmarmy politician responsible for building Starcourt Mall, is \nsitting behind his DESK reading the latest edition of THE \nHAWKINS POST. Candace leads Hopper in.',
#  'KLINE',
#  'Jim!',
#  'He warmly greets Hopper at the door.',
#  'Thanks for coming by.',
#  "KLINE (CONT'D)",
#  'HOPPER',
#  'I’m not doing it, Larry.',
#  'KLINE',
#  '(laughs)',
#  'Calm down, now. You don’t even know \nwhat I want.',
#  'Kline goes back to his desk.',
#  'HOPPER',
#  'You don’t like your fan club, you \nwant me to shut ‘em down. Sound \nabout right?',
#  'KLINE',
#  '(laughs)',
#  'When did you get so serious? Take a \nseat.',
#  'PROTESTERS CAN BE HEARD YELLING. Hopper sits in the chair \nopposite the MAYOR’S DESK.',
#  "KLINE (CONT'D)\nMy fan club, as you call them, no, \nyou know why they’re out there, \ndon’t ya?",
#  'HOPPER\nThey’re not actually fans?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c30.\n30.',
#  'KLINE',
#  'They lost their jobs to the mall \nand blame me for helping make that \nhappen. Now, you go ask anyone else \nin this town -- they all love the \nmall. It helped our economy grow, \nbrought in new jobs, and just some \nincredible new stores.',
#  '(reaching for a fresh ',
#  'CUBAN CIGAR)',
#  'Which is why they all stopped \nshopping at their, uh, mom-and-\npops. Now, that’s not me, Jim.\n(uses the CIGAR CUTTER)\nThat’s just good old fashioned \nAmerican capitalism.',
#  'HOPPER',
#  'Well, Larry, I think that they’re \njust exercising their good old \nfashioned American right to \nprotest.',
#  'Hopper stands and heads for the door. Kline is preparing to \nlight his cigar.',
#  'KLINE',
#  'I agree. If they had a permit. Now \ncorrect me if I’m wrong here, Jim, \nbut I don’t believe they secured a \npermit from your office. Did they?',
#  'HOPPER',
#  'Not that I’m aware of.',
#  'KLINE',
#  'Then I do believe it’s within my \nright to get rid of them.',
#  '(lights cigar)',
#  'HOPPER',
#  'Larry, I’m not a politics guy, but \nI think if you force those people \nout of here without provocation, I \ndon’t think that’s a good look for \nyour re-election campaign.',
#  'Kline walks to the window overlooking the protesters. He \npeers out. An instrumental version of “AMERICA THE BEAUTIFUL” \n(ironically) plays SOFTLY in the BACKGROUND.',
#  'KLINE',
#  'You know what’s in four days, Jim?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c31.\n31.',
#  'HOPPER\nIndependence Day?',
#  'Kline turns and walks over to Hopper.',
#  'KLINE',
#  'That’s right. And I’m gonna throw \nthis town the biggest bash it’s \never seen.',
#  '(now face to face)',
#  'Fireworks, music, activities, you \nname it. I’m gonna pull out all the \nstops. You know why? ‘Cause at the \nend of the day, that’s all the \nvoters will remember. But I can’t \nthink, much less plan, with all \nthat racket going on out there.',
#  '(opens the door for ',
#  'Hopper)',
#  'So, if you don’t mind, please, just \ndo your job. Flash your little gold \nbadge and get rid of them.',
#  'As the SONG CRESCENDOS, Kline flashes a bright smile, pats \nHopper on the arm, and sticks the cigar between his teeth.',
#  'EXT. STARCOURT MALL - BUS STOP (L2) - DAY',
#  'MALL PATRONS get off a BUS. Including El and Max.',
#  'MAX\nSo, what do you think?',
#  'El gazes worriedly.',
#  'Hey, what’s wrong?',
#  "MAX (CONT'D)",
#  'EL',
#  'Too many people. Against the rules.',
#  'MAX',
#  'Seriously? You have superpowers. \nWhat’s the worst that could happen?',
#  'INT. STARCOURT MALL - FOOD COURT - MOMENTS LATER',
#  'A SWEEPING SHOT of the ATRIUM settles on Max and El.',
#  'MAX',
#  'So, what should we do first?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c32.\n32.',
#  'El looks at Max blankly.',
#  "MAX (CONT'D)",
#  'You’ve never been shopping before, \nhave you?',
#  'El shakes her head.',
#  "MAX (CONT'D)",
#  'Well, then I guess we’re just gonna \nhave to try everything. Come on.',
#  'Max takes El by the hand and they run in to THE GAP.',
#  'INT. STARCOURT MALL - NEAR THE GAP (1B) - ON GOING',
#  'AT THAT MOMENT, Mike, Lucas and Will walk past, neither \nnotice the other.',
#  'MIKE',
#  'I just -- I don’t understand what \nwe’re looking for.',
#  'LUCAS',
#  'Something pretty and shiny that \nsays, I’m sorry.',
#  'MIKE',
#  'What, just something that literally \nsays I’m sorry?',
#  'LUCAS',
#  '(exasperated)',
#  'No!',
#  'INT. THE GAP (1B) - LATER',
#  'Max smiles as she trails behind El who peruses racks of \nclothes. Her mouth agape, El stares up at an OUTFIT DISPLAY.',
#  'MAX\nYou like that?',
#  'EL',
#  'How do I know -- what I like?',
#  'MAX',
#  'You just try things on. Until you \nfind something that feels like you.',
#  'EL',
#  'Like me?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c33.\n33.',
#  'MAX',
#  'Yeah. Not Hopper. Not Mike. You.',
#  "EXT. MELVALD'S GENERAL STORE - LATER THAT DAY",
#  'It’s quiet. A lone CAR drives past.',
#  "INT. MELVALD'S GENERAL STORE - DAY",
#  'Joyce, sitting at the CASH COUNTER, studies an open TEXTBOOK. \nStacked around her',
#  ' SEVERAL TEXTBOOKS ON ELECTROMAGNETIC \nCONCEPTS. Exhausted, she sighs and drops her head. Them, she \nlooks up; her eyes shifting thoughtfully.',
#  "EXT. MELVALD'S GENERAL STORE - MOMENTS LATER",
#  'Joyce’s CAR backs out of its spot, then speeds off.',
#  'EXT. SCOTT CLARKE’S RESIDNCE - PORCH - LATER',
#  'Joyce, holding the TALL STACK OF TEXTBOOKS, rings the \nDOORBELL.',
#  'JOYCE',
#  'Hello!?',
#  "INT. SCOTT CLARKE'S RESIDNCE - WORKSHOP - ON GOING",
#  'FROM BEHIND we see a MAN sitting at a work table. He’s \nWEARING A HEADBAND MAGNIFIER.',
#  'ECU',
#  ' The man is using a FINE BRUSH and PAINTING A FIGURINE.',
#  'JOYCE (O.S.)',
#  'Hello?',
#  'DOORBELL CHIMES',
#  'The man looks up and then over his shoulder.',
#  "EXT. SCOTT CLARKE'S RESIDNCE - PORCH - ON GOING",
#  'Joyce glances around, then heads back to her car - walking \npast the GARAGE.',
#  'JUST THEN, the garage door begins to open. Joyce turns her \nattention there. The door opens all the way, REVEALING MR. \nCLARKE. He flips up the magnifier.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c34.\n34.',
#  'MR. CLARKE',
#  'Mrs. Byers?',
#  'INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - DAY',
#  'Jonathan SNAPS pictures of the RABID RAT running into the \nwalls of it’s CAGE on the WASHING MACHINE.',
#  'JONATHAN',
#  'We’re going to have to keep doing \nthis until you stop moving, you \nlittle shit.',
#  'INT. DRISCOLL RESIDENCE - KITCHEN - ON GOING',
#  'Nancy stands over an open PHONE BOOK with the PHONE to her \near. Mrs. Driscoll is in the kitchen preparing LEMONADE.',
#  'NANCY',
#  'Hi, yes, this is nancy Wheeler from \nThe Hawkins Post. Yeah, I have a \nbit of a weird question for you. I \nwas wondering if you guys had \ngotten any recent call about rabid \nrats?',
#  'INDISTINCT MALE VOICE RESPONDS.',
#  "NANCY (CONT'D)\nNo, rabid rats. Rats with rabies? \nOkay, how about just rats in \ngeneral?",
#  'The response is in the NEGATIVE.',
#  'Okay, thank you.',
#  "NANCY (CONT'D)",
#  'Nancy hangs up. Mrs. Driscoll comes from the kitchen carrying \na GLASS OF LEMONADE.',
#  'MRS. DRISCOLL\nYou’re a regular little detective, \naren’t ya? Lemonade? It’s fresh-\nsqueezed.',
#  'Sure. Thanks.',
#  'NANCY',
#  '(reluctantly accepts the ',
#  'drink)',
#  'Do you mind if I make just a few \nmore calls?',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c35.\n35.',
#  'MRS. DRISCOLL\nNot at all! I enjoy the company.',
#  'Mrs. Driscoll walks off, then Nancy looks through the \nphonebook. She turns to a page with a LARGE ADVERTISEMENT',
#  ' \nBLACKBURN’S FARM SUPPLY. “BEST PRICES & LARGEST SELECTION!”',
#  'Nancy picks up the phone and dials.',
#  'INT. DRISCOLL RESIDENCE - BASEMENT - OTHER ROOM - ON GOING',
#  'Jonathan continues snapping photos as the rat continues to \nthrow itself against the walls of its cage. Jonathan turns \naway to reload his camera at a nearby WORKBENCH.',
#  'The SQUEALING suddenly STOPS. Jonathan looks over his \nshoulder. He walks back to the cage. The rat is now WRITHING \nON THE FLOOR of its cage.',
#  'JONATHAN',
#  'You all right, little bud?',
#  'JUST THEN, Nancy at the bottom of the stairs',
#  '',
#  'NANCY',
#  'Jonathan!',
#  'Startled, Jonathan turns to Nancy.',
#  'I have a lead.',
#  "NANCY (CONT'D)",
#  'JONATHAN',
#  'Yeah, okay, but -- I just think \nthere’s something really wrong with \nthis rat.',
#  'NANCY',
#  'Yeah, no shit. Come on.',
#  'Nancy starts heading back upstairs.',
#  'JONATHAN',
#  'No, I --',
#  'He takes another look at the writhing rat before hastily \ngrabbing his camera gear and following her.',
#  'Nancy, wait up.',
#  "JONATHAN (CONT'D)",
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c36.\n36.',
#  'Once he’s gone, the BASEMENT LIGHTS BEGIN TO FLICKER. SORES \nAPPEAR on the writhing rat’s body moments before it EXPLODES \nINTO A PILE OF GOO. Then, the pile of goo starts SLIDING \nACROSS THE CAGE FLOOR and SEEPS through the bars of the cage.',
#  'It drifts off the side of the washing machine and onto the \nfloor. It begins to MORPH INTO A CREATURE WITH LEGS and moves \nacross the basement floor with increasing speed.',
#  'EXT. CORNWALLIS ROAD - NIGHT',
#  'In the UPSIDE DOWN, RED LIGHNING FLASHES across the dark sky.',
#  'BILLY\nI said, what do you want!?',
#  'Facing the IDENTICAL VERSION of himself',
#  '',
#  'BILLY #2\nTo build. I want you to build.',
#  'BILLY',
#  'To build what?',
#  'BILLY #2',
#  'What you see.',
#  'BILLY',
#  'I don’t understand.',
#  'LIGHTNING FLASHES',
#  'EXT. CORNWALLIS ROAD - NIGHT',
#  'BILLY',
#  'I don’t understand.',
#  '(looks around)',
#  'What do you mean? I don’t \nunderstand!',
#  'FLASH CUT TO',
#  '',
#  'FLASH CUT TO',
#  '',
#  'EXT. HAWKINS COMMUNITY POOL - DAY',
#  'Billy JERKS AWAKE, sitting on the LIFEGUARD HIGHCHAIR. His \nBLUE EYES appear VIVID. He glances around at the CROWDED \nPOOL. He notices his arm HANGING OUT OF THE SHADE of the \nUMBRELLA. The SKIN NEAR HIS ELBOW, DARK RED and SHINY.',
#  '8FLiX.com SCREENPLAY DATABASE \nFOR EDUCATIONAL USE ONLY',
#  '\x0c37.\n37.',
#  'Walking along the pool deck, Billy bumps into a MAN causing \nhim to drop his COOLER. ICE and CANNED SODA spill out of the \nbusted cooler.',
#  'POV BILLY',
#  ' Heather is sitting at a nearby TABLE with FRIENDS.',
#  'HEATHER',
#  'Billy, are you okay?',
#  'Ignoring her, Billy continues on.',
#  'INT. HAWKINS COMMUNITY POOL - LOCKER ROOM - MOMENTS LATER',
#  ...]

# %%
text_lines=[]
for item in list_text:
    if "\n" in item:
        ed = item.split("\n")
        for items in ed:
            text_lines.append(items)
    else:
        text_lines.append(item)

# %%
#print(text_lines)

# %%
"MR. CLARKECONT (CINT)".isupper()
# Out:
# True

# %%
import re

# %%
newsubelement = []
random=[]
textToCheck = ["NOTE","8FLiX.com","FOR EDUCATIONAL","EXT.","INT.","INTERCUT","FADE IN",
               "CUT TO","EFFECTS IN","FLASHBACK","I/E.","EPISODE #","The Duffer Brothers", 
               "FINAL PRE-POST DRAFT","*","floor plan","FLASH STUDIO","\x0c"]
for el in text_lines:
    #newsubstrip = re.sub(r'\([^()]*\)',":", el)
    #newsubstrip = newsub.strip().replace("\n"," ")
    #newsubstrip = el
    #if newsubstrip !="8FLiX.com SCREENPLAY DATABASE ":
        #FOR EDUCATIONAL USE ONLY":
    if len(el)>=1:
        if any(chartest in el for chartest in textToCheck):
            random.append(el)
        else:
            #newsubelement.append(newsubstrip.replace("\\s+"," "))
            newsubelement.append(el)
        #if newsubstrip.startswith("-"):
        #    pass
        #if "NOTE" in newsubstrip or "8FLiX.com" in newsubstrip \
        #    or "FOR EDUCATIONAL USE" in newsubstrip \ 
         #   or "EXT." in newsubstrip or "INT." in newsubstrip \
          #  or "INTERCUT" in newsubstrip or "FADE IN" in newsubstrip \
         #   or "CUT TO" in newsubstrip or "EFFECTS IN" in newsubstrip \
          #  or "FLASHBACK" in newsubstrip or "I/E." in newsubstrip \
          #  or "EPISODE #" in newsubstrip or "The Duffer Brothers" in newsubstrip \
          #  or "FINAL PRE-POST DRAFT" in newsubstrip or "*" in newsubstrip \
          #  or "floor plan" in newsubstrip \
          #  or "FLASH STUDIO" in newsubstrip or "\x0c" in newsubstrip:
          #  random.append(newsubstrip)
    #else:
    #        #newsubelement.append(newsubstrip.replace("\\s+"," "))
    #    newsubelement.append(newsubstrip)

# %%
print(newsubelement)
# Out:
# ['STRANGER THINGS 3', '"CHAPTER TWO', ' THE MALL RATS"', 'by', 'updated versions.', 'ii.', 'ii.', 'iv.', ' Scenes in RED take place in the UPSIDE DOWN.', ' Interior Starcourt Mall scenes include SHOP ADDRESS in ', 'Picking up where we left off.', 'The only light, from the BRIGHT MOON, spills through the ', 'FILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the ', 'STAIRS leading to the basement. It’s QUIET.', 'JUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the ', 'stairwell door, pulling himself up. Then, he BREAKS FREE from ', 'the FLESHY TENTACLE which pulled him downstairs only moments ', 'ago.', 'Billy sprints out of the abandoned factory, heading to his ', 'CAMARO.', 'Billy speeds away; leaving a trail of dust in his wake.', 'Billy pulls over to a TELEPHONE BOOTH. He dashes frantically ', 'from his car to the BOOTH. He DIALS 9-1-1. On the SECOND ', 'RING, the FEMALE OPERATOR picks up', 'OPERATOR (O.S.)', 'Nine-one-one, what’s your ', 'emergency?', 'Billy getting pulled into the factory, and down the stairs.', 'IN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS ', 'attack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS ', 'TO BILLY’S FACE.', 'The LIGHT inside the booth FLICKERS.', '2.', 'OPERATOR (O.S.)', 'Is someone there? Hello?', 'The LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the ', 'receiver and then steps outside the booth.', 'He sees something off in the distance. WHITE PARTICLES float ', 'in the air. Billy steps onto Cornwallis Road. Through THICK ', 'FOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male, ', 'female, various ages) shuffling forward.', 'BILLY', 'What do you want?', 'He cautiously walks toward the crowd.', 'Hey! I said, what do you want?', "BILLY (CONT'D)", 'The group continues shuffling toward Billy.', "BILLY (CONT'D)", 'I said WHAT -- DO -- YOU -- WANT?', 'THUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the ', 'UPSIDE DOWN. The group halts their march. A LONE FIGURE ', 'emerges from the silhouetted group and approaches Billy.', 'The FIGURE STEPS INTO THE LIGHT. ', 'Billy stares into the face of an IDENTICLE VERSION OF ', 'HIMSELF.', 'OPENING CREDITS', 'ELEVEN is pacing on the porch. She leans over the edge, takes ', 'a look round, then turns and storms inside the cabin.', 'El marches in and heads straight for the TELEPHONE ON THE ', 'WALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.', 'HOPPER', 'Is everything okay?', '3.', 'EL', 'Yes.', 'KAREN WHEELER is packing LUNCH and SNACKS.', 'PHONE RINGS', 'Karen answers.', 'KAREN', 'Hello, this is the Wheelers.', 'Yeah, just a sec.', 'Karen puts her hand over the mouthpiece, then yells', 'Mike! Phone!', "KAREN (CONT'D)", 'Mike is pacing nervously.', 'MIKE', '(yells to Karen)', 'Okay!', 'Mike walks stiffly to the PHONE ON THE WALL. He takes a deep ', 'breath before picking up.', "MIKE (CONT'D)", '(into the phone)', 'Hello?', 'El goes into her room.', 'EL', 'It’s nine-thirty-two. Where are ', 'you?', 'She TELEKINETICALLY closes her bedroom door.', ' MIKE’S BASEMENT AND EL’S BEDROOM', 'MIKE', '(stammers)', 'Sorry, I was just about to call. I -', '- um -- can’t see you today.', '4.', 'EL', 'What? Why not?', 'MIKE', 'It’s my Nana. She’s very sick.', 'EL', 'But Hop said that your Nana was ', 'okay. That it was a false alarm.', 'MIKE', 'Yeah -- that’s what we thought it ', 'was at first, but then she took a ', 'real turn for the worse.', 'Oh.', 'EL', 'MIKE', 'Yeah. We think she might -- die.', 'Karen’s been listening in.', 'KAREN', 'What?', 'A look of worry flashes across Mike’s face before he covers ', 'the mouthpiece and yells upstairs.', 'MIKE', 'Mom! Get off the phone! How many ', 'times?!', 'Karen, still on the phone, but yelling to Mike.', 'KAREN', 'Did Nana call?', 'MIKE', '(yelling in the direction ', 'of the kitchen)', '(MORE)', '(MORE)', "MIKE (CONT'D)", 'No, Mom! Just get -- off - the -- ', 'phone!', '5.', '5.', 'With a distraught expression, Karen SCOFFS, then hangs up.', 'Mike takes  ...

# %%
newsubelement_v2=[]
for item in newsubelement:
    if ":" in item:
        morelines = item.split(":")
        for items in morelines:
            newsubelement2.append(items)
    else:
        newsubelement_v2.append(item)

# %%
stripped = []
#charslist2v2 = []
for item in newsubelement:
    i = re.sub(r'\([^()]*\)',":", item)
    if i.isupper():
        if ":" in i:
            stripped.append(i)
        else:
            stripped.append(i+":")
    elif re.match(r"^[0-9\.\s]*$",i):
        pass
    elif i == ":":
        pass
    else:
        stripped.append(i)

# %%
print(stripped)
# Out:
# ['STRANGER THINGS 3:', '"CHAPTER TWO:', ' THE MALL RATS":', 'by', 'updated versions.', 'ii.', 'ii.', 'iv.', ' Scenes in RED take place in the UPSIDE DOWN.', ' Interior Starcourt Mall scenes include SHOP ADDRESS in ', 'Picking up where we left off.', 'The only light, from the BRIGHT MOON, spills through the ', 'FILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the ', 'STAIRS leading to the basement. It’s QUIET.', 'JUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the ', 'stairwell door, pulling himself up. Then, he BREAKS FREE from ', 'the FLESHY TENTACLE which pulled him downstairs only moments ', 'ago.', 'Billy sprints out of the abandoned factory, heading to his ', 'CAMARO.:', 'Billy speeds away; leaving a trail of dust in his wake.', 'Billy pulls over to a TELEPHONE BOOTH. He dashes frantically ', 'from his car to the BOOTH. He DIALS 9-1-1. On the SECOND ', 'RING, the FEMALE OPERATOR picks up', 'OPERATOR :', 'Nine-one-one, what’s your ', 'emergency?', 'Billy getting pulled into the factory, and down the stairs.', 'IN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS ', 'attack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS ', 'TO BILLY’S FACE.:', 'The LIGHT inside the booth FLICKERS.', 'OPERATOR :', 'Is someone there? Hello?', 'The LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the ', 'receiver and then steps outside the booth.', 'He sees something off in the distance. WHITE PARTICLES float ', 'in the air. Billy steps onto Cornwallis Road. Through THICK ', 'FOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male, ', 'female, various ages) shuffling forward.', 'BILLY:', 'What do you want?', 'He cautiously walks toward the crowd.', 'Hey! I said, what do you want?', 'BILLY :', 'The group continues shuffling toward Billy.', 'BILLY :', 'I said WHAT -- DO -- YOU -- WANT?', 'THUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the ', 'UPSIDE DOWN. The group halts their march. A LONE FIGURE ', 'emerges from the silhouetted group and approaches Billy.', 'The FIGURE STEPS INTO THE LIGHT. ', 'Billy stares into the face of an IDENTICLE VERSION OF ', 'HIMSELF.:', 'OPENING CREDITS:', 'ELEVEN is pacing on the porch. She leans over the edge, takes ', 'a look round, then turns and storms inside the cabin.', 'El marches in and heads straight for the TELEPHONE ON THE ', 'WALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.', 'HOPPER:', 'Is everything okay?', 'EL:', 'Yes.', 'KAREN WHEELER is packing LUNCH and SNACKS.', 'PHONE RINGS:', 'Karen answers.', 'KAREN:', 'Hello, this is the Wheelers.', 'Yeah, just a sec.', 'Karen puts her hand over the mouthpiece, then yells', 'Mike! Phone!', 'KAREN :', 'Mike is pacing nervously.', 'MIKE:', 'Okay!', 'Mike walks stiffly to the PHONE ON THE WALL. He takes a deep ', 'breath before picking up.', 'MIKE :', 'Hello?', 'El goes into her room.', 'EL:', 'It’s nine-thirty-two. Where are ', 'you?', 'She TELEKINETICALLY closes her bedroom door.', ' MIKE’S BASEMENT AND EL’S BEDROOM:', 'MIKE:', 'Sorry, I was just about to call. I -', '- um -- can’t see you today.', 'EL:', 'What? Why not?', 'MIKE:', 'It’s my Nana. She’s very sick.', 'EL:', 'But Hop said that your Nana was ', 'okay. That it was a false alarm.', 'MIKE:', 'Yeah -- that’s what we thought it ', 'was at first, but then she took a ', 'real turn for the worse.', 'Oh.', 'EL:', 'MIKE:', 'Yeah. We think she might -- die.', 'Karen’s been listening in.', 'KAREN:', 'What?', 'A look of worry flashes across Mike’s face before he covers ', 'the mouthpiece and yells upstairs.', 'MIKE:', 'Mom! Get off the phone! How many ', 'times?!', 'Karen, still on the phone, but yelling to Mike.', 'KAREN:', 'Did Nana call?', 'MIKE:', '(yelling in the direction ', 'of the kitchen)', 'MIKE :', 'No, Mom! Just get -- off - the -- ', 'phone!', 'With a distraught expression, Karen SCOFFS, then hangs up.', 'Mike takes a deep breath, then', 'MIKE:', 'Sorry about that.', 'EL:', 'Was that your mom?', ' MIKE’S BASEMENT AND EL’S BEDROOM:', 'MIK ...

# %%
s3e2_dict = defaultdict(list)
extra_dialog_v2 = []

for index, elem in enumerate(stripped):
    if index + 1 < len(stripped) and index - 1 >= 0:
        if elem.strip().endswith(":"):
            char_name = elem.replace(":","").strip()
            next_elem = stripped[index+1] 
            temp_words_said = []
            next_elem_index = index+1
            while ":" not in next_elem:
                temp_words_said.append(next_elem)
                next_elem_index+=1
                next_elem = stripped[next_elem_index]
            newstrings = " ".join(temp_words_said)
            if char_name in s3e2_dict.keys():
                s3e2_dict[char_name].append(newstrings)
            else:
                s3e2_dict[char_name] = [newstrings]
        elif ":" in elem.strip():
            char_name = elem.split(":")[0].strip()
            #print(elem.split(":"))
            words_said = elem.split(":")[1]
            next_elem = stripped[index+1] 
            temp_words_said = [words_said]
            next_elem_index = index+1
            while ":" not in next_elem:
                temp_words_said.append(next_elem)
                next_elem_index+=1
                next_elem = stripped[next_elem_index]
            newstrings = " ".join(temp_words_said)
            if char_name in s3e2_dict.keys():
                s3e2_dict[char_name].append(newstrings)
            else:
                s3e2_dict[char_name] = [newstrings]

# %%
s3e2_dict
# Out:
# defaultdict(list,
#             {'"CHAPTER TWO': [''],
#              'THE MALL RATS"': ['by updated versions. ii. ii. iv.  Scenes in RED take place in the UPSIDE DOWN.  Interior Starcourt Mall scenes include SHOP ADDRESS in  Picking up where we left off. The only light, from the BRIGHT MOON, spills through the  FILTHY, BROKEN, WINDOWS. The RAYS OF MOONLIGHT highlight the  STAIRS leading to the basement. It’s QUIET. JUST THEN, BILLY HARGROVE SCREAMS, grabbing the frame of the  stairwell door, pulling himself up. Then, he BREAKS FREE from  the FLESHY TENTACLE which pulled him downstairs only moments  ago. Billy sprints out of the abandoned factory, heading to his '],
#              'CAMARO.': ['Billy speeds away; leaving a trail of dust in his wake. Billy pulls over to a TELEPHONE BOOTH. He dashes frantically  from his car to the BOOTH. He DIALS 9-1-1. On the SECOND  RING, the FEMALE OPERATOR picks up'],
#              'OPERATOR': ['Nine-one-one, what’s your  emergency? Billy getting pulled into the factory, and down the stairs. IN THE BASEMENT, Billy SCREAMS as BLOOD and GOO-SOAKED RATS  attack him. Then, the FLESHY TENTACLE WIDENS and then CLAMPS ',
#               'Is someone there? Hello? The LIGHT GOES OUT, the PHONE GOES DEAD. Billy hangs up the  receiver and then steps outside the booth. He sees something off in the distance. WHITE PARTICLES float  in the air. Billy steps onto Cornwallis Road. Through THICK  FOG, Billy sees A SILHOUETTED GROUP OF PEOPLE (12 - 15, male,  female, various ages) shuffling forward.'],
#              'TO BILLY’S FACE.': ['The LIGHT inside the booth FLICKERS.'],
#              'BILLY': ['What do you want? He cautiously walks toward the crowd. Hey! I said, what do you want?',
#               'The group continues shuffling toward Billy.',
#               'I said WHAT -- DO -- YOU -- WANT? THUNDER CLAPS. RED LIGHTNING crackles in the DARK SKY of the  UPSIDE DOWN. The group halts their march. A LONE FIGURE  emerges from the silhouetted group and approaches Billy. The FIGURE STEPS INTO THE LIGHT.  Billy stares into the face of an IDENTICLE VERSION OF ',
#               'Stay away from me, Karen. He marches past Karen.',
#               'I said, what do you want!? Facing the IDENTICAL VERSION of himself',
#               'To build what?',
#               'I don’t understand.',
#               'I don’t understand. What do you mean? I don’t  understand! Billy JERKS AWAKE, sitting on the LIFEGUARD HIGHCHAIR. His  BLUE EYES appear VIVID. He glances around at the CROWDED  POOL. He notices his arm HANGING OUT OF THE SHADE of the  UMBRELLA. The SKIN NEAR HIS ELBOW, DARK RED and SHINY. Walking along the pool deck, Billy bumps into a MAN causing  him to drop his COOLER. ICE and CANNED SODA spill out of the  busted cooler.',
#               '',
#               'Don’t be afraid. It’ll be over  soon. Just stay very still. Hovering his face close to hers, Billy slowly tears the duct  tape off of her mouth. Billy gets up. Heather turns her head  toward a GROWLING SOUND. A LARGE SLIMY CREATURE emerges from the shadows. GROWLING. Heather SCREAMS. As he watches the FLAYING, Billy’s face remains impassive.'],
#              'HIMSELF.': [''],
#              'OPENING CREDITS': ['ELEVEN is pacing on the porch. She leans over the edge, takes  a look round, then turns and storms inside the cabin. El marches in and heads straight for the TELEPHONE ON THE  WALL. HOPPER is in the KITCHEN preparing breakfast. El DIALS.'],
#              'HOPPER': ['Is everything okay?',
#               'What’s going on? Without answering, El trudges back to her room and  TELEKINETICALLY slams the door behind her. IN THE KITCHEN, a smile spreads across Hopper’s face. The  song  “YOU DON’T MESS AROUND WITH JIM” BY JIM CROCE plays. Hopper’s POLICE TRUCK drives by. The SONG CONTINUES, and  Hopper sings along. He’s drumming his hands on the wheel and singing along. Yes,  he certainly showed that -- that smug sonofabitch, Mike,  who’s boss.',
#               'And they say... You don’t tug on Superman’s cape... You don’t spit into the wind... You don’t pull the mask on... That old Lone Ranger... And you don’t mess around with Jim. Hopper pulls into an empty parking space next to JOYCE’S FORD ',
#               'Emotions have been shared.  Boundaries have been set. Order --  has been ... restored.',
#               'Uh, this is the first day in six  long, excruciating months that they  will not be seeing each other. Yes!  I think it worked! Yes! Hopper chuckles and Joyce CLAPS EMPHATICALLY.',
#               'No, stop! It’s all you. I’m a  puppet, you’re the master. So you remembered everything?',
#               'Yeah, yeah. I mean I had to  improvise a little bit, you know?  It turns out, getting to Mike --  that was the key.',
#               'I’ll tell you everything over  dinner. I was thinking, you know,  Enzo’s, tonight, seven o’clock.  Hey, before you say no, I’d like to  make one thing crystal clear. This  is not a date.',
#               'I know. I didn’t say anything about  a date. I just wanted to clear it  up in case there was any confusion  on your part.',
#               'Great. It’s just two friends  getting together for a nice dinner.  I mean, we’ve earned it, haven’t  we?',
#               'You’ll be home by nine. Eight.',
#               'Eight-thirty, I’ll pick you up.',
#               'Seven. Enzo’s. Meeting there. Deal. JUST THEN, Hopper’s WALKIE TALKIE comes alive.',
#               'Yeah, I’m a little busy right now. PROTESTERS, female, male, adults, have gathered to protest  the Mayor and Starcourt Mall. They’re carrying PLACARDS and  shouting.',
#               'Duty calls. While heading for the door, he nearly slips on FALLEN  MAGNETS. But, without missing a beat Clean up on aisle five.',
#               '',
#               'See you tonight. IN THE AISLE, Joyce crouches down and picks up one of the  magnets. She tries to put one back on the DISPLAY, but it  falls down. She tries again with DIFFERENT MAGNETS but the  same thing happens. NANCY WHEELER is pouring COFFEE into a MUG absentmindedly ',
#               'Great. He butts his cigarette out in an ASHTRAY.',
#               'I’m not doing it, Larry.',
#               'You don’t like your fan club, you  want me to shut ‘em down. Sound  about right?',
#               'They’re not actually fans?',
#               'Well, Larry, I think that they’re  just exercising their good old  fashioned American right to  protest. Hopper stands and heads for the door. Kline is preparing to  light his cigar.',
#               'Not that I’m aware of.',
#               'Larry, I’m not a politics guy, but  I think if you force those people  out of here without provocation, I  don’t think that’s a good look for  your re-election campaign. Kline walks to the window overlooking the protesters. He  peers out. An instrumental version of “AMERICA THE BEAUTIFUL” ',
#               'Independence Day? Kline turns and walks over to Hopper.',
#               'You can protest all you want,  Henry, you’ve just gotta go through  the proper channels first. AT THE POLICE CAR, Hopper tries to sit Henry in the back seat  where THREE OTHER PROTESTERS are already sitting handcuffed.',
#               'Ohh, yeah! Hopper pulls out a sweet-looking HAWAIIAN SHIRT.',
#               'Yeah. Yeah! Powell, standing nearby, looks on in disbelief.',
#               '(placing the shirt back in  the bag) It’s cuttin’ edge stuff, all right? Hopper marches off to his TRUCK. Looking over his shoulder  back at Flo and Powell It’s cutting edge!',
#               'Powell shakes his head. An UPSCALE RESTAURANT. A LIVE ENSEMBLE plays “STRING QUINTET ',
#               'I’ll start off with a Scotch, you  can make that a double.',
#               'And I think we’ll have a bottle of  red, as well.',
#               'And how’s your chee-an-ti?',
#               '',
#               'Great! Women love cherries, huh? (closes the menu, hands it  back to the waiter) All right, we’ll have that and two - - two glasses, please, one for, uh,  me, and one for the lady.',
#               'You know what, Enzo?',
#               'I just lost my appetite, all right? Here you go. You can keep the  change. Hopper stumbles to his feet, grabs the Chianti bottle.',
#               'I can do anything I want. I’m the  chief of police. Hopper takes a SWIG FROM THE BOTTLE as he leaves the  restaurant. BY THE BAR, Hopper bumps into a MAN enjoying a DRINK but says  nothing and just keeps walking. It’s Grigori - his MOTORCYCLE  HELMET in front of him. He watches Hopper go. Billy’s car SPEEDS DOWN THE ROAD. Billy pulls up to the abandoned factory and parks. The door SWINGS OPEN and Billy gets out. He moves to the back  of the car and opens the TRUNK. He peers into it. Heather  Holloway, BOUND AND UNCONSCIOUS.  Inside the locker room at the Hawkins Community  Pool. Billy, are you okay? Billy grabs Heather by the throat. He shuts the curtain,  which she FLAILS AGAINST.'],
#              'EL': ['Yes. KAREN WHEELER is packing LUNCH and SNACKS.',
#               'It’s nine-thirty-two. Where are  you? She TELEKINETICALLY closes her bedroom door.',
#               'What? Why not?',
#               'But Hop said that your Nana was  okay. That it was a false alarm.',
#               '',
#               'Was that your mom?',
#               'You can come over after?',
#               'Do you lie?',
#               '',
#               'Can we talk? El is sitting on the edge of Max’s BED. Max paces.',
#               'And then he said he missed me. And  then he just hung up.',
#               '',
#               'But friends don’t lie.',
#               'Doesn’t exist?',
#               'Give him the medicine.',
#               'Where are we going?',
#               'Too many people. Against the rules.',
#               'How do I know -- what I like?',
#               'Like me?',
#               '',
#               '',
#               'Yeah. Am I your pet? What? No!',
#               'Then why do you treat me like  garbage?',
#               'You said Nana was sick.',
#               'You. Lie. Mike looks at El guiltily. Why do you lie?',
#               'JUST THEN, the BUS pulls in. El glares as she steps closer. Mike stands his ground -  albeit very nervously. I dump your ass.',
#               'Max’s jaw drops as she follows El away leaving the boys  staring dumbly.  El and Max take their seat on the CROWDED bus. They HIGH '],
#              'PHONE RINGS': ['Karen answers.'],
#              'KAREN': ['Hello, this is the Wheelers. Yeah, just a sec. Karen puts her hand over the mouthpiece, then yells Mike! Phone!',
#               'Mike is pacing nervously.',
#               'What? A look of worry flashes across Mike’s face before he covers  the mouthpiece and yells upstairs.',
#               'Did Nana call?',
#               'Hey, Jill, I gotta used the  restroom. Will you watch Holly for  me?',
#               'Thanks. Karen walks in, through the grated door. It’s a NARROW ROOM  lined with MACHINERY AND ELECTRICAL PANELS. She rounds a  corner into the next room SHELVES LINE THE WALLS. CHEMICALS and HARDLY-USED POOL  SUPPLIES fill the shelves. Karen walks in. Billy, looking  through the chemical bottles, has his back turned to the  door.',
#               'Billy? Billy sets down a CHEMICAL BOTTLE on the shelf, but does not  turn to face Karen.',
#               'I understand if you’re angry with  me. Billy does not respond. I wanted to explain --',
#               '-- why I didn’t come last night.  It’s not you, it’s just -- I have a  family. SWEAT on Billy’s face glistens in the poorly-lit room.  Karen’s VOICE STARTS TO ECHO. We can HEAR BILLY’S HEARTBEAT ',
#               'And I can’t do anything that will  hurt them. You can understand that,  right? But I shouldn’t have said  that -- Billy TURNS QUICKLY, THEN SLAMS KAREN’S HEAD INTO A SHELF.',
#               'Billy? Karen is standing behind Billy as if nothing happened.',
#               'Billy ... please, will you talk to  me? Billy turns to face her. Karen is slightly taken aback by his  appearance.'],
#              'MIKE': ['Okay! Mike walks stiffly to the PHONE ON THE WALL. He takes a deep  breath before picking up.',
#               'Hello? El goes into her room.',
#               'Sorry, I was just about to call. I - - um -- can’t see you today.',
#               'It’s my Nana. She’s very sick.',
#               'Yeah -- that’s what we thought it  was at first, but then she took a  real turn for the worse. Oh.',
#               'Yeah. We think she might -- die. Karen’s been listening in.',
#               'Mom! Get off the phone! How many  times?! Karen, still on the phone, but yelling to Mike.',
#               '(yelling in the direction  of the kitchen)',
#               'No, Mom! Just get -- off - the --  phone! With a distraught expression, Karen SCOFFS, then hangs up. Mike takes a deep breath, then',
#               'Sorry about that.',
#               'Yeah. She’s so upset, she’s making  no sense. Because we have to go to  the nursing home. To see Nana.',
#               'No! I mean -- I just think I need  to be alone today. With my -- feelings?',
#               'What?! No. Friends don’t lie. Time to end this before the hole gets any deeper.',
#               'What, Mom? Mike waits for Karen’s “response”. Then',
#               'My mom’s calling me. Better go.  Talk to you tomorrow. Miss you  already. Bye! He quickly hangs up. El stares at her receiver in bewilderment. Mike leans his forehead against his phone and sighs. El comes out of her room to hang up. Hopper is standing in  the kitchen eating a BOWL OF CEREAL.',
#               'She knows I’m lying. She knows I’m  lying. LUCAS SINCLAIR is sitting in the RECLINER listening intently.  WILL BYERS is sitting at the GAME TABLE, setting up D&D, not  interested in the conversation.',
#               'Hopper. He threatened me.',
#               '',
#               'The big deal is, if I don’t do what  he says, then he’ll stop me from  seeing El. Like, permanently. You  don’t understand, Lucas. He’s  crazy. He’s lost his mind.',
#               'I had no choice, Lucas. I really  had no choice.',
#               '',
#               'I just -- I don’t understand what  we’re looking for.',
#               'What, just something that literally  says I’m sorry?',
#               'Excuse me, sir. How much for this  little teddy bear here? Parker eyes Mike, then smiles politely.',
#               'I should have shoved that little  teddy bear right up his --',
#               'No.',
#               'That’s ridiculous. Why can’t I just  mow Old Man Humphries’ lawn?',
#               'Okay, what if we split it?',
#               '',
#               'What are you doing here? Shopping.',
#               'What’s wrong with you? You know  she’s not allowed to be here.',
#               '',
#               'What?',
#               'She is. She is sick. (motions to Lucas for  back up) She is sick. Yeah, sick -- she’s sick.',
#               'Yeah, we’re shopping -- Not for us,  but for her, for Nana. For Nana!',
#               'Also, we’re here to get a gift for  you. Just -- we couldn’t find  anything that suited you. And I  only have, like, three dollars and  fifty-cents, so it’s hard.'],
#              'MIKE’S BASEMENT AND EL’S BEDROOM': ['', ''],
#              'PINTO.': ['With a hop in his step, Hopper bursts through the door. JOYCE  BYERS is at the CASH COUNTER.'],
#              'JOYCE': ['Wait, wait, it worked?',
#               '',
#               'And you didn’t yell at him?',
#               'Wait, a date? You never said  anything about a date.',
#               'There’s not.',
#               'I can’t be out late.',
#               '',
#               'I’ll meet you there.',
#               'Bye!',
#               'Hello!? FROM BEHIND we see a MAN sitting at a work table. He’s ',
#               'Hello?',
#               'What is this, again?',
#               'It creates an electromagnetic  field.',
#               'I don’t see anything.',
#               'Yeah.',
#               'Just like my magnets.',
#               'Okay. Why is nothing happening?',
#               'How ...',
#               'No, no, no, I mean, how is this  happening at my house?',
#               'And the magnets at Melvald’s?',
#               'Apo-what-o-whah?',
#               'But what if it’s not.',
#               'A machine?',
#               'But, it is possible?'],
#              'OFFICER POWELL': ['Hey, Chief, do you copy? Chief! He turns and heads for an AISLE while grabbing his walkie  from his belt.',
#               'Yeah, well, I’m busier here. You  wanna keep your job tomorrow, I  think you need to get your ass to  Town Hall. Now! Hopper puts his walkie on his belt.',
#               'That’s a lot of color for you,  Chief.'],
#              'DORIS DRISCOLL 4819 CORNWALLIS RD': ['DISEASE RATS. Then she notices the coffee overflowing.'],
#              'NANCY': ['Oh, shit, shit, shit. BRUCE is leaning back in his chair. He notices Nancy.',
#               'And here you are, two creams, two  sugars.',
#               'Of course.',
#               '',
#               'I really hate to ask this, but do  you think one of the other girls  could run and grab lunch today? They’re needed at their desks.',
#               'I know, I just, I really need to go  to the doctor. Nancy leans closer to Tom while he sips his coffee.',
#               'I’ve been having some -- um, girl  problems. Tom COUGHS NERVOUSLY before recovering and nodding shyly. Ignoring the ILLUMINATED RED LIGHT, Nancy bursts in. JONATHAN  BYERS is working.',
#               'Let’s go! With a spring in her step, and a renewed sense of self-worth,  Nancy rushes out of the building. Jonathan is not too far  behind her carrying BAGS OF PHOTOGRAPHY EQUIPMENT.',
#               'Really? Because I feel like this is  the best idea I’ve had all summer.',
#               'The harm in asking is that Tom will  say no. We ask for forgiveness, not  permission. And if the story’s as  good as I think it’s gonna be, then  Tom won’t care. In fact, he’ll  thank us.',
#               'And then we never have to work in  this shithole again. They climb into the car.',
#               'Yes?',
#               'Hi, I’m Nancy? Nancy Wheeler, we  spoke briefly on the phone last  night.',
#               'Lovely. Do you live here all alone? Jonathan is carrying BAGS OF PHOTOGRAPHY EQUIPMENT and Nancy ',
#               'Oh, um, I’m so sorry.',
#               'And, these bags, you’re sure they  were full before?',
#               'Are you sure they did? Mrs. Driscoll is slightly offended by the question.',
#               'Maybe they just gnawed the bag? I  mean, eating fertilizer seems --',
#               'What does that mean, exactly ...  not right?',
#               'Hi, yes, this is nancy Wheeler from  The Hawkins Post. Yeah, I have a  bit of a weird question for you. I  was wondering if you guys had  gotten any recent call about rabid  rats?',
#               'No, rabid rats. Rats with rabies?  Okay, how about just rats in  general? The response is in the NEGATIVE. Okay, thank you.',
#               'Nancy hangs up. Mrs. Driscoll comes from the kitchen carrying  a GLASS OF LEMONADE.',
#               '(reluctantly accepts the  drink) Do you mind if I make just a few  more calls?',
#               'Jonathan! Startled, Jonathan turns to Nancy. I have a lead.',
#               '',
#               'Yeah, no shit. Come on. Nancy starts heading back upstairs.'],
#              'BRUCE': ['Whoopsie-daisy! Careful, there,  Nancy Drew. Careful. Pouring  coffee’s a tough gig, girl The other REPORTERS in the room, SNICKER. Nancy forces a tight smile then begins the clean up. TOM HOLLOWAY is at his DESK. Nancy walks in carrying the MUG.'],
#              'TOM': ['Thanks, sweetheart.', '', ''],
#              'BEAT': ['Tom? Hm?',
#               '',
#               'Karen’s VOICE ECHOES',
#               'Billy, carrying the unconscious Heather, walks through the  factory toward the BASEMENT STAIRS. Billy lays her down. DUCT TAPE covers Heather’s mouth. She  comes to and looks around before noticing Billy staring down  at her. She squirms desperately, but is unable to break free  from the ROPES THAT BIND HER HANDS AND ANKLES TOGETHER. Billy grabs her by the shoulders and leans close to her ear.'],
#              'JONATHAN': ['Oh, come on! The light!',
#               'Look, I just don’t know if this is  such a good idea anymore.',
#               'Look, all I’m saying is, what harm  is there in asking?',
#               'Or, the old lady is nuts and the  story blows up in our face and Tom  fires us.',
#               'We’re from The Hawkins Post.',
#               'We get that a lot.',
#               'We’re going to have to keep doing  this until you stop moving, you  little shit. Nancy stands over an open PHONE BOOK with the PHONE to her  ear. Mrs. Driscoll is in the kitchen preparing LEMONADE.',
#               'You all right, little bud? JUST THEN, Nancy at the bottom of the stairs',
#               'Yeah, okay, but -- I just think  there’s something really wrong with  this rat.',
#               'No, I -- He takes another look at the writhing rat before hastily  grabbing his camera gear and following her. Nancy, wait up.',
#               'Once he’s gone, the BASEMENT LIGHTS BEGIN TO FLICKER. SORES  APPEAR on the writhing rat’s body moments before it EXPLODES  INTO A PILE OF GOO. Then, the pile of goo starts SLIDING  ACROSS THE CAGE FLOOR and SEEPS through the bars of the cage. It drifts off the side of the washing machine and onto the  floor. It begins to MORPH INTO A CREATURE WITH LEGS and moves  across the basement floor with increasing speed. In the UPSIDE DOWN, RED LIGHNING FLASHES across the dark sky.'],
#              'NEAR JONATHAN’S CAR': [''],
#              'MONTAGE OVER THE SONG': [''],
#              '“GET UP AND GO” BY THE GO GO’S': ['- PATRONS eating. - COUPLES by the FOUNTAIN. - WORKERS preparing FOOD. - TEENAGERS being teenagers. ROBIN BUCKLEY glumly hands a FATHER AND DAUGHTER their ICE '],
#              'CREAM CONES.': ['', ''],
#              'ROBIN': ['Have a nice day.',
#               'Hi! Hi.',
#               '',
#               'Is who here? STEVE HARRINGTON swings open the door from the back room.',
#               'How many children are you friends  with? Steve’s smile fades. Steve and Dustin are in a BOOTH. Dustin is enjoying the ',
#               'Yeah, and how’s that working out  for you?',
#               'Haven’t you already tried the  peppermint stick?',
#               'Steve! Steve, eating a BANANA, is pacing. Dustin is sitting at a  TABLE. On the table  RUSSIAN - ENGLISH DICTIONARY and a ',
#               'All right, babysitting time is  over. You need to get in there. Robin instantly turns her attention to the WALL MOUNTED WHITE  BOARD. It no longer shows Steve’s “YOU SUCK” ratio. Instead,  the RUSSIAN ALPHABET and its ENGLISH EQUIVALENT.',
#               'Hey, my board! That was important  data, shitbirds.',
#               'Yeah? And how do you know these  Russians are up to no good,  anyways? Dustin turns to Steve in shock, and without a hint of irony',
#               'Hello, I can hear you. Steve and Dustin regard Robin.',
#               'Actually, I can hear everything.  You are both extremely loud. You  think you have evil Russians  plotting against our country, on  tape, and you’re trying to  translate, but haven’t figured out  a word because you didn’t realize  Russians use an entirely different  alphabet than we do. Sound about  right? She reaches for the recorder, but Steve snaps it away.',
#               'I wanna hear it. Why?',
#               '‘Cause maybe I can help. I’m fluent  in four languages, you know. Russian?',
#               'Ou-yay are-yay umb-day. Steve and Dustin are impressed! Oh-ho-ho!',
#               'That was Pig Latin, dingus. Steve smacks Dustin with the banana peel. Idiot.',
#               'But I can speak Spanish and French  and Italian, and I’ve been in band  for twelve years. My ears are  little geniuses, trust me. Steve is skeptical.',
#               'Come on, it’s your turn to sling  ice cream, my turn to translate. I  don’t even want credit, I’m just  bored. The SERVICE BELL at the counter rings. Steve and Dustin glance at each other resignedly. Then, Steve  trades the recorder for Robin’s ICE CREAM SCOOP. Jonathan’s car pulls in to the driveway and past a MAILBOX  that reads',
#               'Wait, that last part, just one more  time.',
#               'Okay, that word. Dustin stops the recorder. It’s pronounced dly-nna-ya.',
#               'Dly-nna-ya.',
#               'Which is spelled -- (pointing to the white  board)',
#               'Yeah, okay. Robin slides open the window to the front of the store. Steve  is serving two CUSTOMERS (Max and El',
#               'We’ve got our first sentence. Steve turns around, holding TWO ICE CREAM CONES.',
#               'The week is long.',
#               'I know. But, progress. She shuts the window. Steve turns his attention back to the  customers  Max and El.',
#               'It’s right. Steve joins Robin and Dustin as they walk through the closed ',
#               'I don’t know, is it?',
#               'Listen, just for kicks, let’s  entertain the possibility that it  is a secret Russian transmission.  What’d you think they were gonna  say, fire the warhead at noon? Exactly.',
#               'And my translation is correct. I  know that for sure, so, the silver  cat feeds. Why would anyone talk  like that unless they were trying  to mask the meaning of their  message? Exactly.',
#               'And why would anyone mask the true  meaning of their message unless the  message was somehow sensitive? Exactly!',
#               'So I guess that confirms your  suspicion.',
#               'I can’t believe I’m about to agree  with this strange child, but, yeah,  totally evil Russians.',
#               'Well, I guess we translate the rest  and hopefully a pattern emerges.',
#               'Or a person.',
#               'It’s probably gonna take a super  genius to crack it, but -- where’s  Steve? Steve is standing next to the INDIANA FLYER MECHANICAL HORSE,  going through his pockets for change.',
#               'What are you doing?',
#               'Are you sure you’re tall enough for  that ride?',
#               'You need help getting up, little  Stevie?',
#               'I don’t understand.',
#               'Maybe they have horses like this in  Russia.'],
#              'DAUGHTER': ['Thank you! DUSTIN HENDERSON is standing right behind them. He approaches  Robin at the counter. Dustin’s toothless smile - BEAMING.'],
#              'DUSTIN': ['',
#               'I’m Dustin. I’m Robin.',
#               'Please to meet you. Uh, is -- is he  here?',
#               'I’m back! You got the job!',
#               'Brilliant, too. And she doesn’t  even care that my real pearls are  still coming in. She says kissing  is better without teeth. Steve struggles to maintain a neutral expression.',
#               'So do you really just get to eat as  much of this as you want?',
#               'Seems cool.',
#               'They ditched me yesterday. No.',
#               'My first day back! Can you believe  that shit?',
#               'I swear to God. Mm. They’re gonna  regret it, though. Big time. When  they don’t get to share in my  glory.',
#               'So, last night, we’re trying to get  in contact with Suzie -- and, uh -- (glances around, covers  mouth, whispering) I intercepted a secret Russian  communication.',
#               'I intercepted a secret Russian  communication.',
#               'I intercepted a secret Russian  communication! PATRONS stop what they’re doing and look.',
#               'It means, Steve, we could be  heroes. True American heroes. Ah! Mm-hmm.',
#               'Just think, you could have all the  ladies you want and more. More? More.',
#               '',
#               'Mm-hmm.',
#               'No catch, I just need your help.',
#               'Translation. MAX MAYFIELD SKATEBOARDS out front of her house. She attempts  an OLLIE but fails. She tries again, nearly falling this  time, and sending her board rolling away. The board rolls to a stop at El’s feet. She kicks it up into  her hands.',
#               'So, what do you think?',
#               '',
#               'Why are you listening to the music,  Steve? Listen to the Russian! We’re  translating Russian!',
#               'I guarantee you, what we’re doing  is way more important than your  data.',
#               'How does she know about the  Russians?',
#               'You told her about the  Russians. It wasn’t me.',
#               '',
#               '',
#               '',
#               'Okay. RECORDING CONTINUES and Robin listens intently. AT THE WORD',
#               '',
#               'D ... D ... The -- the chair! The  chair-looking thingy!',
#               'Honestly, I think it’s great news.',
#               'It’s not nonsense. It’s too  specific. It’s obviously a code.',
#               '',
#               '',
#               '',
#               'Evil Russians.',
#               'So how do we crack it?',
#               'A pattern. Right, like maybe silver  cat is a meeting place?',
#               'Or a weapon.',
#               '',
#               'Holly shit. The music. Dustin takes off his BACKPACK and kneels down. The music!',
#               'He takes the RECORDER out of his backpack and presses play.  The SECRET RUSSIAN COMMUNICATION plays with the SAME SONG  behind it.',
#               'It’s the exact same song on the  recording.'],
#              'STEVE': ['Henderson! Dustin laughs. Henderson! He’s back!',
#               'He makes his way to Dustin.',
#               'I got the job! Steve PANTOMIMES AND IMITATES A TRUMPET before he and Dustin  do a COMPLICATED HANDSHAKE, including a DUEL WITH LIGHTSABERS  where Steve, ultimately, “dies” after being disemboweled.  They both LAUGH AND GRIN WIDELY after Steve “spills his  guts.”',
#               'No, no. No way. Hotter than Phoebe  Cates?',
#               'Wow. Yeah, that’s great. Proud of  you, man. That’s kinda romantic.  Just -- like, wow.',
#               'Yeah. I mean, sure. It’s not really  a good idea for me, though. I gotta  keep in shape for the ladies. Robin is cleaning and organizing near the counter.',
#               'Ignore her.',
#               'She’s not. So, where are the other  knuckleheads?',
#               '',
#               'Whoa. Seriously?',
#               'Glory? What glory? Dustin scoots closer to Steve, and lowers his voice.',
#               'What? Dustin looks around, and repeats SOFTLY',
#               'Just speak louder.',
#               'Jeez, shh. Yeah, okay that’s what I   thought you said. What does that mean?',
#               '',
#               'American heroes.',
#               '',
#               'I like more.',
#               'What’s the catch?',
#               'With what? Dustin unzips his BACKPACK and pulls out a RUSSIAN - ENGLISH ',
#               'It sounded familiar. What?',
#               'The music. The music right there at  the end.',
#               'I’m trying to listen to the  Russian, but there’s music playing - - Robin bursts in.',
#               'I don’t know.',
#               '',
#               'Whoa, whoa, what do you think  you’re doing?',
#               'Why?',
#               'Holly shit!',
#               '',
#               'Oh, seriously?',
#               'Well that’s thrilling.',
#               'Okay, here you go, you got a  strawberry and then a vanilla with  sprinkles, extra whipped cream. Thanks.',
#               'Wait a second. Are you even allowed  to be here? The girls exchange a giddy look then run out leaving Steve  perplexed. Okay.',
#               'Max and El burst out the MALL ENTRANCE, enjoying their ICE ',
#               'I mean, it just, it just can’t be  right.',
#               'How is this great news? I mean, so  much for being American heroes.  It’s total nonsense.',
#               'What do you mean, a code?',
#               'That’s a total stretch.',
#               'You’re buying into this?',
#               'It’s a quarter. I need -- do you  have a quarter?',
#               'Quarter! Robin tosses Steve a quarter and he puts it into a slot on  the machine. The ride comes to life. The song',
#               'Shh!',
#               'Would you two just shut up and  listen?',
#               'Indiana Flyer? I don’t think so.  This code, it -- didn’t come from  Russia. It came from here. The STRING QUARTET plays'],
#              'BANANA BOAT ICE CREAM.': [''],
#              'DUDTIN': [''],
#              'DICTIONARY.': [''],
#              'MAX': ['Hi. Hi?',
#               'He’s a piece of shit. What?',
#               'Mike doesn’t have jack shit to do  today and his Nana obviously isn’t  sick. I guarantee you, him and  Lucas are playing Atari right now.',
#               'Yeah, well, boyfriends lie. All.  The. Time. Mike is pacing.',
#               'You’re going to stop calling him.  You’re going to ignore his calls.  As far as you’re concerned, he  doesn’t exist.',
#               'He treated you like garbage. You’re  gonna treat him like garbage. Give  him a taste of his own medicine.',
#               'Mm-hmm. And if he doesn’t fix this,  if he doesn’t explain himself, dump  his ass. Mike flops down on the SOFA.',
#               '',
#               'To have some fun. There’s more to  life than stupid boys, you know. Mike and Lucas run upstairs, forgetting Will.',
#               'So, what do you think? El gazes worriedly. Hey, what’s wrong?',
#               '',
#               'Seriously? You have superpowers.  What’s the worst that could happen? A SWEEPING SHOT of the ATRIUM settles on Max and El.',
#               'So, what should we do first? El looks at Max blankly.',
#               'You’ve never been shopping before,  have you? El shakes her head.',
#               'Well, then I guess we’re just gonna  have to try everything. Come on. Max takes El by the hand and they run in to THE GAP. AT THAT MOMENT, Mike, Lucas and Will walk past, neither  notice the other.',
#               'You like that?',
#               'You just try things on. Until you  find something that feels like you.',
#               'Yeah. Not Hopper. Not Mike. You. It’s quiet. A lone CAR drives past. Joyce, sitting at the CASH COUNTER, studies an open TEXTBOOK.  Stacked around her',
#               'See, what did I tell you. There’s  more to life than stupid boys. SONG CONTINUES as Max and El run by, still unaware of the  boys’ presence.  Sitting on a NEARBY BENCH, with POTTED  PLANTS BEHIND, Will, Mike and Lucas sit gloomily.',
#               'Thanks.',
#               'You wanna trade? They switch cones. Max and El stop when they HEAR MIKE at the  BICYCLE RACK nearby.',
#               'You’ve gotta be shitting me. He hasn’t got that much. Yeah, but --',
#               'Mike drops his bike and points at El.',
#               'This is her new style. What do you  think?',
#               'What is she, your little pet?'],
#              'LUCAS': ['I don’t even understand. Why lie?',
#               'Did he say he’d kill you? What? No!',
#               'So then, what’s the big deal?',
#               'I just wish you’d consulted me,  because the way you handled this,  you’re in deep shit.',
#               'I’m not gonna lie, it’s gonna be  bad. But, you can fix this. It’s just one little mistake. I’ve made hundreds, thousands. Max  has dumped me five times! But what  have I done? Huh? Have I despaired?  No. I’ve marched back into battle,  and I’ve won her back. Every.  Single. Freaking. Time. How?',
#               'I’ll show you. Come on. Come on.',
#               'Something pretty and shiny that  says, I’m sorry.',
#               'No! Max smiles as she trails behind El who peruses racks of  clothes. Her mouth agape, El stares up at an OUTFIT DISPLAY.',
#               'Three-hundred? Three-hundred.',
#               'Hey, Mike. Lucas sprays Mike’s face.',
#               '',
#               '',
#               'Split it with what? That doesn’t  even make sense. Max and El march over. Isn’t this a nice surprise.',
#               '',
#               'She’s super sick. That’s why we’re  here, actually.',
#               '',
#               'Super. Hard. It’s expensive. Nope. Not working.',
#               'No. Mike stands. Heartbroken. Hopper HANDCUFFS a PROTESTER, HENRY, 40s, before leading him  away to a WAITING POLICE CAR.'],
#              'WILL': ['Hey, guys, I’m almost set up here.',
#               'Wait, guys! I’m still here! Will cranes his neck toward the stairs. Guys?',
#               'DOZENS OF CHILDREN AND ADULTS hang out and play in the water.  HEATHER HOLLOWAY, on duty sitting in the HIGHCHAIR, blows her  MARINE WHISTLE, then raises a MEGAPHONE to her mouth.',
#               'Can we please play D&D now. No.',
#               'Now can we play D&D?'],
#              'HEATHER': ['Hey! No dunking, Curtis! No -- dunking. Karen and HER MOM FRIENDS lounge, reading ROMANCE NOVELS, ',
#               'Looking good, Billy. Billy stares at her confusedly, then passes Karen’s friends.',
#               'Billy, are you okay? Ignoring her, Billy continues on. AT A SHOWER STALL, Billy pulls aside the CURTAIN and turns  the TAP TO COLD. Bracing himself against the wall, he stands  under the water stream. He studies his LEFT ARM. A DARK VEIN travels up his skin and  branches off. He touches it and SEES A FLASH OF THE SHADOW ',
#               'Billy? Billy looks up and sees Heather standing there. Billy.',
#               'Heather crouches down to eye-level - her expression,  completely calm. In a DISTORDED VOICE Take me to him.',
#               'What?',
#               'I said, are you hurt? Billy stares in disbelief.',
#               'What’s going on? I heard screaming.  Should I call an ambulance? Billy’s stare changes. His face, WITHOUT EMOTION. His FINGERS  DIG INTO HIS LEG. Heather LEANS BACK fearfully moments before  Billy LASHES OUT.'],
#              'TRASHY MAGAZINES. MOM #1': [', MOM #2 '],
#              'MOM #3': ['.'],
#              'LIZ': ['God, even her voice annoys me.'],
#              'JILL': ['Nails on a chalkboard.', 'Sure thing, hon.'],
#              'MOM #1': ['(putting lotion on her  legs) Don’t worry, ladies, ten more  minutes ‘till showtime. Liz -- -- will you get my back? BUILDING next to the pool.'],
#              'POUNDING.': [''],
#              'BLACK': ['', '', ''],
#              'BILLY’S POV & HANDHELD FOLLOW': [''],
#              'POV BILLY': [' Walking through the grated door. Billy stumbles out. He looks up, holding a hand up against  the blazing sun.',
#               ' BLURRED, OVER-EXPOSED. Scans the pool and  surroundings. Heather struts past him.',
#               ' Karen’s friends, flirty smile, then in UNISON',
#               ' Heather is sitting at a nearby TABLE with FRIENDS.'],
#              'KAREN’S FRIENDS': ['Afternoon, Billy. Billy stares at them confusedly. AT THE HIGHCHAIR, Billy struggles to climb up but manages to  get himself seated. He’s pale, clammy. He LOOKS UP. The  bright sun PULSES. He’s exhausted. His PUPILS'],
#              'FULLY': [''],
#              'DIALATED.': [''],
#              'ECU': ['',
#               ' OVERHEAD; TUB OF ICE CREAM. MINT CHOCOLATE-CHIP. Robin’s  HAND, holding a small SAMPLE SPOON, scoops. Robin gives it to ERICA SINCLAIR, who, with her THREE FRIENDS  standing close behind, accepts the free sample. She tastes  it.',
#               ' The man is using a FINE BRUSH and PAINTING A FIGURINE.'],
#              'INTENSLY GLOWING SUN': [''],
#              'DISSOLVE TO': [''],
#              'ERICA': ['Can I try the peppermint stick?',
#               'Yes, and I’d like to try it again. Robin rolls her eyes.'],
#              'MICROCASSETTE RECORDER.': ['plays. In the background of the recording, the instrumental  song  “DAISY BELL” BY HARRY DACRE plays.'],
#              'DRISCOLL.': ['Nancy knocks on the door, Jonathan standing beside her. DORIS  DRISCOLL, 80s, answers the door.'],
#              'MRS. DRISCOLL': ['Yes? Mrs. Driscoll?',
#               '',
#               'Oh! Oh, yes! Oh my goodness. Oh.  You look too young for reporters.',
#               'Follow me. Mrs. Driscoll leads Nancy and Jonathan through the house and  toward the basement stairs.',
#               'Yes. Jack, my husband, he passed  away -- what is it now -- ten years  ago.',
#               'Oh, don’t be. I kinda like the  quiet. They’re now standing at the DOOR LEADING TO THE BASEMENT. At least, I did.',
#               'Mrs. Driscoll opens the door.',
#               'This way. She starts down the stairs. Jonathan and Nancy peer down  after her and exchange an uneasy look before following her  down. AT THE BOTTOM of the stairs, Mrs. Driscoll turns on the  light. It’s right over there.',
#               'She points to the other side of the basement. Nancy and  Jonathan venture ahead. Nancy crouches down in front of  PARTIALLY EMPTY BAGS OF FERTILIZER WITH HOLES IN THEM. She  lifts one up.',
#               'You see those little teeth marks,  don’t ya? Jonathan SNAPS a photo and Nancy locks eyes with him.',
#               'I’m old, honey, not senile. Bought  them over at Blackburn’s Supplies  just last Tuesday. Now you tell me,  why would rats wanna eat a poor old  woman’s fertilizer?',
#               'Crazy. Believe me, I know, honey.  But -- something’s not right with  these rats.',
#               'Rabies, my guess. That’s when I  said to myself, Doris, you gotta  call the paper. Because if those  diseased rats are runnin’ loose,  the people, the oughta know.  Wouldn’t you agree? Just then, a CRASHING SOUND from the other room startles  Nancy and Jonathan.',
#               'Oh, yes, I forgot to mention! Come  on over here. Mrs. Driscoll rounds a corner, followed by Nancy and  Jonathan. Mrs. Driscoll proudly proclaims',
#               'I caught one of the little  bastards. ON TOP OF A WASHING MACHINE, A FLORAL SHEET covers a  RECTANGULAR OBJECT which shakes violently.',
#               'You’re a regular little detective,  aren’t ya? Lemonade? It’s fresh- squeezed. Sure. Thanks.',
#               'Not at all! I enjoy the company. Mrs. Driscoll walks off, then Nancy looks through the  phonebook. She turns to a page with a LARGE ADVERTISEMENT'],
#              'SQUEALING. SNARLING. BANGING.': ['CROWDS OF PROTESTERS are shouting.'],
#              'PROTESTERS': ['Kline’s a swine! Kline’s a swine!  Kline’s a swine! CAMERA FOLLOWS BEHIND a STRAPPING MAN CARRYING A MOTORCYCLE '],
#              'HELMET': [' heading for the FRONT  DOORS. He passes by Hopper sitting in a CHAIR, where the '],
#              'CAMERA HOLDS. Hopper eyeballs': [' momentarily. Hopper  has a LIT CIGARETTE hanging from his lips.'],
#              'CANDACE': ['Jim? Mayor Kline is ready for you. CANDACE, late 20s, is MAYOR KLINE’s SECRETARY.'],
#              'MAYOR LARRY KLINE, 50s, the wealthy': [',  smarmy politician responsible for building Starcourt Mall, is  sitting behind his DESK reading the latest edition of THE  HAWKINS POST. Candace leads Hopper in.'],
#              'KLINE': ['Jim! He warmly greets Hopper at the door. Thanks for coming by.',
#               '',
#               'Calm down, now. You don’t even know  what I want. Kline goes back to his desk.',
#               'When did you get so serious? Take a  seat. PROTESTERS CAN BE HEARD YELLING. Hopper sits in the chair  opposite the MAYOR’S DESK.',
#               'My fan club, as you call them, no,  you know why they’re out there,  don’t ya?',
#               'They lost their jobs to the mall  and blame me for helping make that  happen. Now, you go ask anyone else  in this town -- they all love the  mall. It helped our economy grow,  brought in new jobs, and just some  incredible new stores. (reaching for a fresh ',
#               'I agree. If they had a permit. Now  correct me if I’m wrong here, Jim,  but I don’t believe they secured a  permit from your office. Did they?',
#               'Then I do believe it’s within my  right to get rid of them.',
#               'You know what’s in four days, Jim?',
#               'That’s right. And I’m gonna throw  this town the biggest bash it’s  ever seen. Fireworks, music, activities, you  name it. I’m gonna pull out all the  stops. You know why? ‘Cause at the  end of the day, that’s all the  voters will remember. But I can’t  think, much less plan, with all  that racket going on out there. (opens the door for  Hopper) So, if you don’t mind, please, just  do your job. Flash your little gold  badge and get rid of them. As the SONG CRESCENDOS, Kline flashes a bright smile, pats  Hopper on the arm, and sticks the cigar between his teeth. MALL PATRONS get off a BUS. Including El and Max.'],
#              'CUBAN CIGAR)': ['Which is why they all stopped  shopping at their, uh, mom-and- pops. Now, that’s not me, Jim. That’s just good old fashioned  American capitalism.'],
#              '': [' plays SOFTLY in the BACKGROUND.'],
#              'SEVERAL TEXTBOOKS ON ELECTROMAGNETIC': ['CONCEPTS. Exhausted, she sighs and drops her head. Them, she  looks up; her eyes shifting thoughtfully. Joyce’s CAR backs out of its spot, then speeds off. Joyce, holding the TALL STACK OF TEXTBOOKS, rings the '],
#              'DOORBELL.': [''],
#              'WEARING A HEADBAND MAGNIFIER.': [''],
#              'DOORBELL CHIMES': ['The man looks up and then over his shoulder. Joyce glances around, then heads back to her car - walking  past the GARAGE. JUST THEN, the garage door begins to open. Joyce turns her  attention there. The door opens all the way, REVEALING MR.  CLARKE. He flips up the magnifier.'],
#              'MR. CLARKE': ['Mrs. Byers? Jonathan SNAPS pictures of the RABID RAT running into the  walls of it’s CAGE on the WASHING MACHINE.',
#               'This is a solenoid. It’s a coil  wrapped around a metallic core, and  when electricity passes through it - -',
#               'Exactamundo. Now for the fun part.  Shall we? Mr. Clarke flips on a TRANSFORMER.',
#               'Nope. You can’t see it, but it’s  there, I assure you. Our very own  Clarke-Byers Electromagnetic Field.  Pretty neato, huh?',
#               'And this field affects any charged  object in its vicinity.',
#               'Just like your magnets.',
#               'Oh, because our field is stable.  But, if we reduce the current -- He turns a CRANK on the transformer and MAGNETS FALL OFF THE ',
#               'The magnetic dipoles tried to  orient according to the field, but  since --',
#               'You want my honest opinion? One of  your kiddos got up in the middle of  the night, bumped into the fridge,  and knocked the suckers loose.',
#               '',
#               'Apophenia. Uh -- You’re seeing  patterns that aren’t there.  Coincidence.',
#               'Well -- Theoretically speaking, I suppose  some large version of this AC  transformer could exist. A machine  of some kind.',
#               'But, in order to reach your house  and downtown, gosh, that would take  billions of volts of electricity  and cost tens of millions of  dollars.',
#               'We cured polio in fifty-three.  Landed on the moon in sixty-nine.  As I tell my students, once you  open up that curiosity door,  anything is possible. The mall is CLOSED. The FOOD COURT is vacant. Shops’ BARRED  GATES are down and locked. Except for The only shop in the mall whose lights are still on. Robin, Steve and Dustin are making progress.'],
#              'INDISTINCT MALE VOICE RESPONDS.': [''],
#              'BLACKBURN’S FARM SUPPLY. “BEST PRICES & LARGEST SELECTION!”': ['Nancy picks up the phone and dials. Jonathan continues snapping photos as the rat continues to  throw itself against the walls of its cage. Jonathan turns  away to reload his camera at a nearby WORKBENCH. The SQUEALING suddenly STOPS. Jonathan looks over his  shoulder. He walks back to the cage. The rat is now WRITHING  ON THE FLOOR of its cage.'],
#              'BILLY #2': ['To build. I want you to build.', 'What you see.'],
#              'LIGHTNING FLASHES': [''],
#              'MONSTER.': ['He WRITHES in pain and backs into the corner of the shower  stall. HIGH PITCHED NOISES causes Billy to cover his ears. He  YELLS as he CRUMBLES to the floor.'],
#              'MONTAGE': [' “MATERIAL GIRL” BY MADONNA plays while - Eleven tries on different clothes in front of a FULL LENGTH '],
#              'MIRROR.': [''],
#              'MONTAGE CONTINUES': ['Mike, Lucas, Will browsing for pretty shiny things that say  “I’m sorry.” Mike sees a SMALL GOLDEN TEDDY BEAR behind the  GLASS COUNTER. Mike gets the attention of the salesman,  PARKER, early 40s, standing nearby.',
#               '- El tries on DIFFERENT OUTFITS. - Max trying on DIFFERENT SUNGLASSES; eventually finding ones  she likes.',
#               'The boys are about to enter the LINGERIE STORE but stop dead  in their tracks when noticing - SEVERAL WOMEN, 20s and 30s, perusing sexy lingerie. - Mike gawks at THIGH-HIGH STOCKINGS. - Lucas stares at a MANNEQUIN in a BRA AND PANTIES. - Will sees BIKINI BOTTOMS on a MANNEQUIN’S LOWER-HALF. - The boys backing away from the store, then taking off.',
#               '- El has found a COLORFUL ROMPER. She smiles as she checks  herself out in the mirror.',
#               '- Max and El leave the store. El wearing the ROMPER and Max  wearing RED FRAMED SUNGLASSES. - Strutting through the mall, smiling, arm-in-arm.',
#               '- Mike and Will sniff SAMPLE FRAGRANCES. - Lucas sprays A BOTTLE into the air and smells it.',
#               'Max and El go into a PHOTO STUDIO.',
#               'Max and El pose in VARIOUS COLORFUL COSTUMES. While the  FLAMBOYANT PHOTOGRAPHER, TOBY, 30s, SNAPS PICTURES.',
#               'In the SHOE STORE, Max helps El walk in a PAIR OF HEELS. El  twists her ankle and falls, CRACKING UP. THREE GIRLS, 17, INCLUDING STACEY, are looking at a display  of HEELS. They ROLL THEIR EYES at the immature behavior. Max  and El just burst into LAUGHTER.',
#               'Near BURGER KING, Max and El peek around a corner at Stacey  and her friends chatting with a TEEN BOY, 17, OUT FRONT OF  ORANGE JULIUS. The girls are enjoying a TALL FROTHY ORANGE '],
#              'Lucas, Will and Mike leave the store': ['.'],
#              'TOBY': ['Wardrobe change! Wardrobe change,  thank you! - More cheesy poses in EXTRAVAGANT OUTFITS. Shake it! Shake it out for me.',
#               ''],
#              'JULIUS BEVERAGE.': ['El concentrates momentarily, then JERKS HER HEAD UPWARD. JUST THEN, Stacey’s DRINK EXPLODES, covering her and her  friends with the beverage. Max and El run away giddily. SONG CONTINUES as Max and El, running'],
#              'SONG ENDS.': ['Dustin is sitting at the table, controlling the RECORDER. The  SECRET RUSSIAN COMMUNICATION plays, while Robin paces,  listening.'],
#              '“DLYNNAYA”': [''],
#              '-- D, D ...': ['Dustin rushes to the WHITE BOARD.'],
#              'O.C.).': [''],
#              'FIVE.': ['The boys watch the bus pull away.'],
#              'HENRY': ['He raised my property taxes, Jim.  Forced me off my land.',
#               'Nothing proper about what that man  did to us! To our town! Henry relents and get in. Hopper slams the door.'],
#              'FLO': ['Special delivery! FLORENCE arrives carrying a PAPER BAG FROM JC PENNY. She  holds the bag out for Hopper.',
#               'Is that the right one?'],
#              'IN E MAJOR, G. 275': [''],
#              'III. MINUETTO” BY LUIGI BOCCHERINI.': ['Hopper comes in wearing a TAN BLAZER over his new shirt. He  adjusts his blazer. Hopper peruses the DRINK MENU. A SNOBBY WAITER, 30s, is  taking Hopper’s order.'],
#              'WAITER': ['Very good, sir.',
#               'Very good, sir!',
#               'Our Chianti is quite good. Chianti.',
#               'Medium-bodied, with just a hint of  cherry.',
#               'Ooh, very good sir. The waiter leaves and Hopper lights a CIGARETTE. He stares  past the EMPTY SEAT across from him -- at the door. Hopper  checks his watch. The restaurant is PACKED. Hopper sits alone  -- waiting. It’s dark. Joyce’s CAR is parked in front of the garage. Scott is wrapping COPPER WIRE around a METAL TOOLBOX.',
#               'Would you like to order your  entrée, sir?',
#               'My name is not Enzo. Hopper waves him off, reaching for his WALLET.',
#               'Sir, I’m afraid no alcohol is  allowed off the premises. Hopper BLOWS RASPBERRY in the waiter’s face.'],
#              'METAL TOOLBOX.': [''],
#              'Apophenia.': [''],
#              'ROBIN, DUSTIN, STEVE': ['(reading from the white  board) The week is long. The silver cat  feeds. When blue meets yellow in  the west. Steve closes and locks the GATE.'],
#              'mall': ['.'],
#              'DUSTIN’': ['Like a super secret spy code.'],
#              '“DAISY BELL”': ['BY HARRY DACRE plays.'],
#              'LA TRAVIATA': [''],
#              'ACT I. “LIBIAMO, NE’': [''],
#              'LIETI CALICI”.': ['Hopper, staring toward A YOUNG COUPLE ENJOYING THEIR DINNER,  holds a NEARLY EMPTY GLASS OF CHIANTI. His eyes, SUNKIN. He’s  drunk. He chugs what’s left and bites into a BREADSTICK.']})

# %%
s3e2_dict.keys()
# Out:
# dict_keys(['"CHAPTER TWO', 'THE MALL RATS"', 'CAMARO.', 'OPERATOR', 'TO BILLY’S FACE.', 'BILLY', 'HIMSELF.', 'OPENING CREDITS', 'HOPPER', 'EL', 'PHONE RINGS', 'KAREN', 'MIKE', 'MIKE’S BASEMENT AND EL’S BEDROOM', 'PINTO.', 'JOYCE', 'OFFICER POWELL', 'DORIS DRISCOLL 4819 CORNWALLIS RD', 'NANCY', 'BRUCE', 'TOM', 'BEAT', 'JONATHAN', 'NEAR JONATHAN’S CAR', 'MONTAGE OVER THE SONG', '“GET UP AND GO” BY THE GO GO’S', 'CREAM CONES.', 'ROBIN', 'DAUGHTER', 'DUSTIN', 'STEVE', 'BANANA BOAT ICE CREAM.', 'DUDTIN', 'DICTIONARY.', 'MAX', 'LUCAS', 'WILL', 'HEATHER', 'TRASHY MAGAZINES. MOM #1', 'MOM #3', 'LIZ', 'JILL', 'MOM #1', 'POUNDING.', 'BLACK', 'BILLY’S POV & HANDHELD FOLLOW', 'POV BILLY', 'KAREN’S FRIENDS', 'FULLY', 'DIALATED.', 'ECU', 'INTENSLY GLOWING SUN', 'DISSOLVE TO', 'ERICA', 'MICROCASSETTE RECORDER.', 'DRISCOLL.', 'MRS. DRISCOLL', 'SQUEALING. SNARLING. BANGING.', 'PROTESTERS', 'HELMET', 'CAMERA HOLDS. Hopper eyeballs', 'CANDACE', 'MAYOR LARRY KLINE, 50s, the wealthy', 'KLINE', 'CUBAN CIGAR)', '', 'SEVERAL TEXTBOOKS ON ELECTROMAGNETIC', 'DOORBELL.', 'WEARING A HEADBAND MAGNIFIER.', 'DOORBELL CHIMES', 'MR. CLARKE', 'INDISTINCT MALE VOICE RESPONDS.', 'BLACKBURN’S FARM SUPPLY. “BEST PRICES & LARGEST SELECTION!”', 'BILLY #2', 'LIGHTNING FLASHES', 'MONSTER.', 'MONTAGE', 'MIRROR.', 'MONTAGE CONTINUES', 'Lucas, Will and Mike leave the store', 'TOBY', 'JULIUS BEVERAGE.', 'SONG ENDS.', '“DLYNNAYA”', '-- D, D ...', 'O.C.).', 'FIVE.', 'HENRY', 'FLO', 'IN E MAJOR, G. 275', 'III. MINUETTO” BY LUIGI BOCCHERINI.', 'WAITER', 'METAL TOOLBOX.', 'Apophenia.', 'ROBIN, DUSTIN, STEVE', 'mall', 'DUSTIN’', '“DAISY BELL”', 'LA TRAVIATA', 'ACT I. “LIBIAMO, NE’', 'LIETI CALICI”.'])

# %%
s3_ep2_df = pd.DataFrame(s3e2_dict.items(), columns=['Character', 'Dialog'])

# %%
import string

# %%
s3_ep2_df['Character'] = s3_ep2_df['Character'].str.replace('[^\w\s]','')
# Out:
# /var/folders/sk/13d9bc1s7wsbnd2qv8jmz03m0000gn/T/ipykernel_8538/3575185055.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   s3_ep2_df['Character'] = s3_ep2_df['Character'].str.replace('[^\w\s]','')

# %%
s3_ep2_df
# Out:
#             Character                                             Dialog
# 0         CHAPTER TWO                                                 []
# 1       THE MALL RATS  [by updated versions. ii. ii. iv.  Scenes in R...
# 2              CAMARO  [Billy speeds away; leaving a trail of dust in...
# 3            OPERATOR  [Nine-one-one, what’s your  emergency? Billy g...
# 4      TO BILLYS FACE             [The LIGHT inside the booth FLICKERS.]
# ..                ...                                                ...
# 96             DUSTIN                    [Like a super secret spy code.]
# 97         DAISY BELL                            [BY HARRY DACRE plays.]
# 98        LA TRAVIATA                                                 []
# 99   ACT I LIBIAMO NE                                                 []
# 100      LIETI CALICI  [Hopper, staring toward A YOUNG COUPLE ENJOYIN...
#
# [101 rows x 2 columns]

# %%
s3_ep2_df = s3_ep2_df.explode('Dialog')

# %%
s3_ep2_df['Fix Name'] = s3_ep2_df['Character'].apply(lambda x: "True" if x in characters_v1 else "Fix")

# %%
fix_df = s3_ep2_df[s3_ep2_df['Fix Name'] == "Fix"]

# %%
fix_df['Character'].unique()
# Out:
# array(['CHAPTER TWO', 'THE MALL RATS', 'CAMARO', 'OPERATOR',
#        'TO BILLYS FACE', 'HIMSELF', 'OPENING CREDITS', 'EL',
#        'PHONE RINGS', 'MIKES BASEMENT AND ELS BEDROOM', 'PINTO',
#        'OFFICER POWELL', 'DORIS DRISCOLL 4819 CORNWALLIS RD', 'BEAT',
#        'NEAR JONATHANS CAR', 'MONTAGE OVER THE SONG',
#        'GET UP AND GO BY THE GO GOS', 'CREAM CONES', 'DAUGHTER',
#        'BANANA BOAT ICE CREAM', 'DUDTIN', 'DICTIONARY',
#        'TRASHY MAGAZINES MOM 1', 'MOM 3', 'LIZ', 'JILL', 'MOM 1',
#        'POUNDING', 'BLACK', 'BILLYS POV  HANDHELD FOLLOW', 'POV BILLY',
#        'KARENS FRIENDS', 'FULLY', 'DIALATED', 'ECU',
#        'INTENSLY GLOWING SUN', 'DISSOLVE TO', 'MICROCASSETTE RECORDER',
#        'DRISCOLL', 'MRS DRISCOLL', 'SQUEALING SNARLING BANGING',
#        'PROTESTERS', 'HELMET', 'CAMERA HOLDS Hopper eyeballs', 'CANDACE',
#        'MAYOR LARRY KLINE 50s the wealthy', 'KLINE', 'CUBAN CIGAR', '',
#        'SEVERAL TEXTBOOKS ON ELECTROMAGNETIC', 'DOORBELL',
#        'WEARING A HEADBAND MAGNIFIER', 'DOORBELL CHIMES', 'MR CLARKE',
#        'INDISTINCT MALE VOICE RESPONDS',
#        'BLACKBURNS FARM SUPPLY BEST PRICES  LARGEST SELECTION', 'BILLY 2',
#        'LIGHTNING FLASHES', 'MONSTER', 'MONTAGE', 'MIRROR',
#        'MONTAGE CONTINUES', 'Lucas Will and Mike leave the store', 'TOBY',
#        'JULIUS BEVERAGE', 'SONG ENDS', 'DLYNNAYA', ' D D ', 'OC', 'FIVE',
#        'FLO', 'IN E MAJOR G 275', 'III MINUETTO BY LUIGI BOCCHERINI',
#        'WAITER', 'METAL TOOLBOX', 'Apophenia', 'ROBIN DUSTIN STEVE',
#        'mall', 'DAISY BELL', 'LA TRAVIATA', 'ACT I LIBIAMO NE',
#        'LIETI CALICI'], dtype=object)

# %%
import numpy as np

# %%
s3_ep2_df['Character_Fix'] = np.where(s3_ep2_df['Character'] == "DUDTIN", "DUSTIN",s3_ep2_df['Character'])

# %%
s3_ep2_df = s3_ep2_df[~s3_ep2_df['Dialog'].isnull()]

# %%
#s3_ep2_df['Dialog'].replace('  ', np.nan, inplace=True)

# %%
s3_ep2_df["Length Dialog"] = s3_ep2_df['Dialog'].apply(lambda x: len(x))

# %%
s3_ep2_df['Length Dialog'].replace(0, np.nan, inplace=True)

# %%
s3_ep2_df = s3_ep2_df.dropna()

# %%
s3_ep2_df
# Out:
#               Character                                             Dialog  \
# 1         THE MALL RATS  by updated versions. ii. ii. iv.  Scenes in RE...
# 2                CAMARO  Billy speeds away; leaving a trail of dust in ...
# 3              OPERATOR  Nine-one-one, what’s your  emergency? Billy ge...
# 3              OPERATOR  Is someone there? Hello? The LIGHT GOES OUT, t...
# 4        TO BILLYS FACE               The LIGHT inside the booth FLICKERS.
# ..                  ...                                                ...
# 94   ROBIN DUSTIN STEVE  (reading from the white  board) The week is lo...
# 95                 mall                                                  .
# 96               DUSTIN                      Like a super secret spy code.
# 97           DAISY BELL                              BY HARRY DACRE plays.
# 100        LIETI CALICI  Hopper, staring toward A YOUNG COUPLE ENJOYING...
#
#     Fix Name       Character_Fix  Length Dialog
# 1        Fix       THE MALL RATS          581.0
# 2        Fix              CAMARO          210.0
# 3        Fix            OPERATOR          220.0
# 3        Fix            OPERATOR          355.0
# 4        Fix      TO BILLYS FACE           36.0
# ..       ...                 ...            ...
# 94       Fix  ROBIN DUSTIN STEVE          142.0
# 95       Fix                mall            1.0
# 96      True              DUSTIN           29.0
# 97       Fix          DAISY BELL           21.0
# 100      Fix        LIETI CALICI          181.0
#
# [454 rows x 5 columns]

# %%
s3_ep2_df['Character_Keep'] = s3_ep2_df['Character_Fix'].apply(lambda x: "Keep" if x in characters_v1 else "Remove")
# Out:
# /var/folders/sk/13d9bc1s7wsbnd2qv8jmz03m0000gn/T/ipykernel_8538/3970099912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s3_ep2_df['Character_Keep'] = s3_ep2_df['Character_Fix'].apply(lambda x: "Keep" if x in characters_v1 else "Remove")

# %%
s3_ep2_df_keep = s3_ep2_df[s3_ep2_df['Character_Keep']=="Keep"]

# %%
s3_ep2_df_keep.reset_index()
# Out:
#      index Character                                             Dialog  \
# 0        5     BILLY  What do you want? He cautiously walks toward t...
# 1        5     BILLY        The group continues shuffling toward Billy.
# 2        5     BILLY  I said WHAT -- DO -- YOU -- WANT? THUNDER CLAP...
# 3        5     BILLY   Stay away from me, Karen. He marches past Karen.
# 4        5     BILLY  I said, what do you want!? Facing the IDENTICA...
# ..     ...       ...                                                ...
# 311     53     ERICA                    Can I try the peppermint stick?
# 312     53     ERICA  Yes, and I’d like to try it again. Robin rolls...
# 313     87     HENRY  He raised my property taxes, Jim.  Forced me o...
# 314     87     HENRY  Nothing proper about what that man  did to us!...
# 315     96    DUSTIN                      Like a super secret spy code.
#
#     Fix Name Character_Fix  Length Dialog Character_Keep
# 0       True         BILLY           86.0           Keep
# 1       True         BILLY           43.0           Keep
# 2       True         BILLY          298.0           Keep
# 3       True         BILLY           48.0           Keep
# 4       True         BILLY           66.0           Keep
# ..       ...           ...            ...            ...
# 311     True         ERICA           31.0           Keep
# 312     True         ERICA           56.0           Keep
# 313     True         HENRY           57.0           Keep
# 314     True         HENRY          108.0           Keep
# 315     True        DUSTIN           29.0           Keep
#
# [316 rows x 7 columns]

# %%
#elements_strings = []
#scene_nums = []
#for item in charlist2:
#    if re.match(r"^([0-9]*)", item):
#        print(item)
#        scene_nums.append(item)
#    else:
#        elements_strings.append(item)
